# %% [markdown]
# # 🧠 RLHF Full Workflow (Unified Notebook)
# This notebook trains PPO Expert, generates preference data using π₁ vs π₂, trains PPO-RLHF using RewardNet, and then trains a DPO policy — all within one integrated flow. Supports both discrete and continuous environments.

# %% [markdown]
# ## 📦 Step 1: Setup and Imports

# %%
import os
import gymnasium as gym
import torch
import pickle
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.policies import ActorCriticPolicy

# %% [markdown]
# ## ⚙️ Step 2: Environment Setup

# %%
# ===== 🧩 Parameter Settings: Used to control the entire training / preference / visualization process =====

env_id = "Pendulum-v1"     # Task environment name (Options: CartPole-v1, Pendulum-v1, Acrobot-v1, MountainCar-v0, MountainCarContinuous-v0)

seed = 42                  # Random seed to ensure experiment reproducibility

total_timesteps = 300_000   # Number of training steps for Expert PPO (Recommended: 40k for CartPole, 300k for Pendulum)

num_prefs = 10_000            # Number of preference samples
sample_prefs = 10_000

# ===========================================================


set_random_seed(seed)

env = Monitor(gym.make(env_id))
is_discrete = hasattr(env.action_space, "n")
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
sample_length = 600
print(f"✅ Environment: {env_id} | Action space: {'Discrete' if is_discrete else 'Continuous'}")
# Out:
# ✅ Environment: Pendulum-v1 | Action space: Continuous

# %% [markdown]
# ## 🧠 Step 3: Train PPO Expert (π₁) and Save Checkpoints

# %%
checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(
    save_freq=total_timesteps // 10,
    save_path=checkpoint_dir,
    name_prefix="ppo"
)

expert_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
expert_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
expert_model.save(f"{env_id}_expert_seed{seed}.zip")
env.close()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    fps             | 7525      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3957         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036137116 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0082       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00229     |
# |    std                  | 0.988        |
# |    value_loss           | 8.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3268         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0020711243 |
# |    clip_fraction        | 0.00454      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.972        |
# |    value_loss           | 6.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3206         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0056473394 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0724       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+03      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 0.966        |
# |    value_loss           | 7.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.18e+03   |
# | time/                   |             |
# |    fps                  | 3283        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005954067 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.019       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.956       |
# |    value_loss           | 7.33e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 3339         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035645005 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0033       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.947        |
# |    value_loss           | 9.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 3377         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0025297212 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00571      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.89e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 0.931        |
# |    value_loss           | 5.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 3406         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032039983 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00178      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.93         |
# |    value_loss           | 7.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.17e+03   |
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002500248 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000996    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.913       |
# |    value_loss           | 8.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 3447         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0008562881 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000546    |
# |    std                  | 0.929        |
# |    value_loss           | 6.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 3465         |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0028596604 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000798     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00236     |
# |    std                  | 0.913        |
# |    value_loss           | 6.68e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 3474        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.002483549 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.000502    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.903       |
# |    value_loss           | 6.92e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3485         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0020230487 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000486     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.55e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000806    |
# |    std                  | 0.894        |
# |    value_loss           | 9.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 3506         |
# |    iterations           | 14           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0022404476 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.000266     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 0.891        |
# |    value_loss           | 7.57e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 3507         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0019240514 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000173     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.71e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000574    |
# |    std                  | 0.895        |
# |    value_loss           | 8.8e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 3505         |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0030941283 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000432     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.889        |
# |    value_loss           | 7.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 3446         |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035299638 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000419     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00306     |
# |    std                  | 0.896        |
# |    value_loss           | 5.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3463         |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017563725 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00029      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.881        |
# |    value_loss           | 5.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3486         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0020866941 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.000223     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+03      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.878        |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3504         |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036356864 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000147     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.08e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 0.866        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3503         |
# |    iterations           | 21           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040781517 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 8.99e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00225     |
# |    std                  | 0.877        |
# |    value_loss           | 5.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 3519         |
# |    iterations           | 22           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0024939217 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 6.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.88         |
# |    value_loss           | 5.46e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 3528        |
# |    iterations           | 23          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004869461 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 6.68e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00456    |
# |    std                  | 0.889       |
# |    value_loss           | 5.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 3537        |
# |    iterations           | 24          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002771392 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 6.31e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.875       |
# |    value_loss           | 4.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3506         |
# |    iterations           | 25           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0046803323 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 5.55e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.873        |
# |    value_loss           | 3.23e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 3516        |
# |    iterations           | 26          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004229717 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 3.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.865       |
# |    value_loss           | 3.69e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 3530         |
# |    iterations           | 27           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0042661284 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 2.32e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.865        |
# |    value_loss           | 4.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 3542         |
# |    iterations           | 28           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0033390112 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 2.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.88         |
# |    value_loss           | 3.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 3531         |
# |    iterations           | 29           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0014606593 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.15e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.886        |
# |    value_loss           | 2.84e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.11e+03   |
# | time/                   |             |
# |    fps                  | 3522        |
# |    iterations           | 30          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002135611 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 1.48e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00133    |
# |    std                  | 0.888       |
# |    value_loss           | 3.44e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 3502         |
# |    iterations           | 31           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0026322685 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.29e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.872        |
# |    value_loss           | 3.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3229         |
# |    iterations           | 32           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0042038765 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.12e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00305     |
# |    std                  | 0.866        |
# |    value_loss           | 3.65e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3203         |
# |    iterations           | 33           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0031772065 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.06e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+03      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00219     |
# |    std                  | 0.886        |
# |    value_loss           | 2.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3204         |
# |    iterations           | 34           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0048773363 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 8.11e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 0.913        |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3209         |
# |    iterations           | 35           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0006805477 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 6.5e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.909        |
# |    value_loss           | 3.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 3200        |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003674881 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 6.14e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 0.918       |
# |    value_loss           | 2.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3208         |
# |    iterations           | 37           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0036517116 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 5.6e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 0.908        |
# |    value_loss           | 2.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3140         |
# |    iterations           | 38           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0037963428 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 4.05e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 928          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 0.899        |
# |    value_loss           | 2.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 3108        |
# |    iterations           | 39          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004236321 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 3.76e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 907         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00222    |
# |    std                  | 0.91        |
# |    value_loss           | 2.65e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3092         |
# |    iterations           | 40           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0036059637 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 4.41e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.919        |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 3081         |
# |    iterations           | 41           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0021971758 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 3.64e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000253    |
# |    std                  | 0.924        |
# |    value_loss           | 2.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 3079         |
# |    iterations           | 42           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0032526464 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 3.46e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 908          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.919        |
# |    value_loss           | 1.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 3078         |
# |    iterations           | 43           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0032642623 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 3.1e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 677          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.902        |
# |    value_loss           | 1.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 3050         |
# |    iterations           | 44           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035909957 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 730          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.908        |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 3056        |
# |    iterations           | 45          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.002643352 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.62e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 740         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00153    |
# |    std                  | 0.894       |
# |    value_loss           | 1.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 3065         |
# |    iterations           | 46           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0025438992 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 858          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000943    |
# |    std                  | 0.882        |
# |    value_loss           | 1.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 3076        |
# |    iterations           | 47          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.003206753 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 2.44e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 677         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.859       |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 3085         |
# |    iterations           | 48           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0040994957 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 689          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.873        |
# |    value_loss           | 1.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 3094         |
# |    iterations           | 49           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046590148 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 2.15e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 869          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.881        |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 3095         |
# |    iterations           | 50           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0048898794 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 709          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.863        |
# |    value_loss           | 1.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 3097         |
# |    iterations           | 51           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0034761033 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 1.79e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 801          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00386     |
# |    std                  | 0.852        |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 3105         |
# |    iterations           | 52           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0048821163 |
# |    clip_fraction        | 0.0492       |
# ...
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -303         |
# | time/                   |              |
# |    fps                  | 3058         |
# |    iterations           | 131          |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0035021058 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | 0.000302     |
# |    std                  | 0.525        |
# |    value_loss           | 435          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 3061        |
# |    iterations           | 132         |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.004932278 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00531    |
# |    std                  | 0.525       |
# |    value_loss           | 564         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 3062        |
# |    iterations           | 133         |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.001973547 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96          |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.001      |
# |    std                  | 0.524       |
# |    value_loss           | 280         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -291         |
# | time/                   |              |
# |    fps                  | 3065         |
# |    iterations           | 134          |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0043183514 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00301     |
# |    std                  | 0.516        |
# |    value_loss           | 93.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -308         |
# | time/                   |              |
# |    fps                  | 3067         |
# |    iterations           | 135          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0031747497 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.515        |
# |    value_loss           | 478          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -311         |
# | time/                   |              |
# |    fps                  | 3069         |
# |    iterations           | 136          |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0047922134 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 333          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.515        |
# |    value_loss           | 366          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -333         |
# | time/                   |              |
# |    fps                  | 3072         |
# |    iterations           | 137          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0029687083 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 202          |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.0041      |
# |    std                  | 0.516        |
# |    value_loss           | 364          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 3075         |
# |    iterations           | 138          |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0053287414 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 196          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.516        |
# |    value_loss           | 485          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 3077        |
# |    iterations           | 139         |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.004356507 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.7        |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.000732   |
# |    std                  | 0.513       |
# |    value_loss           | 252         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -317         |
# | time/                   |              |
# |    fps                  | 3080         |
# |    iterations           | 140          |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0038130344 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 0.508        |
# |    value_loss           | 311          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 3079        |
# |    iterations           | 141         |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.004804925 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.6        |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.506       |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -284        |
# | time/                   |             |
# |    fps                  | 3082        |
# |    iterations           | 142         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.016841142 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.498       |
# |    value_loss           | 75.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 3083        |
# |    iterations           | 143         |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.004473033 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00296     |
# |    std                  | 0.488       |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -274        |
# | time/                   |             |
# |    fps                  | 3086        |
# |    iterations           | 144         |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.011253502 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.000699    |
# |    std                  | 0.48        |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -269        |
# | time/                   |             |
# |    fps                  | 3083        |
# |    iterations           | 145         |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.006516246 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.8        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.474       |
# |    value_loss           | 211         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -244         |
# | time/                   |              |
# |    fps                  | 3084         |
# |    iterations           | 146          |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0078090187 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | 0.00213      |
# |    std                  | 0.474        |
# |    value_loss           | 52.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 3083        |
# |    iterations           | 147         |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.010483112 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 0.461       |
# |    value_loss           | 16.1        |
# -----------------------------------------

# %% [markdown]
# ## 🧪 Step 4: Select π₂ (Half-Performance PPO Checkpoint)

# %%
def evaluate_policy(model, env, episodes=10):
    scores = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        done = False
        total = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        scores.append(total)
    return np.mean(scores)

env = gym.make(env_id)
checkpoints = sorted([f for f in os.listdir(checkpoint_dir) if f.endswith(".zip")])
rewards = [(f, evaluate_policy(PPO.load(os.path.join(checkpoint_dir, f), env=env), env)) for f in checkpoints]
best_reward = max(rewards, key=lambda x: x[1])[1]
if best_reward < 0 :
    target = best_reward*1.5
else :
    target = best_reward * 0.5
rewards.sort(key=lambda x: abs(x[1] - target))
pi2_model = PPO.load(os.path.join(checkpoint_dir, rewards[0][0]), env=env)
pi2_model.save(f"{env_id}_pi2_model_seed{seed}.zip")
print(f"✅ Selected π₂: {rewards[0][0]} with ~{rewards[0][1]:.1f} reward")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Selected π₂: ppo_210000_steps.zip with ~-442.7 reward

# %% [markdown]
# ## ❤️ Step 5: Generate Preferences (π₁ vs π₂)

# %%
import numpy as np
import pickle
from tqdm import trange
import numpy as np

def generate_trajectory(model, env, seed, max_steps):
    obs_list, act_list, rewards, mask = [], [], [], []
    obs, _ = env.reset(seed=seed)

    for step in range(max_steps):
        action, _ = model.predict(obs)
        obs_, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        obs_list.append(np.array(obs))       # ensure obs is np.array
        act_list.append(np.array(action))    # ensure action is np.array
        rewards.append(reward)
        mask.append(1)

        obs = obs_
        if done:
            break

    pad_len = max_steps - len(obs_list)
    if pad_len > 0:
        obs_shape = obs_list[0].shape
        obs_list += [np.zeros(obs_shape)] * pad_len
        act_shape = act_list[0].shape if isinstance(act_list[0], np.ndarray) else ()
        act_list += [np.zeros(act_shape)] * pad_len
        rewards += [0.0] * pad_len
        mask += [0] * pad_len

    return {
        "obs": np.stack(obs_list),       # [T, obs_dim]
        "acts": np.stack(act_list),      # [T] (discrete) or [T, act_dim] (continuous)
        "rews": np.array(rewards),       # [T]
        "mask": np.array(mask)           # [T]
    }

def compute_return(traj):
    return sum(traj["rews"])

def soft_preference_prob(R1, R2):
    max_r = max(R1, R2)
    return np.exp(R1 - max_r) / (np.exp(R1 - max_r) + np.exp(R2 - max_r))

# Sample preference data
prefs = []
env = gym.make(env_id)
for idx in trange(num_prefs, desc="🔄 Generating preference pairs"):
    traj1 = generate_trajectory(model = expert_model, env=env, seed=idx, max_steps=sample_length)
    traj2 = generate_trajectory(pi2_model, env=env, seed=idx, max_steps=sample_length)
    R1, R2 = compute_return(traj1), compute_return(traj2)
    p = soft_preference_prob(R1, R2)
    label = int(np.random.rand() < p)
    prefs.append((traj1, traj2, label))

# save .pkl
filename = f"prefs_{env_id}_seed{seed}.pkl"
with open(filename, "wb") as f:
    pickle.dump(prefs, f)

print(f"✅ Saved {len(prefs)} preference pairs to {filename}")
# Out:
# 🔄 Generating preference pairs: 100%|██████████| 10000/10000 [06:35<00:00, 25.30it/s]
# ✅ Saved 10000 preference pairs to prefs_Pendulum-v1_seed42.pkl

# %%
class PreferenceDataset(torch.utils.data.Dataset):
    def __init__(self, prefs, is_discrete):
        self.prefs = prefs
        self.is_discrete = is_discrete

    def __len__(self):
        return len(self.prefs)

    def __getitem__(self, idx):
        traj1, traj2, label = self.prefs[idx]

        return {
            "obs1": torch.from_numpy(traj1["obs"]).float(),
            "acts1": torch.from_numpy(traj1["acts"]).long() if self.is_discrete else torch.from_numpy(traj1["acts"]).float(),
            "mask1": torch.from_numpy(traj1["mask"]).float(),

            "obs2": torch.from_numpy(traj2["obs"]).float(),
            "acts2": torch.from_numpy(traj2["acts"]).long() if self.is_discrete else torch.from_numpy(traj2["acts"]).float(),
            "mask2": torch.from_numpy(traj2["mask"]).float(),

            "label": torch.tensor(label, dtype=torch.float32)
        }

# %% [markdown]
# ## ⚙️ Step 7: Train DPO Policy

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO

def train_dpo(dataloader, env, seed=0, epochs=25, device='cpu'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    
    model = PPO("MlpPolicy", env, verbose=0, seed=seed, device=device)
    policy = model.policy
    policy.train()  # ensure in training mode
    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]

            obs1_flat = obs1.view(-1, obs_dim)
            obs2_flat = obs2.view(-1, obs_dim)
            acts1_flat = acts1.view(-1) if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1) if is_discrete else acts2.view(-1, act_dim)

            dist1 = policy.get_distribution(obs1_flat)  # returns Categorical
            dist2 = policy.get_distribution(obs2_flat)
            lp1 = dist1.log_prob(acts1_flat).view(B, T)  # [B, T]
            lp2 = dist2.log_prob(acts2_flat).view(B, T)
            
            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits = logp1_sum - logp2_sum        # [B]

            loss = F.binary_cross_entropy_with_logits(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

#with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
#    prefs = pickle.load(f)
#prefs = prefs[:sample_prefs]

#dataset = PreferenceDataset(prefs, is_discrete)
#loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

#dpo_model = train_dpo(loader, env)
#torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO
import copy

def train_dpo_from_ref(dataloader,ref_policy_sb3, env, beta= 0.05,  seed=42, epochs=25, device='cpu'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]


    ref_policy = ref_policy_sb3.policy  # frozen
    policy = copy.deepcopy(ref_policy)  # trainable

    policy.to(device)
    ref_policy.to(device)
    ref_policy.eval()  # ensure frozen

    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        policy.train()  # ensure in training mode
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]
            obs1_flat = obs1.view(-1, obs_dim) # [B*T, obs_dim]
            obs2_flat = obs2.view(-1, obs_dim) # [B*T, obs_dim]
            acts1_flat = acts1.view(-1).long() if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1).long() if is_discrete else acts2.view(-1, act_dim)

            # --- Compute log probs from trainable policy ---

            dist1 = policy.get_distribution(obs1_flat)
            dist2 = policy.get_distribution(obs2_flat)

            logp1 = dist1.log_prob(acts1_flat)
            logp2 = dist2.log_prob(acts2_flat)



            #logp1 = torch.log_softmax(policy(obs1_flat), dim=-1)
            #logp2 = torch.log_softmax(policy(obs2_flat), dim=-1)

            # --- Compute log probs from reference policy (frozen) ---
            with torch.no_grad():
                dist1_ref = ref_policy.get_distribution(obs1_flat)
                dist2_ref = ref_policy.get_distribution(obs2_flat)

                logp1_ref = dist1_ref.log_prob(acts1_flat)
                logp2_ref = dist2_ref.log_prob(acts2_flat)

                #logp1_ref = torch.log_softmax(ref_policy(obs1_flat), dim=-1)
                #logp2_ref = torch.log_softmax(ref_policy(obs2_flat), dim=-1)


            lp1 = (logp1 - logp1_ref).view(B, -1)  # shape [B, T]
            lp2 = (logp2 - logp2_ref).view(B, -1)


            #lp1 = logp1[torch.arange(len(acts1_flat)), acts1_flat].view(B, -1)
            #lp2 = logp2[torch.arange(len(acts2_flat)), acts2_flat].view(B, -1)

            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits =beta*(logp1_sum - logp2_sum)        # [B]
            loss = F.binary_cross_entropy_with_logits(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

# %%
def eval_policy(model, env, is_sb3=True, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0] if is_sb3 else model.select_action(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns



import matplotlib.pyplot as plt
import numpy as np

def fine_tune_dpo_with_betas(env, dataloader, pi2_model, beta_values_from_ref, epochs=15, device='cpu'):
    rewards_from_ref = {}
    rewards = {}

    obs_dim = env.observation_space.shape[0]
    is_discrete = hasattr(env.action_space, "n")
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]

    # ✅ Train DPO starting from π₂ and moving toward expert
    for beta in beta_values_from_ref:
        print(f"Training DPO (π₂ → Expert) with β = {beta}")

        trained_policy_from_ref = train_dpo_from_ref(
            dataloader=dataloader,
            ref_policy_sb3=pi2_model,
            env=env,
            beta=beta,
            epochs=epochs,
            device=device
        )

        avg_reward = np.mean(eval_policy(trained_policy_from_ref, env, episodes=20))
        print(f"Final avg reward for β = {beta}: {avg_reward:.2f}")
        rewards_from_ref[beta] = avg_reward






    # ✅ Plot both curves
    plt.figure(figsize=(9, 5))
    plt.plot(list(rewards_from_ref.keys()), list(rewards_from_ref.values()), marker='o', label="DPO from π₂")
    plt.xlabel("β (temperature)")
    plt.ylabel("Final Avg Reward")
    plt.title("DPO Fine-Tuning: π₂ → Expert vs Baseline")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return rewards_from_ref



import pickle
import numpy as np
from scipy.stats import linregress

sample_prefs_list = [1000, 2000, 4000, 6000, 8000, 10000]
slope_results = []

for sample_prefs in sample_prefs_list:
    with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
        prefs = pickle.load(f)
    prefs = prefs[:sample_prefs]

    dataset = PreferenceDataset(prefs, is_discrete)
    loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

    beta_values_from_ref = np.concatenate([np.arange(0, 2, 0.4), np.arange(2, 6, 0.4)])

    rewards_from_ref = fine_tune_dpo_with_betas(env, loader, pi2_model, beta_values_from_ref)
    beta_from_ref = max(rewards_from_ref, key=rewards_from_ref.get)

    slope_results.append(beta_values_from_ref)
# Out:
# Training DPO (π₂ → Expert) with β = 0.0
# Epoch 1/15, Loss: 0.6931
# Epoch 2/15, Loss: 0.6931
# Epoch 3/15, Loss: 0.6931
# Epoch 4/15, Loss: 0.6931
# Epoch 5/15, Loss: 0.6931
# Epoch 6/15, Loss: 0.6931
# Epoch 7/15, Loss: 0.6931
# Epoch 8/15, Loss: 0.6931
# Epoch 9/15, Loss: 0.6931
# Epoch 10/15, Loss: 0.6931
# Epoch 11/15, Loss: 0.6931
# Epoch 12/15, Loss: 0.6931
# Epoch 13/15, Loss: 0.6931
# Epoch 14/15, Loss: 0.6931
# Epoch 15/15, Loss: 0.6931
# Final avg reward for β = 0.0: -396.27
# Training DPO (π₂ → Expert) with β = 0.4
# Epoch 1/15, Loss: 0.8816
# Epoch 2/15, Loss: 0.3212
# Epoch 3/15, Loss: 0.3302
# Epoch 4/15, Loss: 0.3223
# Epoch 5/15, Loss: 0.7365
# Epoch 6/15, Loss: 0.3106
# Epoch 7/15, Loss: 0.3392
# Epoch 8/15, Loss: 0.3711
# Epoch 9/15, Loss: 0.3780
# Epoch 10/15, Loss: 0.4532
# Epoch 11/15, Loss: 0.2577
# Epoch 12/15, Loss: 0.2458
# Epoch 13/15, Loss: 0.1825
# Epoch 14/15, Loss: 0.3393
# Epoch 15/15, Loss: 0.2378
# Final avg reward for β = 0.4: -451.96
# Training DPO (π₂ → Expert) with β = 0.8
# Epoch 1/15, Loss: 1.7042
# Epoch 2/15, Loss: 0.5826
# Epoch 3/15, Loss: 0.5987
# Epoch 4/15, Loss: 0.4876
# Epoch 5/15, Loss: 0.4730
# Epoch 6/15, Loss: 0.4062
# Epoch 7/15, Loss: 0.6231
# Epoch 8/15, Loss: 0.8522
# Epoch 9/15, Loss: 0.3702
# Epoch 10/15, Loss: 0.4975
# Epoch 11/15, Loss: 0.4491
# Epoch 12/15, Loss: 0.5237
# Epoch 13/15, Loss: 0.6652
# Epoch 14/15, Loss: 0.7797
# Epoch 15/15, Loss: 0.3870
# Final avg reward for β = 0.8: -414.61
# Training DPO (π₂ → Expert) with β = 1.2000000000000002
# Epoch 1/15, Loss: 2.5866
# Epoch 2/15, Loss: 0.8394
# Epoch 3/15, Loss: 0.7052
# Epoch 4/15, Loss: 0.6554
# Epoch 5/15, Loss: 1.0149
# Epoch 6/15, Loss: 0.5880
# Epoch 7/15, Loss: 1.2804
# Epoch 8/15, Loss: 1.1945
# Epoch 13/15, Loss: 2.3881
# Epoch 14/15, Loss: 2.6274
# Epoch 15/15, Loss: 2.1300
# Final avg reward for β = 4.3999999999999995: -438.48
# Training DPO (π₂ → Expert) with β = 4.799999999999999
# Epoch 1/15, Loss: 3.8926
# Epoch 2/15, Loss: 4.0255
# Epoch 3/15, Loss: 3.0076
# Epoch 4/15, Loss: 3.4746
# Epoch 5/15, Loss: 3.0407
# Epoch 6/15, Loss: 3.0204
# Epoch 7/15, Loss: 2.9114
# Epoch 8/15, Loss: 2.9795
# Epoch 9/15, Loss: 2.7784
# Epoch 10/15, Loss: 2.6871
# Epoch 11/15, Loss: 2.5755
# Epoch 12/15, Loss: 2.6986
# Epoch 13/15, Loss: 2.6621
# Epoch 14/15, Loss: 2.4106
# Epoch 15/15, Loss: 2.4397
# Final avg reward for β = 4.799999999999999: -472.02
# Training DPO (π₂ → Expert) with β = 5.199999999999999
# Epoch 1/15, Loss: 3.6803
# Epoch 2/15, Loss: 3.4600
# Epoch 3/15, Loss: 3.5852
# Epoch 4/15, Loss: 3.8078
# Epoch 5/15, Loss: 3.0852
# Epoch 6/15, Loss: 2.9999
# Epoch 7/15, Loss: 2.9318
# Epoch 8/15, Loss: 3.9932
# Epoch 9/15, Loss: 3.2304
# Epoch 10/15, Loss: 2.8374
# Epoch 11/15, Loss: 3.3589
# Epoch 12/15, Loss: 2.8902
# Epoch 13/15, Loss: 3.0308
# Epoch 14/15, Loss: 2.9272
# Epoch 15/15, Loss: 2.6008
# Final avg reward for β = 5.199999999999999: -473.03
# Training DPO (π₂ → Expert) with β = 5.6
# Epoch 1/15, Loss: 4.7836
# Epoch 2/15, Loss: 3.7330
# Epoch 3/15, Loss: 4.3256
# Epoch 4/15, Loss: 3.5691
# Epoch 5/15, Loss: 3.9315
# Epoch 6/15, Loss: 3.4837
# Epoch 7/15, Loss: 3.4254
# Epoch 8/15, Loss: 3.2982
# Epoch 9/15, Loss: 3.3917
# Epoch 10/15, Loss: 2.9592
# Epoch 11/15, Loss: 3.0982
# Epoch 12/15, Loss: 3.0716
# Epoch 13/15, Loss: 3.0986
# Epoch 14/15, Loss: 2.8795
# Epoch 15/15, Loss: 2.4645
# Final avg reward for β = 5.6: -398.79

# %%
print(rewards_from_ref)
# Out:
# {0.0: -396.2742144569917, 0.2: -423.6825305284847, 0.4: -423.68240368491024, 0.6000000000000001: -398.18303493348697, 0.8: -414.7734927934386, 1.0: -367.01937387173894, 1.2000000000000002: -423.74162267158783, 1.4000000000000001: -387.0548382489562, 1.6: -619.5014939414675, 1.8: -373.3061290135061, 2.0: -394.1919171628642, 2.2: -387.25492693236254, 2.4000000000000004: -366.81313862548956, 2.6000000000000005: -413.79086728010435, 2.8000000000000007: -380.2514192601067, 3.000000000000001: -386.9801049834923, 3.200000000000001: -374.76489670010534, 3.4000000000000012: -387.95605736337563, 3.6000000000000014: -366.22264930040467, 3.8000000000000016: -379.50893685304857}

# %%
dpo_model_from_ref = train_dpo_from_ref(loader,pi2_model, env, beta=0.5, seed=seed)
torch.save(dpo_model_from_ref.state_dict(), f"{env_id}_dpo_pi2_seed{seed}.pth")

dpo_model = train_dpo(loader, env, seed=seed)
torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")
# Out:
# Epoch 1/25, Loss: 0.4126
# Epoch 2/25, Loss: 0.3850
# Epoch 3/25, Loss: 0.3696
# Epoch 4/25, Loss: 0.3712
# Epoch 5/25, Loss: 0.3455
# Epoch 6/25, Loss: 0.3449
# Epoch 7/25, Loss: 0.2999
# Epoch 8/25, Loss: 0.3441
# Epoch 9/25, Loss: 0.3133
# Epoch 10/25, Loss: 0.3297
# Epoch 11/25, Loss: 0.3301
# Epoch 12/25, Loss: 0.3507
# Epoch 13/25, Loss: 0.3139
# Epoch 14/25, Loss: 0.2964
# Epoch 15/25, Loss: 0.2575
# Epoch 16/25, Loss: 0.3273
# Epoch 17/25, Loss: 0.3414
# Epoch 18/25, Loss: 0.2545
# Epoch 19/25, Loss: 0.2967
# Epoch 20/25, Loss: 0.2968
# Epoch 21/25, Loss: 0.2772
# Epoch 22/25, Loss: 0.2963
# Epoch 23/25, Loss: 0.3180
# Epoch 24/25, Loss: 0.3058
# Epoch 25/25, Loss: 0.2901
# Epoch 1/25, Loss: 0.9204
# Epoch 2/25, Loss: 0.4786
# Epoch 3/25, Loss: 0.2981
# Epoch 4/25, Loss: 0.2056
# Epoch 5/25, Loss: 0.1674
# Epoch 6/25, Loss: 0.1494
# Epoch 7/25, Loss: 0.1389
# Epoch 8/25, Loss: 0.1342
# Epoch 9/25, Loss: 0.1330
# Epoch 10/25, Loss: 0.1331
# Epoch 11/25, Loss: 0.1330
# Epoch 12/25, Loss: 0.1325
# Epoch 13/25, Loss: 0.1320
# Epoch 14/25, Loss: 0.1317
# Epoch 15/25, Loss: 0.1316
# Epoch 16/25, Loss: 0.1312
# Epoch 17/25, Loss: 0.1313
# Epoch 18/25, Loss: 0.1305
# Epoch 19/25, Loss: 0.1300
# Epoch 20/25, Loss: 0.1300
# Epoch 21/25, Loss: 0.1306
# Epoch 22/25, Loss: 0.1298
# Epoch 23/25, Loss: 0.1299
# Epoch 24/25, Loss: 0.1292
# Epoch 25/25, Loss: 0.1295

# %% [markdown]
# ## 🧠 Step 8: Train RewardNet from Preferences (for PPO-RLHF)

# %%
class RewardNet(nn.Module):
    def __init__(self, obs_dim, act_dim, is_discrete=True, hidden_size=64):
        super().__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, states, actions):
        if self.is_discrete:
            one_hot = F.one_hot(actions.view(-1), num_classes=self.act_dim).float()
            x = torch.cat([states, one_hot], dim=-1)
        else:
            x = torch.cat([states, actions], dim=-1)
        return self.net(x).squeeze(-1)

def train_reward_model(dataloader, obs_dim, act_dim, is_discrete, epochs=50, lr=1e-3, device='cpu'):
    model = RewardNet(obs_dim, act_dim, is_discrete).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        total_loss = 0.0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            r1 = model(obs1.view(-1, obs_dim), acts1.view(-1) if is_discrete else acts1.view(-1, act_dim))
            r2 = model(obs2.view(-1, obs_dim), acts2.view(-1) if is_discrete else acts2.view(-1, act_dim))

            r1 = r1.view(obs1.shape[0], obs1.shape[1]) * mask1
            r2 = r2.view(obs2.shape[0], obs2.shape[1]) * mask2

            r1_sum = r1.sum(dim=1)  # [B]
            r2_sum = r2.sum(dim=1)  # [B]

            logits = r1_sum - r2_sum  # [B]
            loss = criterion(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return model

with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]

dataset = PreferenceDataset(prefs, is_discrete=is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

reward_model = train_reward_model(loader, obs_dim, act_dim, is_discrete)
torch.save(reward_model.state_dict(), f"{env_id}_reward_model_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 0.2495
# Epoch 2/50, Loss: 0.1093
# Epoch 3/50, Loss: 0.1056
# Epoch 4/50, Loss: 0.1069
# Epoch 5/50, Loss: 0.1067
# Epoch 6/50, Loss: 0.1111
# Epoch 7/50, Loss: 0.1123
# Epoch 8/50, Loss: 0.1067
# Epoch 9/50, Loss: 0.1058
# Epoch 10/50, Loss: 0.1096
# Epoch 11/50, Loss: 0.1024
# Epoch 12/50, Loss: 0.1047
# Epoch 13/50, Loss: 0.1055
# Epoch 14/50, Loss: 0.1010
# Epoch 15/50, Loss: 0.1023
# Epoch 16/50, Loss: 0.1053
# Epoch 17/50, Loss: 0.1019
# Epoch 18/50, Loss: 0.1020
# Epoch 19/50, Loss: 0.1036
# Epoch 20/50, Loss: 0.1033
# Epoch 21/50, Loss: 0.1024
# Epoch 22/50, Loss: 0.1009
# Epoch 23/50, Loss: 0.1041
# Epoch 24/50, Loss: 0.0986
# Epoch 25/50, Loss: 0.1024
# Epoch 26/50, Loss: 0.1029
# Epoch 27/50, Loss: 0.0982
# Epoch 28/50, Loss: 0.1004
# Epoch 29/50, Loss: 0.1028
# Epoch 30/50, Loss: 0.0977
# Epoch 31/50, Loss: 0.0975
# Epoch 32/50, Loss: 0.0979
# Epoch 33/50, Loss: 0.1005
# Epoch 34/50, Loss: 0.0982
# Epoch 35/50, Loss: 0.0972
# Epoch 36/50, Loss: 0.0948
# Epoch 37/50, Loss: 0.0963
# Epoch 38/50, Loss: 0.1005
# Epoch 39/50, Loss: 0.0956
# Epoch 40/50, Loss: 0.0991
# Epoch 41/50, Loss: 0.0975
# Epoch 42/50, Loss: 0.1020
# Epoch 43/50, Loss: 0.0951
# Epoch 44/50, Loss: 0.0964
# Epoch 45/50, Loss: 0.0957
# Epoch 46/50, Loss: 0.0985
# Epoch 47/50, Loss: 0.0961
# Epoch 48/50, Loss: 0.0951
# Epoch 49/50, Loss: 0.0993
# Epoch 50/50, Loss: 0.0958

# %% [markdown]
# ## 🔁 Step 9: Train PPO-RLHF (Reward Finetuned from Expert π₁)

# %%
import gymnasium as gym
from gymnasium import Wrapper

class RewardNetWrapper(Wrapper):
    def __init__(self, env, reward_net, is_discrete):
        super().__init__(env)
        self.reward_net = reward_net
        self.is_discrete = is_discrete

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)

        # Convert to tensor
        obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        if self.is_discrete:
            act_tensor = torch.tensor(action, dtype=torch.long).unsqueeze(0)
        else:
            act_tensor = torch.tensor(action, dtype=torch.float32).unsqueeze(0)

        # Predict learned reward
        with torch.no_grad():
            reward = self.reward_net(obs_tensor, act_tensor).item()

        return obs, reward, terminated, truncated, info

# Wrap the environment with the trained reward_net
reward_model.eval()  # Ensure the model is in inference mode
env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
env = Monitor(env)

# Retrain the policy using the new reward
rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
rlhf_model.learn(total_timesteps=total_timesteps)
rlhf_model.save(f"{env_id}_rlhf_seed{seed}.zip")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    fps             | 6015     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -185         |
# | time/                   |              |
# |    fps                  | 4299         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0032200254 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0438       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 0.987        |
# |    value_loss           | 175          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -181         |
# | time/                   |              |
# |    fps                  | 3951         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0018443655 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.4         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.966        |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -179         |
# | time/                   |              |
# |    fps                  | 3797         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0052950033 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.949        |
# |    value_loss           | 66.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -185       |
# | time/                   |            |
# |    fps                  | 3722       |
# |    iterations           | 5          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00454397 |
# |    clip_fraction        | 0.0168     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.548      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.3       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00169   |
# |    std                  | 0.939      |
# |    value_loss           | 60.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 3670        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002417464 |
# |    clip_fraction        | 0.00313     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000647   |
# |    std                  | 0.934       |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 3628        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003795172 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0021     |
# |    std                  | 0.903       |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 3597        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003429581 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.901       |
# |    value_loss           | 51          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 3542        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004994848 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.87        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00295    |
# |    std                  | 0.886       |
# |    value_loss           | 34.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -183       |
# | time/                   |            |
# |    fps                  | 3430       |
# |    iterations           | 10         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00371444 |
# |    clip_fraction        | 0.0185     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.48       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00114   |
# |    std                  | 0.887      |
# |    value_loss           | 18.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -180         |
# | time/                   |              |
# |    fps                  | 3417         |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0015960962 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.41         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000667    |
# |    std                  | 0.882        |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -184         |
# | time/                   |              |
# |    fps                  | 3414         |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0047660163 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.25         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 0.873        |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -184         |
# | time/                   |              |
# |    fps                  | 3412         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0047632726 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.88         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00381     |
# |    std                  | 0.864        |
# |    value_loss           | 19.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 3405        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004872376 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00441    |
# |    std                  | 0.867       |
# |    value_loss           | 8.84        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -181       |
# | time/                   |            |
# |    fps                  | 3404       |
# |    iterations           | 15         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00520434 |
# |    clip_fraction        | 0.0367     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.51       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00404   |
# |    std                  | 0.869      |
# |    value_loss           | 9.44       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -178         |
# | time/                   |              |
# |    fps                  | 3404         |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0031056008 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00357     |
# |    std                  | 0.863        |
# |    value_loss           | 5.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -176         |
# | time/                   |              |
# |    fps                  | 3397         |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0075094365 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0049      |
# |    std                  | 0.858        |
# |    value_loss           | 5.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -172         |
# | time/                   |              |
# |    fps                  | 3328         |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0038219094 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00461     |
# |    std                  | 0.852        |
# |    value_loss           | 6.05         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 3286        |
# |    iterations           | 19          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009583462 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00759    |
# |    std                  | 0.855       |
# |    value_loss           | 4.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 3245        |
# |    iterations           | 20          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008735847 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00799    |
# |    std                  | 0.861       |
# |    value_loss           | 6.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 21          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004998776 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 0.864       |
# |    value_loss           | 5.03        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 3238         |
# |    iterations           | 22           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0084545845 |
# |    clip_fraction        | 0.0798       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0056      |
# |    std                  | 0.848        |
# |    value_loss           | 5.61         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -160        |
# | time/                   |             |
# |    fps                  | 3233        |
# |    iterations           | 23          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008038994 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.841       |
# |    value_loss           | 4.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 3236         |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0067552687 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00485     |
# |    std                  | 0.823        |
# |    value_loss           | 3.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 25          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005995662 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.816       |
# |    value_loss           | 3.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 3243        |
# |    iterations           | 26          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005763825 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00509    |
# |    std                  | 0.803       |
# |    value_loss           | 4.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 3247        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004727539 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.955       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 0.793       |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 3252        |
# |    iterations           | 28          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010598192 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.78        |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 3256        |
# |    iterations           | 29          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004734779 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 0.772       |
# |    value_loss           | 3.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 3257         |
# |    iterations           | 30           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0131257195 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.762        |
# |    value_loss           | 4.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 3240        |
# |    iterations           | 31          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005294227 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00427    |
# |    std                  | 0.76        |
# |    value_loss           | 3.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -132       |
# | time/                   |            |
# |    fps                  | 3238       |
# |    iterations           | 32         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00767885 |
# |    clip_fraction        | 0.0741     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0034    |
# |    std                  | 0.744      |
# |    value_loss           | 2.28       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 3239         |
# |    iterations           | 33           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0058840015 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 0.736        |
# |    value_loss           | 3.44         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 3239        |
# |    iterations           | 34          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005673912 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00181    |
# |    std                  | 0.724       |
# |    value_loss           | 3.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 3230        |
# |    iterations           | 35          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005973591 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.722       |
# |    value_loss           | 3.04        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -124      |
# | time/                   |           |
# |    fps                  | 3229      |
# |    iterations           | 36        |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0079123 |
# |    clip_fraction        | 0.088     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.08     |
# |    explained_variance   | 0.91      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.68      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -0.0033   |
# |    std                  | 0.707     |
# |    value_loss           | 3.34      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 3229        |
# |    iterations           | 37          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011091932 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00829    |
# |    std                  | 0.718       |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -121       |
# | time/                   |            |
# |    fps                  | 3219       |
# |    iterations           | 38         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00854493 |
# |    clip_fraction        | 0.0994     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.54       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00249   |
# |    std                  | 0.711      |
# |    value_loss           | 4.17       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 3206        |
# |    iterations           | 39          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008217854 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0067     |
# |    std                  | 0.702       |
# |    value_loss           | 3.28        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 3208         |
# |    iterations           | 40           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0053841677 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00195     |
# |    std                  | 0.7          |
# |    value_loss           | 4.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 3212        |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021501128 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.686       |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 3216        |
# |    iterations           | 42          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011684433 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.686       |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 3217        |
# |    iterations           | 43          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009239292 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00708    |
# |    std                  | 0.676       |
# |    value_loss           | 3.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 3221        |
# |    iterations           | 44          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012019554 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00745    |
# |    std                  | 0.67        |
# |    value_loss           | 6.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -99.5       |
# | time/                   |             |
# |    fps                  | 3225        |
# |    iterations           | 45          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013070656 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.656       |
# |    value_loss           | 5           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -92.4        |
# | time/                   |              |
# |    fps                  | 3228         |
# |    iterations           | 46           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0081135165 |
# |    clip_fraction        | 0.0991       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00629     |
# |    std                  | 0.649        |
# |    value_loss           | 6.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -84.2       |
# | time/                   |             |
# |    fps                  | 3231        |
# |    iterations           | 47          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013732018 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.646       |
# |    value_loss           | 7.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -75.8       |
# | time/                   |             |
# |    fps                  | 3234        |
# |    iterations           | 48          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010007429 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00815    |
# |    std                  | 0.64        |
# |    value_loss           | 9           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -66.5       |
# | time/                   |             |
# |    fps                  | 3237        |
# |    iterations           | 49          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011914298 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.636       |
# |    value_loss           | 9.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -54.4       |
# | time/                   |             |
# |    fps                  | 3238        |
# |    iterations           | 50          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008338891 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00796    |
# |    std                  | 0.614       |
# |    value_loss           | 7.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -44.3       |
# | time/                   |             |
# |    fps                  | 3241        |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008896382 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.732       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00266    |
# |    std                  | 0.607       |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -36.2       |
# | time/                   |             |
# |    fps                  | 3244        |
# |    iterations           | 52          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010810093 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00633    |
# |    std                  | 0.609       |
# |    value_loss           | 6.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -27.2       |
# | time/                   |             |
# |    fps                  | 3247        |
# |    iterations           | 53          |
# ...
# |    loss                 | 0.17         |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | 0.000571     |
# |    std                  | 0.376        |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 10.9       |
# | time/                   |            |
# |    fps                  | 3296       |
# |    iterations           | 131        |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 268288     |
# | train/                  |            |
# |    approx_kl            | 0.00918004 |
# |    clip_fraction        | 0.0807     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.447     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0178     |
# |    n_updates            | 1300       |
# |    policy_gradient_loss | -0.00347   |
# |    std                  | 0.379      |
# |    value_loss           | 0.072      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 3297        |
# |    iterations           | 132         |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.006739714 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00689     |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 0.368       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 3296        |
# |    iterations           | 133         |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.015086098 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.423      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00952     |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.000329    |
# |    std                  | 0.371       |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.7        |
# | time/                   |             |
# |    fps                  | 3293        |
# |    iterations           | 134         |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.014126291 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.00157     |
# |    std                  | 0.366       |
# |    value_loss           | 0.0746      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 3290         |
# |    iterations           | 135          |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0057669105 |
# |    clip_fraction        | 0.0975       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.4         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00974     |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | 0.000302     |
# |    std                  | 0.356        |
# |    value_loss           | 0.0968       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 11.9         |
# | time/                   |              |
# |    fps                  | 3291         |
# |    iterations           | 136          |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0066283513 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0945       |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | 0.00203      |
# |    std                  | 0.354        |
# |    value_loss           | 0.316        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 3289        |
# |    iterations           | 137         |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.004849286 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0228      |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.00225     |
# |    std                  | 0.354       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 3285        |
# |    iterations           | 138         |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.010266779 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.373      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.234       |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.000669   |
# |    std                  | 0.349       |
# |    value_loss           | 0.266       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 3285        |
# |    iterations           | 139         |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.009135492 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.353      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | 0.0035      |
# |    std                  | 0.34        |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 3284        |
# |    iterations           | 140         |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.013026027 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.329      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0189      |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | 0.00211     |
# |    std                  | 0.332       |
# |    value_loss           | 0.0645      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 3284        |
# |    iterations           | 141         |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.010212739 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0395      |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | 0.0011      |
# |    std                  | 0.339       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 10.3       |
# | time/                   |            |
# |    fps                  | 3284       |
# |    iterations           | 142        |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 290816     |
# | train/                  |            |
# |    approx_kl            | 0.01503463 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.342     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0461     |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | -0.00253   |
# |    std                  | 0.342      |
# |    value_loss           | 0.0859     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10          |
# | time/                   |             |
# |    fps                  | 3284        |
# |    iterations           | 143         |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.026277345 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.353      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.2         |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00293     |
# |    std                  | 0.347       |
# |    value_loss           | 0.226       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 3284        |
# |    iterations           | 144         |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.012676531 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0341      |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 0.346       |
# |    value_loss           | 0.143       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 3285        |
# |    iterations           | 145         |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.012244836 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.346      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0327      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00242    |
# |    std                  | 0.338       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 3284        |
# |    iterations           | 146         |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.009221828 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -1.73e-05   |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 0.34        |
# |    value_loss           | 0.0432      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 3279        |
# |    iterations           | 147         |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.013318236 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0011     |
# |    std                  | 0.323       |
# |    value_loss           | 0.0393      |
# -----------------------------------------

# %% [markdown]
# ## 📊 Step 10: Compare PPO Expert vs PPO-RLHF vs DPO

# %%
def eval_policy(model, env, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0]
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns


env = gym.make(env_id)
returns_expert = eval_policy(PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env), env)
returns_rlhf   = eval_policy(PPO.load(f"{env_id}_rlhf_seed{seed}.zip", env=env), env)
dpo_model = PPO("MlpPolicy", env, verbose=0, seed=seed)
state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
dpo_model.policy.load_state_dict(state_dict)
returns_dpo    = eval_policy(dpo_model, env)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env)
returns_pi2 = eval_policy(pi2_model, env)
dpo_model_from_pi2 = PPO("MlpPolicy", env, verbose=0, seed=seed)
dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))
returns_dpo_from_pi2 = eval_policy(dpo_model_from_pi2, env)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# First subplot: Full comparison
axes[0].boxplot([returns_expert, returns_rlhf, returns_dpo, returns_pi2, returns_dpo_from_pi2],
                labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
                showmeans=True)
axes[0].set_title("Full Policy Comparison")
axes[0].set_ylabel("Episode Return")
axes[0].set_ylim([-1750, 0])
axes[0].grid(True)

# Second subplot: Only DPO, π₁, and π₂
axes[1].boxplot([returns_expert, returns_pi2,returns_rlhf, returns_dpo_from_pi2],
                labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
                showmeans=True)
axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
axes[1].set_ylim([-400, 0])
axes[1].grid(True)

plt.tight_layout()
plt.savefig(f"{env_id}_dual_benchmark_{seed}_dataset{sample_prefs}.png", dpi=300)
plt.show()
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:32: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot([returns_expert, returns_rlhf, returns_dpo, returns_pi2, returns_dpo_from_pi2],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/1006884898.py:41: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot([returns_expert, returns_pi2,returns_rlhf, returns_dpo_from_pi2],

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML, display
from stable_baselines3 import PPO
import os

# Step 1: Run a single episode and record rendered frames
def record_episode(model, env, seed, max_steps=1000):
    frames = []
    obs, _ = env.reset(seed=seed)
    for _ in range(max_steps):
        frame = env.render()
        frames.append(frame)
        action = model.predict(obs, deterministic=True)[0]
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    return frames

# Step 2: Combine multiple frame sequences into a single animation and optionally save as a GIF
def show_combined_animation(frames_list, fps=30, gif_path=None):
    min_len = min(len(f) for f in frames_list)
    fig = plt.figure(figsize=(12, 4))
    plt.axis('off')
    init_frame = np.hstack([f[0] for f in frames_list])
    im = plt.imshow(init_frame)

    def update(i):
        combined = np.hstack([f[i] for f in frames_list])
        im.set_array(combined)
        return [im]

    ani = animation.FuncAnimation(fig, update, frames=min_len, interval=1000/fps)

    if gif_path:
        ani.save(gif_path, writer='pillow', fps=fps)
        print(f"✅ GIF saved to: {os.path.abspath(gif_path)}")

    return HTML(ani.to_jshtml())

def trajectory_overlay_faded(frames, threshold=30, min_alpha=0.05, max_alpha=0.6):
    frames = [f.astype(np.float32) for f in frames]
    H, W, C = frames[0].shape

    overlay = np.ones((H, W, C), dtype=np.float32) * 255
    num_frames = len(frames)

    for idx, frame in enumerate(frames):
        diff = np.abs(frame - 255)
        mask = (diff.mean(axis=2) > threshold)

        alpha = min_alpha + (max_alpha - min_alpha) * (idx / (num_frames - 1))

        for c in range(3):
            overlay[:, :, c][mask] = (
                alpha * frame[:, :, c][mask] +
                (1 - alpha) * overlay[:, :, c][mask]
            )
    return np.clip(overlay, 0, 255).astype(np.uint8)

def show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2, titles=None):
    if titles is None:
        titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]

    fig, axes = plt.subplots(1, 5, figsize=(18, 6))
    images = [img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2]

    for ax, img, title in zip(axes, images, titles):
        ax.imshow(img)
        ax.set_title(title, fontsize=20)
        ax.axis('off')
    plt.tight_layout()
    plt.savefig(f"{env_id}_render_{seed}_dataset{sample_prefs}.png", dpi=300)
    plt.show()

# Step 4: Load models and environments
# Step 4: Load models and environments
env_expert = gym.make(env_id, render_mode="rgb_array")
env_rlhf   = gym.make(env_id, render_mode="rgb_array")
env_dpo    = gym.make(env_id, render_mode="rgb_array")
env_pi2 = gym.make(env_id, render_mode="rgb_array")
env_dpo_from_pi2 = gym.make(env_id, render_mode="rgb_array")
expert_model = PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env_expert)
rlhf_model   = PPO.load(f"{env_id}_rlhf_seed{seed}.zip", env=env_rlhf)
dpo_model.policy.load_state_dict(state_dict)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env_pi2)
dpo_from_pi2 = copy.deepcopy(pi2_model.policy)
dpo_from_pi2.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# Step 5: Collect animation frames for all three strategies
frames_expert = record_episode(expert_model, env_expert, seed=seed)
frames_rlhf   = record_episode(rlhf_model, env_rlhf, seed=seed)
frames_dpo    = record_episode(dpo_model, env_dpo, seed=seed)
frames_pi2 = record_episode(pi2_model, env_pi2, seed=seed)
frames_dpo_from_pi2 = record_episode(dpo_from_pi2, env_dpo_from_pi2, seed=seed)

# Step 6: Display the combined animation and save it as a GIF file
display(HTML("<h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2"))
display(show_combined_animation(
    [frames_expert, frames_rlhf, frames_dpo, frames_pi2, frames_dpo_from_pi2],
    gif_path=f"{env_id}_comparison_seed{seed}_dataset{sample_prefs}.gif"
))

img_expert = trajectory_overlay_faded(frames_expert, threshold=55)
img_rlhf = trajectory_overlay_faded(frames_rlhf, threshold=55)
img_dpo = trajectory_overlay_faded(frames_dpo, threshold=55)
img_pi2 = trajectory_overlay_faded(frames_pi2, threshold=55)
img_dpo_from_pi2 = trajectory_overlay_faded(frames_dpo_from_pi2, threshold=55)
show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2)
# Out:
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/4259130483.py:66: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1910/4259130483.py:66: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2
# ✅ GIF saved to: /Users/mathis/Master/RL/project/yule/EE-568-RL/Pendulum-v1_comparison_seed42_dataset10000.gif
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img27ddaa02c37d440f80fb928f0517ca34">
#   <div class="anim-controls">
#     <input id="_anim_slider27ddaa02c37d440f80fb928f0517ca34" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim27ddaa02c37d440f80fb928f0517ca34.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim27ddaa02c37d440f80fb928f0517ca34.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim27ddaa02c37d440f80fb928f0517ca34.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim27ddaa02c37d440f80fb928f0517ca34.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim27ddaa02c37d440f80fb928f0517ca34.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim27ddaa02c37d440f80fb928f0517ca34.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim27ddaa02c37d440f80fb928f0517ca34.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim27ddaa02c37d440f80fb928f0517ca34.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim27ddaa02c37d440f80fb928f0517ca34.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim27ddaa02c37d440f80fb928f0517ca34.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select27ddaa02c37d440f80fb928f0517ca34"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_27ddaa02c37d440f80fb928f0517ca34"
#              >
#       <label for="_anim_radio1_27ddaa02c37d440f80fb928f0517ca34">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_27ddaa02c37d440f80fb928f0517ca34"
#              checked>
#       <label for="_anim_radio2_27ddaa02c37d440f80fb928f0517ca34">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_27ddaa02c37d440f80fb928f0517ca34"
#              >
#       <label for="_anim_radio3_27ddaa02c37d440f80fb928f0517ca34">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img27ddaa02c37d440f80fb928f0517ca34";
#     var slider_id = "_anim_slider27ddaa02c37d440f80fb928f0517ca34";
#     var loop_select_id = "_anim_loop_select27ddaa02c37d440f80fb928f0517ca34";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAD95J
