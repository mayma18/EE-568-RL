# %% [markdown]
# # 🧠 RLHF Full Workflow (Unified Notebook)
# This notebook trains PPO Expert, generates preference data using π₁ vs π₂, trains PPO-RLHF using RewardNet, and then trains a DPO policy — all within one integrated flow. Supports both discrete and continuous environments.

# %% [markdown]
# ## 📦 Step 1: Setup and Imports

# %%
import os
import gymnasium as gym
import torch
import pickle
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.policies import ActorCriticPolicy

# %% [markdown]
# ## ⚙️ Step 2: Environment Setup

# %%
# ===== 🧩 Parameter Settings: Used to control the entire training / preference / visualization process =====

env_id = "Pendulum-v1"     # Task environment name (Options: CartPole-v1, Pendulum-v1, Acrobot-v1, MountainCar-v0, MountainCarContinuous-v0)

seed = 42                  # Random seed to ensure experiment reproducibility

total_timesteps = 300_000   # Number of training steps for Expert PPO (Recommended: 40k for CartPole, 300k for Pendulum)

num_prefs = 10_000            # Number of preference samples
sample_prefs = 2_000

# ===========================================================


set_random_seed(seed)

env = Monitor(gym.make(env_id))
is_discrete = hasattr(env.action_space, "n")
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
sample_length = 200
print(f"✅ Environment: {env_id} | Action space: {'Discrete' if is_discrete else 'Continuous'}")
# Out:
# ✅ Environment: Pendulum-v1 | Action space: Continuous

# %% [markdown]
# ## 🧠 Step 3: Train PPO Expert (π₁) and Save Checkpoints

# %%
checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(
    save_freq=total_timesteps // 10,
    save_path=checkpoint_dir,
    name_prefix="ppo"
)

expert_model = PPO("MlpPolicy", env, verbose=1, seed=seed, device="cpu")
expert_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
expert_model.save(f"{env_id}_expert_seed{seed}.zip")
env.close()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    fps             | 1882      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 1166         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036137106 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0082       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00229     |
# |    std                  | 0.988        |
# |    value_loss           | 8.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 1032         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0020699282 |
# |    clip_fraction        | 0.00454      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.972        |
# |    value_loss           | 6.99e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005652496 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0724      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.1e+03     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00448    |
# |    std                  | 0.966       |
# |    value_loss           | 7.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059981355 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.019        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.45e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00373     |
# |    std                  | 0.957        |
# |    value_loss           | 7.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035557372 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0033       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.17e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.948        |
# |    value_loss           | 9.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0026940266 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00572      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00227     |
# |    std                  | 0.931        |
# |    value_loss           | 5.96e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032982763 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00176      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.96e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00198     |
# |    std                  | 0.931        |
# |    value_loss           | 8.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023999477 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000978     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+03      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.915        |
# |    value_loss           | 8.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0015800439 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00146      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 0.932        |
# |    value_loss           | 6.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0038937037 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000788     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.46e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00267     |
# |    std                  | 0.923        |
# |    value_loss           | 6.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 12           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0044846814 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.000449     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+03      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.911        |
# |    value_loss           | 7.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 13           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0027967247 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000564     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.38e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00137     |
# |    std                  | 0.9          |
# |    value_loss           | 8.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 14           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0009454092 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000551     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000888    |
# |    std                  | 0.896        |
# |    value_loss           | 5.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 15           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0029430245 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000233     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.892        |
# |    value_loss           | 8.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0040861354 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.000373     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.36e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00352     |
# |    std                  | 0.888        |
# |    value_loss           | 7.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003455534 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.000287    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.63e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00379    |
# |    std                  | 0.889       |
# |    value_loss           | 5.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004184423 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.000198    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.871       |
# |    value_loss           | 6.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 19          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004405112 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.000244    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.863       |
# |    value_loss           | 4.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 20           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031962674 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00185     |
# |    std                  | 0.87         |
# |    value_loss           | 4.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 21           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0032078046 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 9.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.872        |
# |    value_loss           | 5.29e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.19e+03  |
# | time/                   |            |
# |    fps                  | 774        |
# |    iterations           | 22         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00425444 |
# |    clip_fraction        | 0.0261     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 6.41e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.11e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00279   |
# |    std                  | 0.881      |
# |    value_loss           | 5.42e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 23           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0040985253 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 5.63e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.896        |
# |    value_loss           | 5.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 24           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035924222 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 7.02e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+03      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.879        |
# |    value_loss           | 4.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003383427 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 5.61e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.895       |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 26           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024948479 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 4.01e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.884        |
# |    value_loss           | 3.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 27           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0028061457 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.48e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000948    |
# |    std                  | 0.877        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 28           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0028699546 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.74e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.89         |
# |    value_loss           | 3.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 29           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0008581034 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.56e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000439    |
# |    std                  | 0.893        |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 30           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0030353507 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.902        |
# |    value_loss           | 3.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 31           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0021875247 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.87e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000784    |
# |    std                  | 0.892        |
# |    value_loss           | 4.32e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 32          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003180161 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 1.82e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.882       |
# |    value_loss           | 3.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 33           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0019716776 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.51e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.902        |
# |    value_loss           | 2.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.11e+03   |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 34          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003970334 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 1.47e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 977         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000971   |
# |    std                  | 0.925       |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 35           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0029812397 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 8.82e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.91         |
# |    value_loss           | 3.09e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.1e+03   |
# | time/                   |            |
# |    fps                  | 780        |
# |    iterations           | 36         |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00416654 |
# |    clip_fraction        | 0.0341     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 9.42e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09e+03   |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00259   |
# |    std                  | 0.917      |
# |    value_loss           | 2.3e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 37          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005548319 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 7.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00328    |
# |    std                  | 0.907       |
# |    value_loss           | 2.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 38          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004473949 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 5.78e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 842         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.921       |
# |    value_loss           | 1.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 39          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004523319 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 4.71e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 917         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.92        |
# |    value_loss           | 2.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 40          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006485818 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 4.23e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00385    |
# |    std                  | 0.904       |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 41           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0041854642 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 4.59e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.891        |
# |    value_loss           | 2.57e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 42           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0024276022 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 4.11e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.885        |
# |    value_loss           | 1.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 43          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004471793 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 3.58e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 562         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.89        |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 44           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0037951546 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.56e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 803          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 0.902        |
# |    value_loss           | 2.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 45           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0032562576 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 3.04e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 649          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00238     |
# |    std                  | 0.899        |
# |    value_loss           | 1.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 46           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0034426863 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.68e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 773          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.888        |
# |    value_loss           | 1.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 47           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017433102 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.8e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 621          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -8.45e-06    |
# |    std                  | 0.886        |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 48           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0054194964 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 3.04e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 719          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00625     |
# |    std                  | 0.89         |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.05e+03   |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 49          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004001994 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.86e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 944         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.906       |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.04e+03   |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 50          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005443167 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 727         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.888       |
# |    value_loss           | 1.6e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.02e+03    |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 51           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0029791049 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 2.26e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 771          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 0.871        |
# |    value_loss           | 1.48e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.02e+03    |
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 52           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0055086697 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 2.8e-06      |
# |    learning_rate        | 0.0003       |
# ...
# |    std                  | 0.515       |
# |    value_loss           | 67.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 131          |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0025074289 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 321          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00303     |
# |    std                  | 0.516        |
# |    value_loss           | 252          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -282         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 132          |
# |    time_elapsed         | 367          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0047070296 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.1         |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00261     |
# |    std                  | 0.517        |
# |    value_loss           | 355          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -277        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 133         |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.008822044 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00275    |
# |    std                  | 0.507       |
# |    value_loss           | 100         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -278       |
# | time/                   |            |
# |    fps                  | 736        |
# |    iterations           | 134        |
# |    time_elapsed         | 372        |
# |    total_timesteps      | 274432     |
# | train/                  |            |
# |    approx_kl            | 0.00816053 |
# |    clip_fraction        | 0.0907     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.742     |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.1       |
# |    n_updates            | 1330       |
# |    policy_gradient_loss | -0.00172   |
# |    std                  | 0.511      |
# |    value_loss           | 156        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 135         |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.004444576 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.9        |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.511       |
# |    value_loss           | 218         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -278        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 136         |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.010076949 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -4.54e-06   |
# |    std                  | 0.499       |
# |    value_loss           | 50.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -284       |
# | time/                   |            |
# |    fps                  | 736        |
# |    iterations           | 137        |
# |    time_elapsed         | 381        |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.04935674 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.728     |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.6       |
# |    n_updates            | 1360       |
# |    policy_gradient_loss | 0.00674    |
# |    std                  | 0.503      |
# |    value_loss           | 26.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -315         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 138          |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0037680953 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.738       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | 0.000393     |
# |    std                  | 0.509        |
# |    value_loss           | 255          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -334         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 139          |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0026650564 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.511        |
# |    value_loss           | 606          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -344         |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 140          |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0074109035 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 0.519        |
# |    value_loss           | 404          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -336         |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 141          |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0047851102 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 448          |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00374     |
# |    std                  | 0.513        |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 142          |
# |    time_elapsed         | 395          |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0106419055 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.8         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.0009      |
# |    std                  | 0.507        |
# |    value_loss           | 193          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 143          |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0020621265 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.739       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.507        |
# |    value_loss           | 381          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 144         |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.002964203 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 174         |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00444    |
# |    std                  | 0.507       |
# |    value_loss           | 541         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -352         |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 145          |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0041686418 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.734       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 149          |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00254     |
# |    std                  | 0.501        |
# |    value_loss           | 379          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -344       |
# | time/                   |            |
# |    fps                  | 737        |
# |    iterations           | 146        |
# |    time_elapsed         | 405        |
# |    total_timesteps      | 299008     |
# | train/                  |            |
# |    approx_kl            | 0.02953802 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.721     |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22       |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | 0.00548    |
# |    std                  | 0.495      |
# |    value_loss           | 45.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 147         |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.010104677 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.00216    |
# |    std                  | 0.483       |
# |    value_loss           | 54.7        |
# -----------------------------------------

# %% [markdown]
# ## 🧪 Step 4: Select π₂ (Half-Performance PPO Checkpoint)

# %%
def evaluate_policy(model, env, episodes=10):
    scores = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        done = False
        total = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        scores.append(total)
    return np.mean(scores)

checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)
env = gym.make(env_id)
checkpoints = sorted([f for f in os.listdir(checkpoint_dir) if f.endswith(".zip")])
rewards = [(f, evaluate_policy(PPO.load(os.path.join(checkpoint_dir, f), env=env, device="cpu"), env)) for f in checkpoints]
best_reward = max(rewards, key=lambda x: x[1])[1]
target = best_reward * 1.5
rewards.sort(key=lambda x: abs(x[1]/target - 1.0))
pi2_model = PPO.load(os.path.join(checkpoint_dir, rewards[0][0]), env=env, device="cpu")
pi2_model.save(f"{env_id}_pi2_model_seed{seed}.zip")
print(f"✅ Selected π₂: {rewards[0][0]} with ~{rewards[0][1]:.1f} reward")
best_model_path, best_reward = max(rewards, key=lambda x: x[1])
expert_model = PPO.load(os.path.join(checkpoint_dir, best_model_path), env=env, device="cpu")
expert_model_path = f"{env_id}_expert_seed{seed}.zip"
expert_model.save(expert_model_path)

print(f"✅ Expert model selected: '{best_model_path}' with mean reward ≈ {best_reward:.2f}")
print(f"📦 Saved to: {expert_model_path}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Selected π₂: ppo_210000_steps.zip with ~-332.7 reward
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Expert model selected: 'ppo_300000_steps.zip' with mean reward ≈ -220.63
# 📦 Saved to: Pendulum-v1_expert_seed42.zip

# %% [markdown]
# ## ❤️ Step 5: Generate Preferences (π₁ vs π₂)

# %%
import numpy as np
import pickle
from tqdm import trange
import numpy as np

def generate_trajectory(model, env, seed, max_steps):
    obs_list, act_list, rewards, mask = [], [], [], []
    obs, _ = env.reset(seed=seed)

    for step in range(max_steps):
        action, _ = model.predict(obs)
        obs_, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        obs_list.append(np.array(obs))       # ensure obs is np.array
        act_list.append(np.array(action))    # ensure action is np.array
        rewards.append(reward)
        mask.append(1)

        obs = obs_
        if done:
            break

    pad_len = max_steps - len(obs_list)
    if pad_len > 0:
        obs_shape = obs_list[0].shape
        obs_list += [np.zeros(obs_shape)] * pad_len
        act_shape = act_list[0].shape if isinstance(act_list[0], np.ndarray) else ()
        act_list += [np.zeros(act_shape)] * pad_len
        rewards += [0.0] * pad_len
        mask += [0] * pad_len

    return {
        "obs": np.stack(obs_list),       # [T, obs_dim]
        "acts": np.stack(act_list),      # [T] (discrete) or [T, act_dim] (continuous)
        "rews": np.array(rewards),       # [T]
        "mask": np.array(mask)           # [T]
    }

def compute_return(traj):
    return sum(traj["rews"])

def soft_preference_prob(R1, R2):
    max_r = max(R1, R2)
    return np.exp(R1 - max_r) / (np.exp(R1 - max_r) + np.exp(R2 - max_r))

# Sample preference data
prefs = []
env = gym.make(env_id)
for idx in trange(num_prefs, desc="🔄 Generating preference pairs"):
    traj1 = generate_trajectory(model = expert_model, env=env, seed=idx, max_steps=sample_length)
    traj2 = generate_trajectory(pi2_model, env=env, seed=idx, max_steps=sample_length)
    R1, R2 = compute_return(traj1), compute_return(traj2)
    p = soft_preference_prob(R1, R2)
    label = int(np.random.rand() < p)
    prefs.append((traj1, traj2, label))

# save .pkl
filename = f"prefs_{env_id}_seed{seed}.pkl"
with open(filename, "wb") as f:
    pickle.dump(prefs, f)

print(f"✅ Saved {len(prefs)} preference pairs to {filename}")
# Out:
# 🔄 Generating preference pairs: 100%|██████████| 10000/10000 [25:27<00:00,  6.55it/s]
# ✅ Saved 10000 preference pairs to prefs_Pendulum-v1_seed42.pkl

# %%
class PreferenceDataset(torch.utils.data.Dataset):
    def __init__(self, prefs, is_discrete):
        self.prefs = prefs
        self.is_discrete = is_discrete

    def __len__(self):
        return len(self.prefs)

    def __getitem__(self, idx):
        traj1, traj2, label = self.prefs[idx]

        return {
            "obs1": torch.from_numpy(traj1["obs"]).float(),
            "acts1": torch.from_numpy(traj1["acts"]).long() if self.is_discrete else torch.from_numpy(traj1["acts"]).float(),
            "mask1": torch.from_numpy(traj1["mask"]).float(),

            "obs2": torch.from_numpy(traj2["obs"]).float(),
            "acts2": torch.from_numpy(traj2["acts"]).long() if self.is_discrete else torch.from_numpy(traj2["acts"]).float(),
            "mask2": torch.from_numpy(traj2["mask"]).float(),

            "label": torch.tensor(label, dtype=torch.float32)
        }

# %% [markdown]
# ## ⚙️ Step 7: Train DPO Policy

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO

def train_dpo(dataloader, env, seed=0, epochs=50, device='cuda'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    
    model = PPO("MlpPolicy", env, verbose=0, seed=seed, device="cuda")
    policy = model.policy
    policy.train()  # ensure in training mode
    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]

            obs1_flat = obs1.view(-1, obs_dim)
            obs2_flat = obs2.view(-1, obs_dim)
            acts1_flat = acts1.view(-1) if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1) if is_discrete else acts2.view(-1, act_dim)

            dist1 = policy.get_distribution(obs1_flat)  # returns Categorical
            dist2 = policy.get_distribution(obs2_flat)
            lp1 = dist1.log_prob(acts1_flat).view(B, T)  # [B, T]
            lp2 = dist2.log_prob(acts2_flat).view(B, T)
            
            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits = logp1_sum - logp2_sum        # [B]

            loss = F.binary_cross_entropy_with_logits(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

#with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
#    prefs = pickle.load(f)
#prefs = prefs[:sample_prefs]

#dataset = PreferenceDataset(prefs, is_discrete)
#loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

#dpo_model = train_dpo(loader, env)
#torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO
import copy

def train_dpo_from_ref(dataloader,ref_policy_sb3, env, beta= 0.05,  seed=42, epochs=50, device='cuda'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]


    ref_policy = ref_policy_sb3.policy  # frozen
    policy = copy.deepcopy(ref_policy)  # trainable

    policy.to(device)
    ref_policy.to(device)
    ref_policy.eval()  # ensure frozen

    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        policy.train()  # ensure in training mode
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]
            obs1_flat = obs1.view(-1, obs_dim) # [B*T, obs_dim]
            obs2_flat = obs2.view(-1, obs_dim) # [B*T, obs_dim]
            acts1_flat = acts1.view(-1).long() if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1).long() if is_discrete else acts2.view(-1, act_dim)

            # --- Compute log probs from trainable policy ---

            dist1 = policy.get_distribution(obs1_flat)
            dist2 = policy.get_distribution(obs2_flat)

            logp1 = dist1.log_prob(acts1_flat)
            logp2 = dist2.log_prob(acts2_flat)



            #logp1 = torch.log_softmax(policy(obs1_flat), dim=-1)
            #logp2 = torch.log_softmax(policy(obs2_flat), dim=-1)

            # --- Compute log probs from reference policy (frozen) ---
            with torch.no_grad():
                dist1_ref = ref_policy.get_distribution(obs1_flat)
                dist2_ref = ref_policy.get_distribution(obs2_flat)

                logp1_ref = dist1_ref.log_prob(acts1_flat)
                logp2_ref = dist2_ref.log_prob(acts2_flat)

                #logp1_ref = torch.log_softmax(ref_policy(obs1_flat), dim=-1)
                #logp2_ref = torch.log_softmax(ref_policy(obs2_flat), dim=-1)


            lp1 = (logp1 - logp1_ref).view(B, -1)  # shape [B, T]
            lp2 = (logp2 - logp2_ref).view(B, -1)


            #lp1 = logp1[torch.arange(len(acts1_flat)), acts1_flat].view(B, -1)
            #lp2 = logp2[torch.arange(len(acts2_flat)), acts2_flat].view(B, -1)

            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits =beta*(logp1_sum - logp2_sum)        # [B]
            loss = F.binary_cross_entropy_with_logits(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

# %%
with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]
dataset = PreferenceDataset(prefs, is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)
dpo_model_from_ref = train_dpo_from_ref(loader,pi2_model, env, beta=0.5, seed=seed)
torch.save(dpo_model_from_ref.state_dict(), f"{env_id}_dpo_pi2_seed{seed}.pth")

dpo_model = train_dpo(loader, env, seed=seed)
torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 0.5138
# Epoch 2/50, Loss: 0.4346
# Epoch 3/50, Loss: 0.6141
# Epoch 4/50, Loss: 0.4097
# Epoch 5/50, Loss: 0.6640
# Epoch 6/50, Loss: 0.6304
# Epoch 7/50, Loss: 0.4483
# Epoch 8/50, Loss: 0.3919
# Epoch 9/50, Loss: 0.4160
# Epoch 10/50, Loss: 0.4764
# Epoch 11/50, Loss: 0.4669
# Epoch 12/50, Loss: 0.4008
# Epoch 13/50, Loss: 0.4769
# Epoch 14/50, Loss: 0.3942
# Epoch 15/50, Loss: 0.4314
# Epoch 16/50, Loss: 0.4754
# Epoch 17/50, Loss: 0.4064
# Epoch 18/50, Loss: 0.3433
# Epoch 19/50, Loss: 0.4188
# Epoch 20/50, Loss: 0.5956
# Epoch 21/50, Loss: 0.6561
# Epoch 22/50, Loss: 0.3641
# Epoch 23/50, Loss: 0.5747
# Epoch 24/50, Loss: 0.3914
# Epoch 25/50, Loss: 0.4590
# Epoch 26/50, Loss: 0.3914
# Epoch 27/50, Loss: 0.4465
# Epoch 28/50, Loss: 0.3251
# Epoch 29/50, Loss: 0.3361
# Epoch 30/50, Loss: 0.3509
# Epoch 31/50, Loss: 0.4715
# Epoch 32/50, Loss: 0.4008
# Epoch 33/50, Loss: 0.3907
# Epoch 34/50, Loss: 0.4122
# Epoch 35/50, Loss: 0.4182
# Epoch 36/50, Loss: 0.3593
# Epoch 37/50, Loss: 0.3923
# Epoch 38/50, Loss: 0.3568
# Epoch 39/50, Loss: 0.4394
# Epoch 40/50, Loss: 0.3668
# Epoch 41/50, Loss: 0.3177
# Epoch 42/50, Loss: 0.4334
# Epoch 43/50, Loss: 0.3626
# Epoch 44/50, Loss: 0.3828
# Epoch 45/50, Loss: 0.4507
# Epoch 46/50, Loss: 0.3555
# Epoch 47/50, Loss: 0.3815
# Epoch 48/50, Loss: 0.2988
# Epoch 49/50, Loss: 0.5367
# Epoch 50/50, Loss: 0.3852
# c:\Users\MATH-286-Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Epoch 1/50, Loss: 1.2435
# Epoch 2/50, Loss: 0.9853
# Epoch 3/50, Loss: 0.8468
# Epoch 4/50, Loss: 0.7525
# Epoch 5/50, Loss: 0.6574
# Epoch 6/50, Loss: 0.5872
# Epoch 7/50, Loss: 0.5311
# Epoch 8/50, Loss: 0.4840
# Epoch 9/50, Loss: 0.4460
# Epoch 10/50, Loss: 0.4129
# Epoch 11/50, Loss: 0.3890
# Epoch 12/50, Loss: 0.3674
# Epoch 13/50, Loss: 0.3512
# Epoch 14/50, Loss: 0.3319
# Epoch 15/50, Loss: 0.3190
# Epoch 16/50, Loss: 0.3073
# Epoch 17/50, Loss: 0.2986
# Epoch 18/50, Loss: 0.2917
# Epoch 19/50, Loss: 0.2820
# Epoch 20/50, Loss: 0.2774
# Epoch 21/50, Loss: 0.2717
# Epoch 22/50, Loss: 0.2663
# Epoch 23/50, Loss: 0.2619
# Epoch 24/50, Loss: 0.2594
# Epoch 25/50, Loss: 0.2588
# Epoch 26/50, Loss: 0.2538
# Epoch 27/50, Loss: 0.2517
# Epoch 28/50, Loss: 0.2496
# Epoch 29/50, Loss: 0.2483
# Epoch 30/50, Loss: 0.2440
# Epoch 31/50, Loss: 0.2458
# Epoch 32/50, Loss: 0.2418
# Epoch 33/50, Loss: 0.2413
# Epoch 34/50, Loss: 0.2396
# Epoch 35/50, Loss: 0.2382
# Epoch 36/50, Loss: 0.2382
# Epoch 37/50, Loss: 0.2358
# Epoch 38/50, Loss: 0.2340
# Epoch 39/50, Loss: 0.2337
# Epoch 40/50, Loss: 0.2336
# Epoch 41/50, Loss: 0.2313
# Epoch 42/50, Loss: 0.2330
# Epoch 43/50, Loss: 0.2316
# Epoch 44/50, Loss: 0.2308
# Epoch 45/50, Loss: 0.2295
# Epoch 46/50, Loss: 0.2309
# Epoch 47/50, Loss: 0.2295
# Epoch 48/50, Loss: 0.2281
# Epoch 49/50, Loss: 0.2289
# Epoch 50/50, Loss: 0.2289

# %% [markdown]
# ## 🧠 Step 8: Train RewardNet from Preferences (for PPO-RLHF)

# %%
class RewardNet(nn.Module):
    def __init__(self, obs_dim, act_dim, is_discrete=True, hidden_size=64):
        super().__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, states, actions):
        if self.is_discrete:
            one_hot = F.one_hot(actions.view(-1), num_classes=self.act_dim).float()
            x = torch.cat([states, one_hot], dim=-1)
        else:
            x = torch.cat([states, actions], dim=-1)
        return self.net(x).squeeze(-1)

def train_reward_model(dataloader, obs_dim, act_dim, is_discrete, epochs=50, lr=1e-3, device='cuda'):
    model = RewardNet(obs_dim, act_dim, is_discrete).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        total_loss = 0.0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            r1 = model(obs1.view(-1, obs_dim), acts1.view(-1) if is_discrete else acts1.view(-1, act_dim))
            r2 = model(obs2.view(-1, obs_dim), acts2.view(-1) if is_discrete else acts2.view(-1, act_dim))

            r1 = r1.view(obs1.shape[0], obs1.shape[1]) * mask1
            r2 = r2.view(obs2.shape[0], obs2.shape[1]) * mask2

            r1_sum = r1.sum(dim=1)  # [B]
            r2_sum = r2.sum(dim=1)  # [B]

            logits = r1_sum - r2_sum  # [B]
            loss = criterion(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return model

with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]

dataset = PreferenceDataset(prefs, is_discrete=is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

reward_model = train_reward_model(loader, obs_dim, act_dim, is_discrete)
torch.save(reward_model.state_dict(), f"{env_id}_reward_model_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 0.3903
# Epoch 2/50, Loss: 0.2354
# Epoch 3/50, Loss: 0.2233
# Epoch 4/50, Loss: 0.2174
# Epoch 5/50, Loss: 0.2152
# Epoch 6/50, Loss: 0.2076
# Epoch 7/50, Loss: 0.2093
# Epoch 8/50, Loss: 0.2056
# Epoch 9/50, Loss: 0.2077
# Epoch 10/50, Loss: 0.2030
# Epoch 11/50, Loss: 0.2065
# Epoch 12/50, Loss: 0.2032
# Epoch 13/50, Loss: 0.2062
# Epoch 14/50, Loss: 0.2003
# Epoch 15/50, Loss: 0.2012
# Epoch 16/50, Loss: 0.2003
# Epoch 17/50, Loss: 0.1995
# Epoch 18/50, Loss: 0.1986
# Epoch 19/50, Loss: 0.2069
# Epoch 20/50, Loss: 0.1998
# Epoch 21/50, Loss: 0.1970
# Epoch 22/50, Loss: 0.2009
# Epoch 23/50, Loss: 0.2036
# Epoch 24/50, Loss: 0.1972
# Epoch 25/50, Loss: 0.1983
# Epoch 26/50, Loss: 0.2015
# Epoch 27/50, Loss: 0.1950
# Epoch 28/50, Loss: 0.2109
# Epoch 29/50, Loss: 0.1997
# Epoch 30/50, Loss: 0.1977
# Epoch 31/50, Loss: 0.1991
# Epoch 32/50, Loss: 0.1968
# Epoch 33/50, Loss: 0.1982
# Epoch 34/50, Loss: 0.1959
# Epoch 35/50, Loss: 0.1938
# Epoch 36/50, Loss: 0.2001
# Epoch 37/50, Loss: 0.1944
# Epoch 38/50, Loss: 0.1979
# Epoch 39/50, Loss: 0.1953
# Epoch 40/50, Loss: 0.1953
# Epoch 41/50, Loss: 0.1947
# Epoch 42/50, Loss: 0.1942
# Epoch 43/50, Loss: 0.2050
# Epoch 44/50, Loss: 0.1949
# Epoch 45/50, Loss: 0.1969
# Epoch 46/50, Loss: 0.2016
# Epoch 47/50, Loss: 0.1934
# Epoch 48/50, Loss: 0.1945
# Epoch 49/50, Loss: 0.1976
# Epoch 50/50, Loss: 0.1916

# %% [markdown]
# ## 🔁 Step 9: Train PPO-RLHF (Reward Finetuned from Expert π₁)

# %%
# import gymnasium as gym
# from gymnasium import Wrapper

# class RewardNetWrapper(Wrapper):
#     def __init__(self, env, reward_net, is_discrete):
#         super().__init__(env)
#         self.reward_net = reward_net
#         self.is_discrete = is_discrete

#     def step(self, action):
#         obs, reward, terminated, truncated, info = self.env.step(action)

#         # Convert to tensor
#         obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
#         if self.is_discrete:
#             act_tensor = torch.tensor(action, dtype=torch.long).unsqueeze(0)
#         else:
#             act_tensor = torch.tensor(action, dtype=torch.float32).unsqueeze(0)

#         # Predict learned reward
#         with torch.no_grad():
#             reward = self.reward_net(obs_tensor, act_tensor).item()

#         return obs, reward, terminated, truncated, info

# # Wrap the environment with the trained reward_net
# reward_model.eval()  # Ensure the model is in inference mode
# env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
# env = Monitor(env)

# # Retrain the policy using the new reward
# rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
# rlhf_model.learn(total_timesteps=total_timesteps)
# rlhf_model.save(f"{env_id}_rlhf_seed{seed}.zip")


import gymnasium as gym
from gymnasium import Wrapper

class RewardNetWrapper(Wrapper):
    def __init__(self, env, reward_net, is_discrete):
        super().__init__(env)
        self.reward_net = reward_net
        self.is_discrete = is_discrete

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)

        # Convert to tensor and move to reward_net's device
        device = next(self.reward_net.parameters()).device
        obs_tensor = torch.tensor(obs, dtype=torch.float32, device=device).unsqueeze(0)
        if self.is_discrete:
            act_tensor = torch.tensor(action, dtype=torch.long, device=device).unsqueeze(0)
        else:
            act_tensor = torch.tensor(action, dtype=torch.float32, device=device).unsqueeze(0)

        # Predict learned reward
        with torch.no_grad():
            reward = self.reward_net(obs_tensor, act_tensor).item()

        return obs, reward, terminated, truncated, info

# Wrap the environment with the trained reward_net
reward_model.eval()  # Ensure the model is in inference mode
env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
env = Monitor(env)

# Retrain the policy using the new reward
path_model_pi_2 = f"{env_id}_pi2_model_seed{seed}.zip"
print(path_model_pi_2)

# rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed, device="cpu")
rlhf_model = PPO.load(path   = path_model_pi_2, 
                      env    = env, 
                      seed   = seed, 
                      device = "cpu",
                      kl_coeff = 0.5,
                      target_kl= 0.01)  # KL penalty coefficient 0.01

# rlhf_model.learn(total_timesteps=total_timesteps)
# rlhf_model.learn(total_timesteps=total_timesteps // 2) #FF0000
# rlhf_model.learn(total_timesteps=60000) #FF0000
rlhf_model.learn(total_timesteps=200000) #FF0000
rlhf_model.save(f"{env_id}_rlhf_pi2_seed{seed}.zip")
# Out:
# Pendulum-v1_pi2_model_seed42.zip
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    fps             | 861      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 16.3         |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054267375 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 117          |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -9.39e-05    |
# |    std                  | 0.594        |
# |    value_loss           | 484          |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0047328225 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.1         |
# |    n_updates            | 1033         |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.596        |
# |    value_loss           | 456          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009074017 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.8        |
# |    n_updates            | 1035        |
# |    policy_gradient_loss | 0.000876    |
# |    std                  | 0.597       |
# |    value_loss           | 184         |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | 18.1      |
# | time/                   |           |
# |    fps                  | 694       |
# |    iterations           | 5         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0085159 |
# |    clip_fraction        | 0.0706    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.9      |
# |    explained_variance   | 0.679     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 28        |
# |    n_updates            | 1040      |
# |    policy_gradient_loss | -0.000318 |
# |    std                  | 0.592     |
# |    value_loss           | 168       |
# ---------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 19.9       |
# | time/                   |            |
# |    fps                  | 687        |
# |    iterations           | 6          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00573444 |
# |    clip_fraction        | 0.0372     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.895     |
# |    explained_variance   | 0.703      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.1       |
# |    n_updates            | 1044       |
# |    policy_gradient_loss | 0.00129    |
# |    std                  | 0.591      |
# |    value_loss           | 217        |
# ----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0049793455 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.97         |
# |    n_updates            | 1047         |
# |    policy_gradient_loss | 0.000472     |
# |    std                  | 0.589        |
# |    value_loss           | 93.9         |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006517229 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 1053        |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.579       |
# |    value_loss           | 92.2        |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 9           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014119895 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 1057        |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.573       |
# |    value_loss           | 48.7        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 690          |
# |    iterations           | 10           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0055008186 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 1059         |
# |    policy_gradient_loss | 0.0021       |
# |    std                  | 0.575        |
# |    value_loss           | 37.5         |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 11          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005109211 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 1063        |
# |    policy_gradient_loss | 0.000788    |
# |    std                  | 0.572       |
# |    value_loss           | 48.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 12           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0054192063 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.859       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 1064         |
# |    policy_gradient_loss | 0.000227     |
# |    std                  | 0.571        |
# |    value_loss           | 35.2         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 8.13        |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005048902 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11        |
# |    n_updates            | 1065        |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.57        |
# |    value_loss           | 34.4        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 8.06         |
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 14           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0053912415 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 1066         |
# |    policy_gradient_loss | 0.00117      |
# |    std                  | 0.57         |
# |    value_loss           | 40.5         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 6.05        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 15          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005863722 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43        |
# |    n_updates            | 1067        |
# |    policy_gradient_loss | 7.61e-05    |
# |    std                  | 0.57        |
# |    value_loss           | 20.9        |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 7.5          |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 16           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0046658795 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.9         |
# |    n_updates            | 1071         |
# |    policy_gradient_loss | 0.00283      |
# |    std                  | 0.569        |
# |    value_loss           | 25.2         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 4.83         |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 17           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0072382432 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22         |
# |    n_updates            | 1073         |
# |    policy_gradient_loss | 0.00711      |
# |    std                  | 0.567        |
# |    value_loss           | 18.5         |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 6.14        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 18          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015403101 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.84        |
# |    n_updates            | 1077        |
# |    policy_gradient_loss | 0.00322     |
# |    std                  | 0.567       |
# |    value_loss           | 17          |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 6.97        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007088738 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.35        |
# |    n_updates            | 1078        |
# |    policy_gradient_loss | 0.00174     |
# |    std                  | 0.565       |
# |    value_loss           | 14          |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 7.17        |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014610201 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.33        |
# |    n_updates            | 1081        |
# |    policy_gradient_loss | 0.00127     |
# |    std                  | 0.564       |
# |    value_loss           | 20          |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 3.92         |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 21           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0052409032 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.32         |
# |    n_updates            | 1083         |
# |    policy_gradient_loss | 0.00114      |
# |    std                  | 0.562        |
# |    value_loss           | 19.8         |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 2.73        |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 22          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011228438 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.93        |
# |    n_updates            | 1087        |
# |    policy_gradient_loss | -0.00279    |
# |    std                  | 0.565       |
# |    value_loss           | 19.7        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 3.22        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 23          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006316189 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.24        |
# |    n_updates            | 1088        |
# |    policy_gradient_loss | 0.00288     |
# |    std                  | 0.563       |
# |    value_loss           | 8.7         |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 5.49        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 24          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003722941 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 1089        |
# |    policy_gradient_loss | 0.000972    |
# |    std                  | 0.562       |
# |    value_loss           | 19.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 7.71        |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 25          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004344512 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | 0.00113     |
# |    std                  | 0.561       |
# |    value_loss           | 24          |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.04
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 3.53         |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 26           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0150106875 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.96         |
# |    n_updates            | 1094         |
# |    policy_gradient_loss | 0.00277      |
# |    std                  | 0.56         |
# |    value_loss           | 9.14         |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 6.11         |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 27           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0067008836 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19         |
# |    n_updates            | 1097         |
# |    policy_gradient_loss | 0.00028      |
# |    std                  | 0.56         |
# |    value_loss           | 11.9         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.03
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 6.47         |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 28           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0060052304 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.48         |
# |    n_updates            | 1098         |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.559        |
# |    value_loss           | 16.9         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 5.81        |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 29          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005853946 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62        |
# |    n_updates            | 1099        |
# |    policy_gradient_loss | 0.00406     |
# |    std                  | 0.558       |
# |    value_loss           | 8.66        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 8.6         |
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006373173 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00257    |
# |    std                  | 0.558       |
# |    value_loss           | 12.3        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 9.76       |
# | time/                   |            |
# |    fps                  | 719        |
# |    iterations           | 31         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00259593 |
# |    clip_fraction        | 0.026      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.836     |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.43       |
# |    n_updates            | 1102       |
# |    policy_gradient_loss | -3.55e-05  |
# |    std                  | 0.559      |
# |    value_loss           | 10.8       |
# ----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004958767 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2         |
# |    n_updates            | 1103        |
# |    policy_gradient_loss | 0.00552     |
# |    std                  | 0.559       |
# |    value_loss           | 12.6        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 33          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006744598 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 1104        |
# |    policy_gradient_loss | -0.00043    |
# |    std                  | 0.56        |
# |    value_loss           | 27.2        |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.28       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 34          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004660987 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 1107        |
# |    policy_gradient_loss | -0.000799   |
# |    std                  | 0.562       |
# |    value_loss           | 53.7        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -3.14        |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 35           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0043701413 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.9         |
# |    n_updates            | 1109         |
# |    policy_gradient_loss | 0.00172      |
# |    std                  | 0.562        |
# |    value_loss           | 103          |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 0.603       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 36          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002829645 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 1112        |
# |    policy_gradient_loss | 0.00243     |
# |    std                  | 0.563       |
# |    value_loss           | 46.3        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 0.735        |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 37           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0075399266 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.9         |
# |    n_updates            | 1113         |
# |    policy_gradient_loss | -0.00216     |
# |    std                  | 0.563        |
# |    value_loss           | 39.9         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.06       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 38          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003554672 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.94        |
# |    n_updates            | 1114        |
# |    policy_gradient_loss | -0.00467    |
# |    std                  | 0.563       |
# |    value_loss           | 30.8        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.58       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 39          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011327905 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82        |
# |    n_updates            | 1116        |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.564       |
# |    value_loss           | 18.1        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -3.64        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 40           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0031815176 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.33         |
# |    n_updates            | 1117         |
# |    policy_gradient_loss | 0.00159      |
# |    std                  | 0.564        |
# |    value_loss           | 20.6         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -0.646       |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 41           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0065702223 |
# |    clip_fraction        | 0.0825       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.845       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.9          |
# |    n_updates            | 1118         |
# |    policy_gradient_loss | -0.000854    |
# |    std                  | 0.563        |
# |    value_loss           | 11.6         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 2.14        |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 42          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003841639 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 1119        |
# |    policy_gradient_loss | 0.00252     |
# |    std                  | 0.562       |
# |    value_loss           | 10.8        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 3.57        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 43          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010358182 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.27        |
# |    n_updates            | 1121        |
# |    policy_gradient_loss | 8.47e-05    |
# |    std                  | 0.562       |
# |    value_loss           | 11.7        |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 44          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004373463 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 1124        |
# |    policy_gradient_loss | 0.00206     |
# |    std                  | 0.563       |
# |    value_loss           | 36.9        |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 45          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010854685 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11        |
# |    n_updates            | 1127        |
# |    policy_gradient_loss | -0.000125   |
# |    std                  | 0.557       |
# |    value_loss           | 5.93        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 46           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0063326596 |
# |    clip_fraction        | 0.0911       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25         |
# |    n_updates            | 1128         |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 0.557        |
# |    value_loss           | 16.9         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 12           |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 47           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0092912875 |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.41         |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.000332    |
# |    std                  | 0.559        |
# |    value_loss           | 16.6         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 48           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0057800114 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79         |
# |    n_updates            | 1132         |
# |    policy_gradient_loss | -0.000866    |
# |    std                  | 0.558        |
# |    value_loss           | 5.14         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 49          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009004421 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95        |
# |    n_updates            | 1133        |
# |    policy_gradient_loss | -0.000752   |
# |    std                  | 0.557       |
# |    value_loss           | 12.9        |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 17.6       |
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 50         |
# ...
# |    std                  | 0.558        |
# |    value_loss           | 4.44         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 83           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0054604034 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.11         |
# |    n_updates            | 1188         |
# |    policy_gradient_loss | -0.00236     |
# |    std                  | 0.558        |
# |    value_loss           | 7.64         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 84          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.018652944 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.61        |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.00281     |
# |    std                  | 0.557       |
# |    value_loss           | 4.81        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 85          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006406978 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.24        |
# |    n_updates            | 1191        |
# |    policy_gradient_loss | -0.000379   |
# |    std                  | 0.556       |
# |    value_loss           | 7.21        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 24.2        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 86          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.003373277 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.75        |
# |    n_updates            | 1192        |
# |    policy_gradient_loss | -0.002      |
# |    std                  | 0.555       |
# |    value_loss           | 20.8        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 26.7        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 87          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.005201338 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 1193        |
# |    policy_gradient_loss | 0.00274     |
# |    std                  | 0.555       |
# |    value_loss           | 8.85        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 28.7        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 88          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008080155 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42        |
# |    n_updates            | 1194        |
# |    policy_gradient_loss | -0.00453    |
# |    std                  | 0.555       |
# |    value_loss           | 6.34        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 29.6         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 89           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0074562184 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.15         |
# |    n_updates            | 1195         |
# |    policy_gradient_loss | 0.00345      |
# |    std                  | 0.555        |
# |    value_loss           | 9.48         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 29.4         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 90           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0052684676 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18         |
# |    n_updates            | 1196         |
# |    policy_gradient_loss | 0.00914      |
# |    std                  | 0.554        |
# |    value_loss           | 8.31         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 31           |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 91           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0078001916 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 1197         |
# |    policy_gradient_loss | -0.0006      |
# |    std                  | 0.554        |
# |    value_loss           | 4.18         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 31.4         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 92           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0056023453 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 1198         |
# |    policy_gradient_loss | 0.00242      |
# |    std                  | 0.554        |
# |    value_loss           | 5.13         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 31.7        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 93          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.007095683 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 1199        |
# |    policy_gradient_loss | -0.00103    |
# |    std                  | 0.554       |
# |    value_loss           | 2.74        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 32.5         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 94           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0054891813 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53         |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.554        |
# |    value_loss           | 6.32         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 95          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008050415 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 1201        |
# |    policy_gradient_loss | -0.00827    |
# |    std                  | 0.555       |
# |    value_loss           | 3.06        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 29.4         |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 96           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0069649275 |
# |    clip_fraction        | 0.082        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16           |
# |    n_updates            | 1202         |
# |    policy_gradient_loss | 0.00239      |
# |    std                  | 0.556        |
# |    value_loss           | 23           |
# ------------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 22.4        |
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 97          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.013331011 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 1207        |
# |    policy_gradient_loss | -0.000539   |
# |    std                  | 0.557       |
# |    value_loss           | 24.4        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 15.6        |
# | time/                   |             |
# |    fps                  | 756         |
# |    iterations           | 98          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.014295928 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 1209        |
# |    policy_gradient_loss | 0.00117     |
# |    std                  | 0.558       |
# |    value_loss           | 62.7        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02

# %% [markdown]
# ## 📊 Step 10: Compare PPO Expert vs PPO-RLHF vs DPO

# %%
def eval_policy(model, env, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0]
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns


env = gym.make(env_id)
returns_pi1 = eval_policy(PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env, device="cpu"), env)
returns_pi2_rlhf   = eval_policy(PPO.load(f"{env_id}_rlhf_pi2_seed{seed}.zip", env=env, device="cpu"), env)
state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env, device="cpu")
returns_pi2 = eval_policy(pi2_model, env)
dpo_model_from_pi2 = PPO("MlpPolicy", env, verbose=0, seed=seed, device="cpu")
dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))
returns_dpo_from_pi2 = eval_policy(dpo_model_from_pi2, env)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# First subplot: Full comparison
axes[0].boxplot([returns_pi1, returns_pi2_rlhf, returns_pi2, returns_dpo_from_pi2],
                tick_labels=["Expert ($\pi_1$)", 
                        "$\pi_2$ RLHF", 
                        "$\pi_2$", 
                        "$\pi_2$ DPO"],
                showmeans=True)
axes[0].set_title("Full Policy Comparison")
axes[0].set_ylabel("Episode Return")
axes[0].set_ylim([-1750, 0])
axes[0].grid(True)

# Second subplot: Only DPO, π₁, and π₂
axes[1].boxplot([returns_pi1, returns_pi2,returns_pi2_rlhf, returns_dpo_from_pi2],
                tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
                showmeans=True)
axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
axes[1].set_ylim([-400, 0])
axes[1].grid(True)

plt.tight_layout()
plt.savefig(f"{env_id}_dual_benchmark_{seed}_dataset{sample_prefs}.png", dpi=300)
plt.show()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# <>:31: SyntaxWarning: invalid escape sequence '\p'
# <>:32: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# <>:31: SyntaxWarning: invalid escape sequence '\p'
# <>:32: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:30: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:31: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$ RLHF",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:32: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:33: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$ DPO"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_31140\1096960866.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML, display
from stable_baselines3 import PPO
import os
import copy

# Step 1: Run a single episode and record rendered frames
def record_episode(model, env, seed, max_steps=1000):
    frames = []
    obs, _ = env.reset(seed=seed)
    for _ in range(max_steps):
        frame = env.render()
        frames.append(frame)
        action = model.predict(obs, deterministic=True)[0]
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    return frames

# Step 2: Combine multiple frame sequences into a single animation and optionally save as a GIF
def show_combined_animation(frames_list, fps=30, gif_path=None):
    min_len = min(len(f) for f in frames_list)
    fig = plt.figure(figsize=(12, 4))
    plt.axis('off')
    init_frame = np.hstack([f[0] for f in frames_list])
    im = plt.imshow(init_frame)

    def update(i):
        combined = np.hstack([f[i] for f in frames_list])
        im.set_array(combined)
        return [im]

    ani = animation.FuncAnimation(fig, update, frames=min_len, interval=1000/fps)

    if gif_path:
        ani.save(gif_path, writer='pillow', fps=fps)
        print(f"✅ GIF saved to: {os.path.abspath(gif_path)}")

    return HTML(ani.to_jshtml())

def trajectory_overlay_faded(frames, threshold=30, min_alpha=0.05, max_alpha=0.6):
    frames = [f.astype(np.float32) for f in frames]
    H, W, C = frames[0].shape

    overlay = np.ones((H, W, C), dtype=np.float32) * 255
    num_frames = len(frames)

    for idx, frame in enumerate(frames):
        diff = np.abs(frame - 255)
        mask = (diff.mean(axis=2) > threshold)

        alpha = min_alpha + (max_alpha - min_alpha) * (idx / (num_frames - 1))

        for c in range(3):
            overlay[:, :, c][mask] = (
                alpha * frame[:, :, c][mask] +
                (1 - alpha) * overlay[:, :, c][mask]
            )
    return np.clip(overlay, 0, 255).astype(np.uint8)

def show_trajectory_comparison(img_expert, img_rlhf, img_pi2, img_dpo_from_pi2, titles=None):
    if titles is None:
        titles = ["Expert", "$\pi_2$ RLHF",  "$\pi_2$", "$\pi_2$ DPO"]

    fig, axes = plt.subplots(1, 4, figsize=(18, 6))
    images = [img_expert, img_rlhf, img_pi2, img_dpo_from_pi2]

    for ax, img, title in zip(axes, images, titles):
        ax.imshow(img)
        ax.set_title(title, fontsize=20)
        ax.axis('off')
    plt.tight_layout()
    plt.savefig(f"{env_id}_render_{seed}_dataset{sample_prefs}.png", dpi=300)
    plt.show()

# Step 4: Load models and environments
# Step 4: Load models and environments
env_expert = gym.make(env_id, render_mode="rgb_array")
env_rlhf   = gym.make(env_id, render_mode="rgb_array")
# env_dpo    = gym.make(env_id, render_mode="rgb_array")
env_pi2 = gym.make(env_id, render_mode="rgb_array")
env_dpo_from_pi2 = gym.make(env_id, render_mode="rgb_array")
expert_model = PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env_expert)
rlhf_model   = PPO.load(f"{env_id}_rlhf_pi2_seed{seed}.zip", env=env_rlhf)
# dpo_model.policy.load_state_dict(state_dict)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env_pi2)
dpo_from_pi2 = copy.deepcopy(pi2_model.policy)
dpo_from_pi2.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# Step 5: Collect animation frames for all three strategies
frames_expert = record_episode(expert_model, env_expert, seed=seed)
frames_rlhf   = record_episode(rlhf_model, env_rlhf, seed=seed)
# frames_dpo    = record_episode(dpo_model, env_dpo, seed=seed)
frames_pi2 = record_episode(pi2_model, env_pi2, seed=seed)
frames_dpo_from_pi2 = record_episode(dpo_from_pi2, env_dpo_from_pi2, seed=seed)

# Step 6: Display the combined animation and save it as a GIF file
display(HTML("<h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2"))
display(show_combined_animation(
    [frames_expert, frames_rlhf, frames_pi2, frames_dpo_from_pi2],
    gif_path=f"{env_id}_comparison_seed{seed}_dataset{sample_prefs}.gif"
))

img_expert = trajectory_overlay_faded(frames_expert, threshold=55)
img_rlhf = trajectory_overlay_faded(frames_rlhf, threshold=55)
# img_dpo = trajectory_overlay_faded(frames_dpo, threshold=55)
img_pi2 = trajectory_overlay_faded(frames_pi2, threshold=55)
img_dpo_from_pi2 = trajectory_overlay_faded(frames_dpo_from_pi2, threshold=55)
show_trajectory_comparison(img_expert, img_rlhf, img_pi2, img_dpo_from_pi2)
# Out:
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# <>:67: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_33264\2382609275.py:67: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "$\pi_2$ RLHF",  "$\pi_2$", "$\pi_2$ DPO"]
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_33264\2382609275.py:67: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "$\pi_2$ RLHF",  "$\pi_2$", "$\pi_2$ DPO"]
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_33264\2382609275.py:67: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "$\pi_2$ RLHF",  "$\pi_2$", "$\pi_2$ DPO"]
# c:\Users\MATH-286-Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_33264\2382609275.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dpo_from_pi2.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2
# ✅ GIF saved to: d:\EPFL\Course\MA2\[EE-568] Reinforcement Learning\EE-568-RL\Pendulum-v1_comparison_seed42_dataset2000.gif
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img858ee1de3f094ea58ba1dc3cd77a61c8">
#   <div class="anim-controls">
#     <input id="_anim_slider858ee1de3f094ea58ba1dc3cd77a61c8" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim858ee1de3f094ea58ba1dc3cd77a61c8.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim858ee1de3f094ea58ba1dc3cd77a61c8.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select858ee1de3f094ea58ba1dc3cd77a61c8"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_858ee1de3f094ea58ba1dc3cd77a61c8"
#              >
#       <label for="_anim_radio1_858ee1de3f094ea58ba1dc3cd77a61c8">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_858ee1de3f094ea58ba1dc3cd77a61c8"
#              checked>
#       <label for="_anim_radio2_858ee1de3f094ea58ba1dc3cd77a61c8">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_858ee1de3f094ea58ba1dc3cd77a61c8"
#              >
#       <label for="_anim_radio3_858ee1de3f094ea58ba1dc3cd77a61c8">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img858ee1de3f094ea58ba1dc3cd77a61c8";
#     var slider_id = "_anim_slider858ee1de3f094ea58ba1dc3cd77a61c8";
#     var loop_select_id = "_anim_loop_select858ee1de3f094ea58ba1dc3cd77a61c8";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAFKhJ
