# %% [markdown]
# # 🧠 RLHF Full Workflow (Unified Notebook)
# This notebook trains PPO Expert, generates preference data using π₁ vs π₂, trains PPO-RLHF using RewardNet, and then trains a DPO policy — all within one integrated flow. Supports both discrete and continuous environments.

# %% [markdown]
# ## 📦 Step 1: Setup and Imports

# %%
import os
import gymnasium as gym
import torch
import pickle
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.policies import ActorCriticPolicy

# %% [markdown]
# ## ⚙️ Step 2: Environment Setup

# %%
# ===== 🧩 Parameter Settings: Used to control the entire training / preference / visualization process =====

env_id = "Pendulum-v1"     # Task environment name (Options: CartPole-v1, Pendulum-v1, Acrobot-v1, MountainCar-v0, MountainCarContinuous-v0)

seed = 42                  # Random seed to ensure experiment reproducibility

total_timesteps = 300_000   # Number of training steps for Expert PPO (Recommended: 40k for CartPole, 300k for Pendulum)

num_prefs = 10_000            # Number of preference samples
sample_prefs = 2_000

# ===========================================================


set_random_seed(seed)

env = Monitor(gym.make(env_id))
is_discrete = hasattr(env.action_space, "n")
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
sample_length = 200
print(f"✅ Environment: {env_id} | Action space: {'Discrete' if is_discrete else 'Continuous'}")
# Out:
# ✅ Environment: Pendulum-v1 | Action space: Continuous

# %% [markdown]
# ## 🧠 Step 3: Train PPO Expert (π₁) and Save Checkpoints

# %%
checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(
    save_freq=total_timesteps // 10,
    save_path=checkpoint_dir,
    name_prefix="ppo"
)

expert_model = PPO("MlpPolicy", env, verbose=1, seed=seed, device="cpu")
expert_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
expert_model.save(f"{env_id}_expert_seed{seed}.zip")
env.close()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    fps             | 1972      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 1100         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036137106 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0082       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00229     |
# |    std                  | 0.988        |
# |    value_loss           | 8.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 1010         |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0020699282 |
# |    clip_fraction        | 0.00454      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.972        |
# |    value_loss           | 6.99e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005652496 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0724      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.1e+03     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00448    |
# |    std                  | 0.966       |
# |    value_loss           | 7.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 968          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059981355 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.019        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.45e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00373     |
# |    std                  | 0.957        |
# |    value_loss           | 7.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035557372 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0033       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.17e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.948        |
# |    value_loss           | 9.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 935          |
# |    iterations           | 7            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0026940266 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00572      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00227     |
# |    std                  | 0.931        |
# |    value_loss           | 5.96e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032982763 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00176      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.96e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00198     |
# |    std                  | 0.931        |
# |    value_loss           | 8.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023999477 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000978     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+03      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.915        |
# |    value_loss           | 8.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 912          |
# |    iterations           | 10           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0015800439 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00146      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 0.932        |
# |    value_loss           | 6.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 910          |
# |    iterations           | 11           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0038937037 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000788     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.46e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00267     |
# |    std                  | 0.923        |
# |    value_loss           | 6.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 910          |
# |    iterations           | 12           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0044846814 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.000449     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+03      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.911        |
# |    value_loss           | 7.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 13           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0027967247 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000564     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.38e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00137     |
# |    std                  | 0.9          |
# |    value_loss           | 8.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 14           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0009454092 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000551     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000888    |
# |    std                  | 0.896        |
# |    value_loss           | 5.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 15           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0029430245 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000233     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.892        |
# |    value_loss           | 8.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 16           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0040861354 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.000373     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.36e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00352     |
# |    std                  | 0.888        |
# |    value_loss           | 7.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 17          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003455534 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.000287    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.63e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00379    |
# |    std                  | 0.889       |
# |    value_loss           | 5.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 906         |
# |    iterations           | 18          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004184423 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.000198    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.871       |
# |    value_loss           | 6.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 19          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004405112 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.000244    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.863       |
# |    value_loss           | 4.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 20           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031962674 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000152     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00185     |
# |    std                  | 0.87         |
# |    value_loss           | 4.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 902          |
# |    iterations           | 21           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0032078046 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 9.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.872        |
# |    value_loss           | 5.29e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.19e+03  |
# | time/                   |            |
# |    fps                  | 900        |
# |    iterations           | 22         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00425444 |
# |    clip_fraction        | 0.0261     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 6.41e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.11e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00279   |
# |    std                  | 0.881      |
# |    value_loss           | 5.42e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 23           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0040985253 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 5.63e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.896        |
# |    value_loss           | 5.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 24           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035924222 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 7.02e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+03      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.879        |
# |    value_loss           | 4.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 25          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003383427 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 5.61e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.895       |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 902          |
# |    iterations           | 26           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024948479 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 4.01e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.884        |
# |    value_loss           | 3.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 903          |
# |    iterations           | 27           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0028061457 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.48e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000948    |
# |    std                  | 0.877        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 28           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0028699546 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.74e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.89         |
# |    value_loss           | 3.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 29           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0008581034 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.56e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000439    |
# |    std                  | 0.893        |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 30           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0030353507 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.902        |
# |    value_loss           | 3.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 31           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0021875247 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.87e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000784    |
# |    std                  | 0.892        |
# |    value_loss           | 4.32e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 32          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003180161 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 1.82e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.882       |
# |    value_loss           | 3.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 33           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0019716776 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 1.51e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.902        |
# |    value_loss           | 2.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.11e+03   |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 34          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003970334 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 1.47e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 977         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000971   |
# |    std                  | 0.925       |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 35           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0029812397 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 8.82e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.91         |
# |    value_loss           | 3.09e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.1e+03   |
# | time/                   |            |
# |    fps                  | 791        |
# |    iterations           | 36         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00416654 |
# |    clip_fraction        | 0.0341     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 9.42e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09e+03   |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00259   |
# |    std                  | 0.917      |
# |    value_loss           | 2.3e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.08e+03   |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 37          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005548319 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 7.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00328    |
# |    std                  | 0.907       |
# |    value_loss           | 2.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 38          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004473949 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 5.78e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 842         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.921       |
# |    value_loss           | 1.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 765         |
# |    iterations           | 39          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004523319 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 4.71e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 917         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.92        |
# |    value_loss           | 2.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 40          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006485818 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 4.23e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00385    |
# |    std                  | 0.904       |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 41           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0041854642 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 4.59e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.891        |
# |    value_loss           | 2.57e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 42           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0024276022 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 4.11e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.885        |
# |    value_loss           | 1.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 43          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004471793 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 3.58e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 562         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.89        |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 44           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0037951546 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.56e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 803          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 0.902        |
# |    value_loss           | 2.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 45           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0032562576 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 3.04e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 649          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00238     |
# |    std                  | 0.899        |
# |    value_loss           | 1.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 46           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0034426863 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.68e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 773          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.888        |
# |    value_loss           | 1.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 47           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017433102 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.8e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 621          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -8.45e-06    |
# |    std                  | 0.886        |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 48           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0054194964 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 3.04e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 719          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00625     |
# |    std                  | 0.89         |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.05e+03   |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 49          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004001994 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.86e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 944         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.906       |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.04e+03   |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 50          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005443167 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 727         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.888       |
# |    value_loss           | 1.6e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.02e+03    |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 51           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0029791049 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 2.26e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 771          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00387     |
# |    std                  | 0.871        |
# |    value_loss           | 1.48e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.02e+03    |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 52           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0055086697 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 2.8e-06      |
# |    learning_rate        | 0.0003       |
# ...
# |    std                  | 0.515       |
# |    value_loss           | 67.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 131          |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0025074289 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 321          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00303     |
# |    std                  | 0.516        |
# |    value_loss           | 252          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -282         |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 132          |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0047070296 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.1         |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00261     |
# |    std                  | 0.517        |
# |    value_loss           | 355          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -277        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 133         |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.008822044 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00275    |
# |    std                  | 0.507       |
# |    value_loss           | 100         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -278       |
# | time/                   |            |
# |    fps                  | 812        |
# |    iterations           | 134        |
# |    time_elapsed         | 337        |
# |    total_timesteps      | 274432     |
# | train/                  |            |
# |    approx_kl            | 0.00816053 |
# |    clip_fraction        | 0.0907     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.742     |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.1       |
# |    n_updates            | 1330       |
# |    policy_gradient_loss | -0.00172   |
# |    std                  | 0.511      |
# |    value_loss           | 156        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 135         |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.004444576 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.9        |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.511       |
# |    value_loss           | 218         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -278        |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 136         |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.010076949 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -4.54e-06   |
# |    std                  | 0.499       |
# |    value_loss           | 50.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -284       |
# | time/                   |            |
# |    fps                  | 804        |
# |    iterations           | 137        |
# |    time_elapsed         | 348        |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.04935674 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.728     |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.6       |
# |    n_updates            | 1360       |
# |    policy_gradient_loss | 0.00674    |
# |    std                  | 0.503      |
# |    value_loss           | 26.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -315         |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 138          |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0037680953 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.738       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | 0.000393     |
# |    std                  | 0.509        |
# |    value_loss           | 255          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -334         |
# | time/                   |              |
# |    fps                  | 798          |
# |    iterations           | 139          |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0026650564 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.511        |
# |    value_loss           | 606          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -344         |
# | time/                   |              |
# |    fps                  | 796          |
# |    iterations           | 140          |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0074109035 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 0.519        |
# |    value_loss           | 404          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -336         |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 141          |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0047851102 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 448          |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00374     |
# |    std                  | 0.513        |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 142          |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0106419055 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.8         |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.0009      |
# |    std                  | 0.507        |
# |    value_loss           | 193          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 143          |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0020621265 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.739       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.507        |
# |    value_loss           | 381          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 144         |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.002964203 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 174         |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00444    |
# |    std                  | 0.507       |
# |    value_loss           | 541         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -352         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 145          |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0041686418 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.734       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 149          |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00254     |
# |    std                  | 0.501        |
# |    value_loss           | 379          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -344       |
# | time/                   |            |
# |    fps                  | 774        |
# |    iterations           | 146        |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 299008     |
# | train/                  |            |
# |    approx_kl            | 0.02953802 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.721     |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22       |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | 0.00548    |
# |    std                  | 0.495      |
# |    value_loss           | 45.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 147         |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.010104677 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.00216    |
# |    std                  | 0.483       |
# |    value_loss           | 54.7        |
# -----------------------------------------

# %% [markdown]
# ## 🧪 Step 4: Select π₂ (Half-Performance PPO Checkpoint)

# %%
def evaluate_policy(model, env, episodes=10):
    scores = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        done = False
        total = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        scores.append(total)
    return np.mean(scores)

checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)
env = gym.make(env_id)
checkpoints = sorted([f for f in os.listdir(checkpoint_dir) if f.endswith(".zip")])
rewards = [(f, evaluate_policy(PPO.load(os.path.join(checkpoint_dir, f), env=env, device="cpu"), env)) for f in checkpoints]
best_reward = max(rewards, key=lambda x: x[1])[1]
target = best_reward * 1.5
rewards.sort(key=lambda x: abs(x[1]/target - 1.0))
pi2_model = PPO.load(os.path.join(checkpoint_dir, rewards[0][0]), env=env, device="cpu")
pi2_model.save(f"{env_id}_pi2_model_seed{seed}.zip")
print(f"✅ Selected π₂: {rewards[0][0]} with ~{rewards[0][1]:.1f} reward")
best_model_path, best_reward = max(rewards, key=lambda x: x[1])
expert_model = PPO.load(os.path.join(checkpoint_dir, best_model_path), env=env, device="cpu")
expert_model_path = f"{env_id}_expert_seed{seed}.zip"
expert_model.save(expert_model_path)

print(f"✅ Expert model selected: '{best_model_path}' with mean reward ≈ {best_reward:.2f}")
print(f"📦 Saved to: {expert_model_path}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Selected π₂: ppo_210000_steps.zip with ~-332.7 reward
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Expert model selected: 'ppo_300000_steps.zip' with mean reward ≈ -220.63
# 📦 Saved to: Pendulum-v1_expert_seed42.zip

# %% [markdown]
# ## ❤️ Step 5: Generate Preferences (π₁ vs π₂)

# %%
import numpy as np
import pickle
from tqdm import trange
import numpy as np

def generate_trajectory(model, env, seed, max_steps):
    obs_list, act_list, rewards, mask = [], [], [], []
    obs, _ = env.reset(seed=seed)

    for step in range(max_steps):
        action, _ = model.predict(obs)
        obs_, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        obs_list.append(np.array(obs))       # ensure obs is np.array
        act_list.append(np.array(action))    # ensure action is np.array
        rewards.append(reward)
        mask.append(1)

        obs = obs_
        if done:
            break

    pad_len = max_steps - len(obs_list)
    if pad_len > 0:
        obs_shape = obs_list[0].shape
        obs_list += [np.zeros(obs_shape)] * pad_len
        act_shape = act_list[0].shape if isinstance(act_list[0], np.ndarray) else ()
        act_list += [np.zeros(act_shape)] * pad_len
        rewards += [0.0] * pad_len
        mask += [0] * pad_len

    return {
        "obs": np.stack(obs_list),       # [T, obs_dim]
        "acts": np.stack(act_list),      # [T] (discrete) or [T, act_dim] (continuous)
        "rews": np.array(rewards),       # [T]
        "mask": np.array(mask)           # [T]
    }

def compute_return(traj):
    return sum(traj["rews"])

def soft_preference_prob(R1, R2):
    max_r = max(R1, R2)
    return np.exp(R1 - max_r) / (np.exp(R1 - max_r) + np.exp(R2 - max_r))

# Sample preference data
prefs = []
env = gym.make(env_id)
for idx in trange(num_prefs, desc="🔄 Generating preference pairs"):
    traj1 = generate_trajectory(model = expert_model, env=env, seed=idx, max_steps=sample_length)
    traj2 = generate_trajectory(pi2_model, env=env, seed=idx, max_steps=sample_length)
    R1, R2 = compute_return(traj1), compute_return(traj2)
    p = soft_preference_prob(R1, R2)
    label = int(np.random.rand() < p)
    prefs.append((traj1, traj2, label))

# save .pkl
filename = f"prefs_{env_id}_seed{seed}.pkl"
with open(filename, "wb") as f:
    pickle.dump(prefs, f)

print(f"✅ Saved {len(prefs)} preference pairs to {filename}")

# %%
class PreferenceDataset(torch.utils.data.Dataset):
    def __init__(self, prefs, is_discrete):
        self.prefs = prefs
        self.is_discrete = is_discrete

    def __len__(self):
        return len(self.prefs)

    def __getitem__(self, idx):
        traj1, traj2, label = self.prefs[idx]

        return {
            "obs1": torch.from_numpy(traj1["obs"]).float(),
            "acts1": torch.from_numpy(traj1["acts"]).long() if self.is_discrete else torch.from_numpy(traj1["acts"]).float(),
            "mask1": torch.from_numpy(traj1["mask"]).float(),

            "obs2": torch.from_numpy(traj2["obs"]).float(),
            "acts2": torch.from_numpy(traj2["acts"]).long() if self.is_discrete else torch.from_numpy(traj2["acts"]).float(),
            "mask2": torch.from_numpy(traj2["mask"]).float(),

            "label": torch.tensor(label, dtype=torch.float32)
        }

# %% [markdown]
# ## ⚙️ Step 7: Train DPO Policy

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO

def train_dpo(dataloader, env, seed=0, epochs=50, device='cuda'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    
    model = PPO("MlpPolicy", env, verbose=0, seed=seed, device="cuda")
    policy = model.policy
    policy.train()  # ensure in training mode
    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]

            obs1_flat = obs1.view(-1, obs_dim)
            obs2_flat = obs2.view(-1, obs_dim)
            acts1_flat = acts1.view(-1) if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1) if is_discrete else acts2.view(-1, act_dim)

            dist1 = policy.get_distribution(obs1_flat)  # returns Categorical
            dist2 = policy.get_distribution(obs2_flat)
            lp1 = dist1.log_prob(acts1_flat).view(B, T)  # [B, T]
            lp2 = dist2.log_prob(acts2_flat).view(B, T)
            
            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits = logp1_sum - logp2_sum        # [B]

            loss = F.binary_cross_entropy_with_logits(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

#with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
#    prefs = pickle.load(f)
#prefs = prefs[:sample_prefs]

#dataset = PreferenceDataset(prefs, is_discrete)
#loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

#dpo_model = train_dpo(loader, env)
#torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO
import copy

def train_dpo_from_ref(dataloader,ref_policy_sb3, env, beta= 0.05,  seed=42, epochs=50, device='cuda'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]


    ref_policy = ref_policy_sb3.policy  # frozen
    policy = copy.deepcopy(ref_policy)  # trainable

    policy.to(device)
    ref_policy.to(device)
    ref_policy.eval()  # ensure frozen

    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        policy.train()  # ensure in training mode
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]
            obs1_flat = obs1.view(-1, obs_dim) # [B*T, obs_dim]
            obs2_flat = obs2.view(-1, obs_dim) # [B*T, obs_dim]
            acts1_flat = acts1.view(-1).long() if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1).long() if is_discrete else acts2.view(-1, act_dim)

            # --- Compute log probs from trainable policy ---

            dist1 = policy.get_distribution(obs1_flat)
            dist2 = policy.get_distribution(obs2_flat)

            logp1 = dist1.log_prob(acts1_flat)
            logp2 = dist2.log_prob(acts2_flat)



            #logp1 = torch.log_softmax(policy(obs1_flat), dim=-1)
            #logp2 = torch.log_softmax(policy(obs2_flat), dim=-1)

            # --- Compute log probs from reference policy (frozen) ---
            with torch.no_grad():
                dist1_ref = ref_policy.get_distribution(obs1_flat)
                dist2_ref = ref_policy.get_distribution(obs2_flat)

                logp1_ref = dist1_ref.log_prob(acts1_flat)
                logp2_ref = dist2_ref.log_prob(acts2_flat)

                #logp1_ref = torch.log_softmax(ref_policy(obs1_flat), dim=-1)
                #logp2_ref = torch.log_softmax(ref_policy(obs2_flat), dim=-1)


            lp1 = (logp1 - logp1_ref).view(B, -1)  # shape [B, T]
            lp2 = (logp2 - logp2_ref).view(B, -1)


            #lp1 = logp1[torch.arange(len(acts1_flat)), acts1_flat].view(B, -1)
            #lp2 = logp2[torch.arange(len(acts2_flat)), acts2_flat].view(B, -1)

            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits =beta*(logp1_sum - logp2_sum)        # [B]
            loss = F.binary_cross_entropy_with_logits(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

# %%
with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]
dataset = PreferenceDataset(prefs, is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)
dpo_model_from_ref = train_dpo_from_ref(loader,pi2_model, env, beta=0.5, seed=seed)
torch.save(dpo_model_from_ref.state_dict(), f"{env_id}_dpo_pi2_seed{seed}.pth")

dpo_model = train_dpo(loader, env, seed=seed)
torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 1.1998
# Epoch 2/50, Loss: 0.8448
# Epoch 3/50, Loss: 0.6887
# Epoch 4/50, Loss: 0.7198
# Epoch 5/50, Loss: 0.6307
# Epoch 6/50, Loss: 0.6889
# Epoch 7/50, Loss: 0.5575
# Epoch 8/50, Loss: 0.7391
# Epoch 9/50, Loss: 0.8134
# Epoch 10/50, Loss: 0.7952
# Epoch 11/50, Loss: 0.6652
# Epoch 12/50, Loss: 1.3137
# Epoch 13/50, Loss: 0.7416
# Epoch 14/50, Loss: 0.8242
# Epoch 15/50, Loss: 0.7887
# Epoch 16/50, Loss: 0.5439
# Epoch 17/50, Loss: 1.0425
# Epoch 18/50, Loss: 0.6117
# Epoch 19/50, Loss: 0.6272
# Epoch 20/50, Loss: 0.8294
# Epoch 21/50, Loss: 1.2155
# Epoch 22/50, Loss: 0.8757
# Epoch 23/50, Loss: 0.7778
# Epoch 24/50, Loss: 0.5111
# Epoch 25/50, Loss: 0.6641
# Epoch 26/50, Loss: 0.8241
# Epoch 27/50, Loss: 0.7573
# Epoch 28/50, Loss: 0.6677
# Epoch 29/50, Loss: 0.7467
# Epoch 30/50, Loss: 0.7323
# Epoch 31/50, Loss: 0.7494
# Epoch 32/50, Loss: 0.4906
# Epoch 33/50, Loss: 0.6948
# Epoch 34/50, Loss: 0.6074
# Epoch 35/50, Loss: 0.7462
# Epoch 36/50, Loss: 0.5249
# Epoch 37/50, Loss: 0.9677
# Epoch 38/50, Loss: 0.8377
# Epoch 39/50, Loss: 0.9365
# Epoch 40/50, Loss: 0.5458
# Epoch 41/50, Loss: 0.7259
# Epoch 42/50, Loss: 0.7481
# Epoch 43/50, Loss: 0.5020
# Epoch 44/50, Loss: 0.7307
# Epoch 45/50, Loss: 0.7102
# Epoch 46/50, Loss: 0.7322
# Epoch 47/50, Loss: 0.9172
# Epoch 48/50, Loss: 0.7187
# Epoch 49/50, Loss: 0.5517
# Epoch 50/50, Loss: 0.5813
# c:\Users\MATH-286-Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Epoch 1/50, Loss: 1.5411
# Epoch 2/50, Loss: 1.1841
# Epoch 3/50, Loss: 0.9907
# Epoch 4/50, Loss: 0.8480
# Epoch 5/50, Loss: 0.7615
# Epoch 6/50, Loss: 0.6824
# Epoch 7/50, Loss: 0.6107
# Epoch 8/50, Loss: 0.5612
# Epoch 9/50, Loss: 0.5205
# Epoch 10/50, Loss: 0.4770
# Epoch 11/50, Loss: 0.4482
# Epoch 12/50, Loss: 0.4278
# Epoch 13/50, Loss: 0.4002
# Epoch 14/50, Loss: 0.3856
# Epoch 15/50, Loss: 0.3673
# Epoch 16/50, Loss: 0.3567
# Epoch 17/50, Loss: 0.3450
# Epoch 18/50, Loss: 0.3394
# Epoch 19/50, Loss: 0.3274
# Epoch 20/50, Loss: 0.3230
# Epoch 21/50, Loss: 0.3186
# Epoch 22/50, Loss: 0.3148
# Epoch 23/50, Loss: 0.3068
# Epoch 24/50, Loss: 0.3067
# Epoch 25/50, Loss: 0.3047
# Epoch 26/50, Loss: 0.2974
# Epoch 27/50, Loss: 0.2974
# Epoch 28/50, Loss: 0.2973
# Epoch 29/50, Loss: 0.2933
# Epoch 30/50, Loss: 0.2933
# Epoch 31/50, Loss: 0.2983
# Epoch 32/50, Loss: 0.2921
# Epoch 33/50, Loss: 0.2927
# Epoch 34/50, Loss: 0.2955
# Epoch 35/50, Loss: 0.2886
# Epoch 36/50, Loss: 0.2923
# Epoch 37/50, Loss: 0.2885
# Epoch 38/50, Loss: 0.2890
# Epoch 39/50, Loss: 0.2883
# Epoch 40/50, Loss: 0.2888
# Epoch 41/50, Loss: 0.2866
# Epoch 42/50, Loss: 0.2892
# Epoch 43/50, Loss: 0.2896
# Epoch 44/50, Loss: 0.2871
# Epoch 45/50, Loss: 0.2861
# Epoch 46/50, Loss: 0.2873
# Epoch 47/50, Loss: 0.2905
# Epoch 48/50, Loss: 0.2883
# Epoch 49/50, Loss: 0.2856
# Epoch 50/50, Loss: 0.2873

# %% [markdown]
# ## 🧠 Step 8: Train RewardNet from Preferences (for PPO-RLHF)

# %%
class RewardNet(nn.Module):
    def __init__(self, obs_dim, act_dim, is_discrete=True, hidden_size=64):
        super().__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, states, actions):
        if self.is_discrete:
            one_hot = F.one_hot(actions.view(-1), num_classes=self.act_dim).float()
            x = torch.cat([states, one_hot], dim=-1)
        else:
            x = torch.cat([states, actions], dim=-1)
        return self.net(x).squeeze(-1)

def train_reward_model(dataloader, obs_dim, act_dim, is_discrete, epochs=50, lr=1e-3, device='cuda'):
    model = RewardNet(obs_dim, act_dim, is_discrete).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        total_loss = 0.0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            r1 = model(obs1.view(-1, obs_dim), acts1.view(-1) if is_discrete else acts1.view(-1, act_dim))
            r2 = model(obs2.view(-1, obs_dim), acts2.view(-1) if is_discrete else acts2.view(-1, act_dim))

            r1 = r1.view(obs1.shape[0], obs1.shape[1]) * mask1
            r2 = r2.view(obs2.shape[0], obs2.shape[1]) * mask2

            r1_sum = r1.sum(dim=1)  # [B]
            r2_sum = r2.sum(dim=1)  # [B]

            logits = r1_sum - r2_sum  # [B]
            loss = criterion(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return model

with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]

dataset = PreferenceDataset(prefs, is_discrete=is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

reward_model = train_reward_model(loader, obs_dim, act_dim, is_discrete)
torch.save(reward_model.state_dict(), f"{env_id}_reward_model_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 1.1131
# Epoch 2/50, Loss: 0.2732
# Epoch 3/50, Loss: 0.2611
# Epoch 4/50, Loss: 0.2499
# Epoch 5/50, Loss: 0.2471
# Epoch 6/50, Loss: 0.2600
# Epoch 7/50, Loss: 0.2426
# Epoch 8/50, Loss: 0.2383
# Epoch 9/50, Loss: 0.2378
# Epoch 10/50, Loss: 0.2423
# Epoch 11/50, Loss: 0.2430
# Epoch 12/50, Loss: 0.2503
# Epoch 13/50, Loss: 0.2337
# Epoch 14/50, Loss: 0.2284
# Epoch 15/50, Loss: 0.2285
# Epoch 16/50, Loss: 0.2286
# Epoch 17/50, Loss: 0.2443
# Epoch 18/50, Loss: 0.2317
# Epoch 19/50, Loss: 0.2256
# Epoch 20/50, Loss: 0.2372
# Epoch 21/50, Loss: 0.2321
# Epoch 22/50, Loss: 0.2275
# Epoch 23/50, Loss: 0.2279
# Epoch 24/50, Loss: 0.2208
# Epoch 25/50, Loss: 0.2207
# Epoch 26/50, Loss: 0.2419
# Epoch 27/50, Loss: 0.2237
# Epoch 28/50, Loss: 0.2440
# Epoch 29/50, Loss: 0.2322
# Epoch 30/50, Loss: 0.2378
# Epoch 31/50, Loss: 0.2416
# Epoch 32/50, Loss: 0.2217
# Epoch 33/50, Loss: 0.2336
# Epoch 34/50, Loss: 0.2181
# Epoch 35/50, Loss: 0.2209
# Epoch 36/50, Loss: 0.2305
# Epoch 37/50, Loss: 0.2248
# Epoch 38/50, Loss: 0.2273
# Epoch 39/50, Loss: 0.2236
# Epoch 40/50, Loss: 0.2176
# Epoch 41/50, Loss: 0.2166
# Epoch 42/50, Loss: 0.2310
# Epoch 43/50, Loss: 0.2202
# Epoch 44/50, Loss: 0.2394
# Epoch 45/50, Loss: 0.2246
# Epoch 46/50, Loss: 0.2238
# Epoch 47/50, Loss: 0.2219
# Epoch 48/50, Loss: 0.2212
# Epoch 49/50, Loss: 0.2227
# Epoch 50/50, Loss: 0.2163

# %% [markdown]
# ## 🔁 Step 9: Train PPO-RLHF (Reward Finetuned from Expert π₁)

# %%
# import gymnasium as gym
# from gymnasium import Wrapper

# class RewardNetWrapper(Wrapper):
#     def __init__(self, env, reward_net, is_discrete):
#         super().__init__(env)
#         self.reward_net = reward_net
#         self.is_discrete = is_discrete

#     def step(self, action):
#         obs, reward, terminated, truncated, info = self.env.step(action)

#         # Convert to tensor
#         obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
#         if self.is_discrete:
#             act_tensor = torch.tensor(action, dtype=torch.long).unsqueeze(0)
#         else:
#             act_tensor = torch.tensor(action, dtype=torch.float32).unsqueeze(0)

#         # Predict learned reward
#         with torch.no_grad():
#             reward = self.reward_net(obs_tensor, act_tensor).item()

#         return obs, reward, terminated, truncated, info

# # Wrap the environment with the trained reward_net
# reward_model.eval()  # Ensure the model is in inference mode
# env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
# env = Monitor(env)

# # Retrain the policy using the new reward
# rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
# rlhf_model.learn(total_timesteps=total_timesteps)
# rlhf_model.save(f"{env_id}_rlhf_seed{seed}.zip")


import gymnasium as gym
from gymnasium import Wrapper

class RewardNetWrapper(Wrapper):
    def __init__(self, env, reward_net, is_discrete):
        super().__init__(env)
        self.reward_net = reward_net
        self.is_discrete = is_discrete

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)

        # Convert to tensor and move to reward_net's device
        device = next(self.reward_net.parameters()).device
        obs_tensor = torch.tensor(obs, dtype=torch.float32, device=device).unsqueeze(0)
        if self.is_discrete:
            act_tensor = torch.tensor(action, dtype=torch.long, device=device).unsqueeze(0)
        else:
            act_tensor = torch.tensor(action, dtype=torch.float32, device=device).unsqueeze(0)

        # Predict learned reward
        with torch.no_grad():
            reward = self.reward_net(obs_tensor, act_tensor).item()

        return obs, reward, terminated, truncated, info

# Wrap the environment with the trained reward_net
reward_model.eval()  # Ensure the model is in inference mode
env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
env = Monitor(env)

# Retrain the policy using the new reward
path_model_pi_2 = f"{env_id}_pi2_model_seed{seed}.zip"
print(path_model_pi_2)

# rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed, device="cpu")
rlhf_model = PPO.load(path   = path_model_pi_2, 
                      env    = env, 
                      seed   = seed, 
                      device = "cpu",
                      kl_coeff = 0.5,
                      target_kl= 0.01)  # KL penalty coefficient 0.01

# rlhf_model.learn(total_timesteps=total_timesteps)
# rlhf_model.learn(total_timesteps=total_timesteps // 2) #FF0000
# rlhf_model.learn(total_timesteps=60000) #FF0000
rlhf_model.learn(total_timesteps=200000) #FF0000
rlhf_model.save(f"{env_id}_rlhf_pi2_seed{seed}.zip")
# Out:
# Pendulum-v1_pi2_model_seed42.zip
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -8.41    |
# | time/              |          |
# |    fps             | 1009     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -5.15      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 2          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00542742 |
# |    clip_fraction        | 0.028      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.894     |
# |    explained_variance   | 0.831      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 121        |
# |    n_updates            | 1030       |
# |    policy_gradient_loss | -0.000537  |
# |    std                  | 0.594      |
# |    value_loss           | 484        |
# ----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 2.58        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004726977 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.7        |
# |    n_updates            | 1033        |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.596       |
# |    value_loss           | 442         |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -4.63       |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009562025 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.4        |
# |    n_updates            | 1035        |
# |    policy_gradient_loss | 0.000529    |
# |    std                  | 0.598       |
# |    value_loss           | 178         |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007943176 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.4        |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.000497   |
# |    std                  | 0.596       |
# |    value_loss           | 235         |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.85        |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 6            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064487956 |
# |    clip_fraction        | 0.0885       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 337          |
# |    n_updates            | 1041         |
# |    policy_gradient_loss | 0.00198      |
# |    std                  | 0.596        |
# |    value_loss           | 498          |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -12.2        |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 7            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0077638878 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.2         |
# |    n_updates            | 1045         |
# |    policy_gradient_loss | -0.000956    |
# |    std                  | 0.598        |
# |    value_loss           | 139          |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009187911 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.6        |
# |    n_updates            | 1048        |
# |    policy_gradient_loss | -0.000281   |
# |    std                  | 0.596       |
# |    value_loss           | 193         |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016386563 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | 0.00133     |
# |    std                  | 0.595       |
# |    value_loss           | 85.6        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.03
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -12          |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036006696 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.9         |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 1051         |
# |    policy_gradient_loss | -0.000586    |
# |    std                  | 0.595        |
# |    value_loss           | 50.9         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -12.7      |
# | time/                   |            |
# |    fps                  | 824        |
# |    iterations           | 11         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00850704 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.9       |
# |    explained_variance   | 0.864      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 70.9       |
# |    n_updates            | 1052       |
# |    policy_gradient_loss | 0.00337    |
# |    std                  | 0.595      |
# |    value_loss           | 132        |
# ----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -17.6        |
# | time/                   |              |
# |    fps                  | 826          |
# |    iterations           | 12           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0063442104 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 1053         |
# |    policy_gradient_loss | -0.000588    |
# |    std                  | 0.594        |
# |    value_loss           | 105          |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -19.9        |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 13           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0024126696 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 1054         |
# |    policy_gradient_loss | 0.00084      |
# |    std                  | 0.594        |
# |    value_loss           | 137          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -18        |
# | time/                   |            |
# |    fps                  | 830        |
# |    iterations           | 14         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01040339 |
# |    clip_fraction        | 0.0551     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.898     |
# |    explained_variance   | 0.816      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.1       |
# |    n_updates            | 1056       |
# |    policy_gradient_loss | 0.00303    |
# |    std                  | 0.594      |
# |    value_loss           | 58.7       |
# ----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -15.3        |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 15           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0059914975 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 1057         |
# |    policy_gradient_loss | 0.00076      |
# |    std                  | 0.594        |
# |    value_loss           | 49.2         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 16          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004038846 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 1058        |
# |    policy_gradient_loss | 0.0012      |
# |    std                  | 0.593       |
# |    value_loss           | 64.3        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 17          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002705694 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 1059        |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 0.594       |
# |    value_loss           | 55.6        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -11.2      |
# | time/                   |            |
# |    fps                  | 833        |
# |    iterations           | 18         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00871084 |
# |    clip_fraction        | 0.0396     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.897     |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.4       |
# |    n_updates            | 1061       |
# |    policy_gradient_loss | -0.00106   |
# |    std                  | 0.594      |
# |    value_loss           | 61.5       |
# ----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -13.1       |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005476536 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 1062        |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 0.594       |
# |    value_loss           | 31.1        |
# -----------------------------------------
# Early stopping at step 6 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -11.9       |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 20          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006260448 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.69        |
# |    n_updates            | 1069        |
# |    policy_gradient_loss | -0.000167   |
# |    std                  | 0.589       |
# |    value_loss           | 51.3        |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 21          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006311803 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 1072        |
# |    policy_gradient_loss | 0.00215     |
# |    std                  | 0.581       |
# |    value_loss           | 25.3        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008332722 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.77        |
# |    n_updates            | 1074        |
# |    policy_gradient_loss | 5.54e-05    |
# |    std                  | 0.581       |
# |    value_loss           | 27.6        |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 23          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008181746 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.63        |
# |    n_updates            | 1078        |
# |    policy_gradient_loss | -0.00367    |
# |    std                  | 0.572       |
# |    value_loss           | 15.7        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -15.1        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 24           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0054785996 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 1079         |
# |    policy_gradient_loss | 0.00481      |
# |    std                  | 0.572        |
# |    value_loss           | 25.7         |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -15.4      |
# | time/                   |            |
# |    fps                  | 812        |
# |    iterations           | 25         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01698085 |
# |    clip_fraction        | 0.0494     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.862     |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.4       |
# |    n_updates            | 1083       |
# |    policy_gradient_loss | -0.00279   |
# |    std                  | 0.575      |
# |    value_loss           | 33.4       |
# ----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 26          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007512691 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.12        |
# |    n_updates            | 1088        |
# |    policy_gradient_loss | 0.00127     |
# |    std                  | 0.574       |
# |    value_loss           | 20.7        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -16.2       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 27          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007564546 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.4        |
# |    n_updates            | 1089        |
# |    policy_gradient_loss | 0.00838     |
# |    std                  | 0.574       |
# |    value_loss           | 42          |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -17.2       |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 28          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009002617 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.32        |
# |    n_updates            | 1091        |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.574       |
# |    value_loss           | 28.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -21          |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 29           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0036602106 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.89         |
# |    n_updates            | 1092         |
# |    policy_gradient_loss | 0.00328      |
# |    std                  | 0.573        |
# |    value_loss           | 15.2         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 30          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005814729 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 1093        |
# |    policy_gradient_loss | 0.0065      |
# |    std                  | 0.572       |
# |    value_loss           | 44.3        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -27.8       |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 31          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008408302 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 1095        |
# |    policy_gradient_loss | -0.00437    |
# |    std                  | 0.573       |
# |    value_loss           | 31.5        |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -25.3        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 32           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0057622897 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00244     |
# |    std                  | 0.567        |
# |    value_loss           | 29.2         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 33          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005062172 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.57        |
# |    n_updates            | 1102        |
# |    policy_gradient_loss | 0.00199     |
# |    std                  | 0.562       |
# |    value_loss           | 12.5        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -25          |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 34           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0058569466 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6          |
# |    n_updates            | 1103         |
# |    policy_gradient_loss | 0.00122      |
# |    std                  | 0.56         |
# |    value_loss           | 9.4          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -26.6        |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 35           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0068554883 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99         |
# |    n_updates            | 1105         |
# |    policy_gradient_loss | 0.00235      |
# |    std                  | 0.554        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 36          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007292161 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 1106        |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.553       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -23.3        |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 37           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0034690588 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32         |
# |    n_updates            | 1107         |
# |    policy_gradient_loss | 0.00299      |
# |    std                  | 0.553        |
# |    value_loss           | 5.56         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -25.1      |
# | time/                   |            |
# |    fps                  | 816        |
# |    iterations           | 38         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00860799 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.826     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.96       |
# |    n_updates            | 1108       |
# |    policy_gradient_loss | 0.00419    |
# |    std                  | 0.553      |
# |    value_loss           | 9.15       |
# ----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -19.8        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 39           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0050230077 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.41         |
# |    n_updates            | 1109         |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.554        |
# |    value_loss           | 13.5         |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -15.6       |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 40          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011682888 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14        |
# |    n_updates            | 1112        |
# |    policy_gradient_loss | -0.00174    |
# |    std                  | 0.554       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -8.87        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 41           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0052673323 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89         |
# |    n_updates            | 1113         |
# |    policy_gradient_loss | -1.81e-05    |
# |    std                  | 0.555        |
# |    value_loss           | 4.34         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -8.88       |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 42          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004066691 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 1114        |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.554       |
# |    value_loss           | 6.15        |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -7.94       |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 43          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005104929 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54        |
# |    n_updates            | 1116        |
# |    policy_gradient_loss | 0.00265     |
# |    std                  | 0.552       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -6.07        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 44           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0050735963 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.09         |
# |    n_updates            | 1117         |
# |    policy_gradient_loss | 0.0018       |
# |    std                  | 0.552        |
# |    value_loss           | 16.6         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -6.25        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 45           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0037184865 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25         |
# |    n_updates            | 1118         |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.553        |
# |    value_loss           | 8.51         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -5.09        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 46           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0070742727 |
# |    clip_fraction        | 0.0906       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4          |
# |    n_updates            | 1119         |
# |    policy_gradient_loss | 0.00641      |
# |    std                  | 0.552        |
# |    value_loss           | 7.44         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -3.85       |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 47          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.012290699 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41        |
# |    n_updates            | 1121        |
# |    policy_gradient_loss | -0.00313    |
# |    std                  | 0.551       |
# |    value_loss           | 8.76        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.34        |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 48           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0071376534 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59         |
# |    n_updates            | 1122         |
# |    policy_gradient_loss | 0.000563     |
# |    std                  | 0.55         |
# |    value_loss           | 5.8          |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -3.79       |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 49          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004127268 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67        |
# |    n_updates            | 1123        |
# |    policy_gradient_loss | 0.00171     |
# |    std                  | 0.551       |
# |    value_loss           | 4.83        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.33       |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 50          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 102400      |
# ...
# |    std                  | 0.535       |
# |    value_loss           | 9.8         |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 1.35         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 83           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0051031606 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.15         |
# |    n_updates            | 1189         |
# |    policy_gradient_loss | -0.00779     |
# |    std                  | 0.535        |
# |    value_loss           | 20.1         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 0.352        |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 84           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0068147206 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.07         |
# |    n_updates            | 1191         |
# |    policy_gradient_loss | 0.0014       |
# |    std                  | 0.533        |
# |    value_loss           | 4.32         |
# ------------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 0.697        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 85           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0084775025 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12         |
# |    n_updates            | 1196         |
# |    policy_gradient_loss | 0.00139      |
# |    std                  | 0.528        |
# |    value_loss           | 3.87         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24        |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 86           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0055763125 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.779       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.95         |
# |    n_updates            | 1197         |
# |    policy_gradient_loss | -0.00247     |
# |    std                  | 0.527        |
# |    value_loss           | 5.86         |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -2.76       |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 87          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006802016 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.76        |
# |    n_updates            | 1203        |
# |    policy_gradient_loss | 1.73e-05    |
# |    std                  | 0.53        |
# |    value_loss           | 20          |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -4.05       |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 88          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.006913887 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.78        |
# |    n_updates            | 1206        |
# |    policy_gradient_loss | -0.000739   |
# |    std                  | 0.528       |
# |    value_loss           | 21.4        |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -3.86        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 89           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0050901384 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.18         |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 0.528        |
# |    value_loss           | 18.5         |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -4.32        |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 90           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0059886677 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5          |
# |    n_updates            | 1216         |
# |    policy_gradient_loss | -0.0019      |
# |    std                  | 0.529        |
# |    value_loss           | 11.3         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.04
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -7.41      |
# | time/                   |            |
# |    fps                  | 813        |
# |    iterations           | 91         |
# |    time_elapsed         | 229        |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.01054492 |
# |    clip_fraction        | 0.06       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.784     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.08       |
# |    n_updates            | 1218       |
# |    policy_gradient_loss | 0.0021     |
# |    std                  | 0.53       |
# |    value_loss           | 5.75       |
# ----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -6.62        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 92           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0035111038 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.57         |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.000374    |
# |    std                  | 0.529        |
# |    value_loss           | 26.7         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -7.75       |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 93          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.010720759 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54        |
# |    n_updates            | 1222        |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 0.531       |
# |    value_loss           | 13.5        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -8.67       |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 94          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.002552621 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 1223        |
# |    policy_gradient_loss | -0.0031     |
# |    std                  | 0.531       |
# |    value_loss           | 17.8        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -6.09        |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 95           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0066119316 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.14         |
# |    n_updates            | 1224         |
# |    policy_gradient_loss | -0.00437     |
# |    std                  | 0.531        |
# |    value_loss           | 18.5         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -4.54        |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 96           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0035590075 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 1226         |
# |    policy_gradient_loss | 0.000395     |
# |    std                  | 0.531        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 1.91       |
# | time/                   |            |
# |    fps                  | 815        |
# |    iterations           | 97         |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00531789 |
# |    clip_fraction        | 0.0732     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.786     |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.95       |
# |    n_updates            | 1227       |
# |    policy_gradient_loss | -0.00142   |
# |    std                  | 0.53       |
# |    value_loss           | 9.53       |
# ----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 4.54       |
# | time/                   |            |
# |    fps                  | 815        |
# |    iterations           | 98         |
# |    time_elapsed         | 246        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.00796894 |
# |    clip_fraction        | 0.0213     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.784     |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.95       |
# |    n_updates            | 1229       |
# |    policy_gradient_loss | -0.000666  |
# |    std                  | 0.529      |
# |    value_loss           | 9.16       |
# ----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02

# %% [markdown]
# ## 📊 Step 10: Compare PPO Expert vs PPO-RLHF vs DPO

# %%
def eval_policy(model, env, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0]
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns


env = gym.make(env_id)
returns_pi1 = eval_policy(PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env, device="cpu"), env)
returns_pi2_rlhf   = eval_policy(PPO.load(f"{env_id}_rlhf_pi2_seed{seed}.zip", env=env, device="cpu"), env)
state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env, device="cpu")
returns_pi2 = eval_policy(pi2_model, env)
dpo_model_from_pi2 = PPO("MlpPolicy", env, verbose=0, seed=seed, device="cpu")
dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))
returns_dpo_from_pi2 = eval_policy(dpo_model_from_pi2, env)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# First subplot: Full comparison
axes[0].boxplot([returns_pi1, returns_pi2_rlhf, returns_pi2, returns_dpo_from_pi2],
                tick_labels=["Expert ($\pi_1$)", 
                        "$\pi_2$ RLHF", 
                        "$\pi_2$", 
                        "$\pi_2$ DPO"],
                showmeans=True)
axes[0].set_title("Full Policy Comparison")
axes[0].set_ylabel("Episode Return")
axes[0].set_ylim([-1750, 0])
axes[0].grid(True)

# Second subplot: Only DPO, π₁, and π₂
axes[1].boxplot([returns_pi1, returns_pi2,returns_pi2_rlhf, returns_dpo_from_pi2],
                tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
                showmeans=True)
axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
axes[1].set_ylim([-400, 0])
axes[1].grid(True)

plt.tight_layout()
plt.savefig(f"{env_id}_dual_benchmark_{seed}_dataset{sample_prefs}.png", dpi=300)
plt.show()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# <>:31: SyntaxWarning: invalid escape sequence '\p'
# <>:32: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:30: SyntaxWarning: invalid escape sequence '\p'
# <>:31: SyntaxWarning: invalid escape sequence '\p'
# <>:32: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:30: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:31: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$ RLHF",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:32: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$",
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:33: SyntaxWarning: invalid escape sequence '\p'
#   "$\pi_2$ DPO"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:42: SyntaxWarning: invalid escape sequence '\p'
#   tick_labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\MATH-286-Dell\AppData\Local\Temp\ipykernel_12796\1096960866.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML, display
from stable_baselines3 import PPO
import os

# Step 1: Run a single episode and record rendered frames
def record_episode(model, env, seed, max_steps=1000):
    frames = []
    obs, _ = env.reset(seed=seed)
    for _ in range(max_steps):
        frame = env.render()
        frames.append(frame)
        action = model.predict(obs, deterministic=True)[0]
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    return frames

# Step 2: Combine multiple frame sequences into a single animation and optionally save as a GIF
def show_combined_animation(frames_list, fps=30, gif_path=None):
    min_len = min(len(f) for f in frames_list)
    fig = plt.figure(figsize=(12, 4))
    plt.axis('off')
    init_frame = np.hstack([f[0] for f in frames_list])
    im = plt.imshow(init_frame)

    def update(i):
        combined = np.hstack([f[i] for f in frames_list])
        im.set_array(combined)
        return [im]

    ani = animation.FuncAnimation(fig, update, frames=min_len, interval=1000/fps)

    if gif_path:
        ani.save(gif_path, writer='pillow', fps=fps)
        print(f"✅ GIF saved to: {os.path.abspath(gif_path)}")

    return HTML(ani.to_jshtml())

def trajectory_overlay_faded(frames, threshold=30, min_alpha=0.05, max_alpha=0.6):
    frames = [f.astype(np.float32) for f in frames]
    H, W, C = frames[0].shape

    overlay = np.ones((H, W, C), dtype=np.float32) * 255
    num_frames = len(frames)

    for idx, frame in enumerate(frames):
        diff = np.abs(frame - 255)
        mask = (diff.mean(axis=2) > threshold)

        alpha = min_alpha + (max_alpha - min_alpha) * (idx / (num_frames - 1))

        for c in range(3):
            overlay[:, :, c][mask] = (
                alpha * frame[:, :, c][mask] +
                (1 - alpha) * overlay[:, :, c][mask]
            )
    return np.clip(overlay, 0, 255).astype(np.uint8)

def show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2, titles=None):
    if titles is None:
        titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]

    fig, axes = plt.subplots(1, 5, figsize=(18, 6))
    images = [img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2]

    for ax, img, title in zip(axes, images, titles):
        ax.imshow(img)
        ax.set_title(title, fontsize=20)
        ax.axis('off')
    plt.tight_layout()
    plt.savefig(f"{env_id}_render_{seed}_dataset{sample_prefs}.png", dpi=300)
    plt.show()

# Step 4: Load models and environments
# Step 4: Load models and environments
env_expert = gym.make(env_id, render_mode="rgb_array")
env_rlhf   = gym.make(env_id, render_mode="rgb_array")
env_dpo    = gym.make(env_id, render_mode="rgb_array")
env_pi2 = gym.make(env_id, render_mode="rgb_array")
env_dpo_from_pi2 = gym.make(env_id, render_mode="rgb_array")
expert_model = PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env_expert)
rlhf_model   = PPO.load(f"{env_id}_rlhf_seed{seed}.zip", env=env_rlhf)
dpo_model.policy.load_state_dict(state_dict)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env_pi2)
dpo_from_pi2 = copy.deepcopy(pi2_model.policy)
dpo_from_pi2.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# Step 5: Collect animation frames for all three strategies
frames_expert = record_episode(expert_model, env_expert, seed=seed)
frames_rlhf   = record_episode(rlhf_model, env_rlhf, seed=seed)
frames_dpo    = record_episode(dpo_model, env_dpo, seed=seed)
frames_pi2 = record_episode(pi2_model, env_pi2, seed=seed)
frames_dpo_from_pi2 = record_episode(dpo_from_pi2, env_dpo_from_pi2, seed=seed)

# Step 6: Display the combined animation and save it as a GIF file
display(HTML("<h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2"))
display(show_combined_animation(
    [frames_expert, frames_rlhf, frames_dpo, frames_pi2, frames_dpo_from_pi2],
    gif_path=f"{env_id}_comparison_seed{seed}_dataset{sample_prefs}.gif"
))

img_expert = trajectory_overlay_faded(frames_expert, threshold=55)
img_rlhf = trajectory_overlay_faded(frames_rlhf, threshold=55)
img_dpo = trajectory_overlay_faded(frames_dpo, threshold=55)
img_pi2 = trajectory_overlay_faded(frames_pi2, threshold=55)
img_dpo_from_pi2 = trajectory_overlay_faded(frames_dpo_from_pi2, threshold=55)
show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2)
# Out:
# <>:66: DeprecationWarning: invalid escape sequence \p
# /home/menzzz/anaconda3/envs/py38/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2
# ✅ GIF saved to: /home/menzzz/2024/learning/RL/project_v2/EE-568-RL/Pendulum-v1_comparison_seed42_dataset2000.gif
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img57c93b2cf35f41aab41863eff52e8cbf">
#   <div class="anim-controls">
#     <input id="_anim_slider57c93b2cf35f41aab41863eff52e8cbf" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim57c93b2cf35f41aab41863eff52e8cbf.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim57c93b2cf35f41aab41863eff52e8cbf.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select57c93b2cf35f41aab41863eff52e8cbf"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_57c93b2cf35f41aab41863eff52e8cbf"
#              >
#       <label for="_anim_radio1_57c93b2cf35f41aab41863eff52e8cbf">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_57c93b2cf35f41aab41863eff52e8cbf"
#              checked>
#       <label for="_anim_radio2_57c93b2cf35f41aab41863eff52e8cbf">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_57c93b2cf35f41aab41863eff52e8cbf"
#              >
#       <label for="_anim_radio3_57c93b2cf35f41aab41863eff52e8cbf">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img57c93b2cf35f41aab41863eff52e8cbf";
#     var slider_id = "_anim_slider57c93b2cf35f41aab41863eff52e8cbf";
#     var loop_select_id = "_anim_loop_select57c93b2cf35f41aab41863eff52e8cbf";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuNSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/xnp5ZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAP3klE
