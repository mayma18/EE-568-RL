# %% [markdown]
# # 🧠 RLHF Full Workflow (Unified Notebook)
# This notebook trains PPO Expert, generates preference data using π₁ vs π₂, trains PPO-RLHF using RewardNet, and then trains a DPO policy — all within one integrated flow. Supports both discrete and continuous environments.

# %% [markdown]
# ## 📦 Step 1: Setup and Imports

# %%
import os
import gymnasium as gym
import torch
import pickle
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch.nn.functional as F
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.policies import ActorCriticPolicy

# %% [markdown]
# ## ⚙️ Step 2: Environment Setup

# %%
# ===== 🧩 Parameter Settings: Used to control the entire training / preference / visualization process =====

env_id = "Pendulum-v1"     # Task environment name (Options: CartPole-v1, Pendulum-v1, Acrobot-v1, MountainCar-v0, MountainCarContinuous-v0)

seed = 42                  # Random seed to ensure experiment reproducibility

total_timesteps = 300_000   # Number of training steps for Expert PPO (Recommended: 40k for CartPole, 300k for Pendulum)

num_prefs = 10_000            # Number of preference samples
sample_prefs = 10_000

# ===========================================================


set_random_seed(seed)

env = Monitor(gym.make(env_id))
is_discrete = hasattr(env.action_space, "n")
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
sample_length = 100
print(f"✅ Environment: {env_id} | Action space: {'Discrete' if is_discrete else 'Continuous'}")
# Out:
# ✅ Environment: Pendulum-v1 | Action space: Continuous

# %% [markdown]
# ## 🧠 Step 3: Train PPO Expert (π₁) and Save Checkpoints

# %%
checkpoint_dir = f"./checkpoints_{env_id.replace('-', '_')}"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(
    save_freq=total_timesteps // 10,
    save_path=checkpoint_dir,
    name_prefix="ppo"
)

expert_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
expert_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
expert_model.save(f"{env_id}_expert_seed{seed}.zip")
env.close()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    fps             | 7456      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 4408         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036137116 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0082       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00229     |
# |    std                  | 0.988        |
# |    value_loss           | 8.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 4112         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0020711243 |
# |    clip_fraction        | 0.00454      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.972        |
# |    value_loss           | 6.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3971         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0056473394 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0724       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+03      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 0.966        |
# |    value_loss           | 7.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.18e+03   |
# | time/                   |             |
# |    fps                  | 3882        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005954067 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.019       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.956       |
# |    value_loss           | 7.33e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 3821         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035645005 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0033       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.947        |
# |    value_loss           | 9.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 3786         |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0025297212 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00571      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.89e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 0.931        |
# |    value_loss           | 5.95e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 3767         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032039983 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00178      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.93         |
# |    value_loss           | 7.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.17e+03   |
# | time/                   |             |
# |    fps                  | 3770        |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002500248 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000996    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.913       |
# |    value_loss           | 8.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 3760         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0008562881 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000546    |
# |    std                  | 0.929        |
# |    value_loss           | 6.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 3756         |
# |    iterations           | 11           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0028596604 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000798     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00236     |
# |    std                  | 0.913        |
# |    value_loss           | 6.68e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 3758        |
# |    iterations           | 12          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.002483549 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.000502    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.903       |
# |    value_loss           | 6.92e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3748         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0020230487 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000486     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.55e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000806    |
# |    std                  | 0.894        |
# |    value_loss           | 9.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 3752         |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0022404476 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.000266     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.18e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 0.891        |
# |    value_loss           | 7.57e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 3746         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0019240514 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000173     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.71e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000574    |
# |    std                  | 0.895        |
# |    value_loss           | 8.8e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 3749         |
# |    iterations           | 16           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0030941283 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000432     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.49e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.889        |
# |    value_loss           | 7.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.24e+03    |
# | time/                   |              |
# |    fps                  | 3743         |
# |    iterations           | 17           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035299638 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.000419     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00306     |
# |    std                  | 0.896        |
# |    value_loss           | 5.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3725         |
# |    iterations           | 18           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017563725 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00029      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.881        |
# |    value_loss           | 5.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3722         |
# |    iterations           | 19           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0020866941 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.000223     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+03      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.878        |
# |    value_loss           | 5.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3723         |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0036356864 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000147     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.08e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 0.866        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 3725         |
# |    iterations           | 21           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040781517 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 8.99e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00225     |
# |    std                  | 0.877        |
# |    value_loss           | 5.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 3725         |
# |    iterations           | 22           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0024939217 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 6.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.88         |
# |    value_loss           | 5.46e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.19e+03   |
# | time/                   |             |
# |    fps                  | 3730        |
# |    iterations           | 23          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004869461 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 6.68e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00456    |
# |    std                  | 0.889       |
# |    value_loss           | 5.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 3735        |
# |    iterations           | 24          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002771392 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 6.31e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.875       |
# |    value_loss           | 4.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 3738         |
# |    iterations           | 25           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0046803323 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 5.55e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.873        |
# |    value_loss           | 3.23e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 3743        |
# |    iterations           | 26          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004229717 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 3.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.865       |
# |    value_loss           | 3.69e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 3737         |
# |    iterations           | 27           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0042661284 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 2.32e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.865        |
# |    value_loss           | 4.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 3741         |
# |    iterations           | 28           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0033390112 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 2.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.88         |
# |    value_loss           | 3.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 3746         |
# |    iterations           | 29           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0014606593 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.15e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.886        |
# |    value_loss           | 2.84e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.11e+03   |
# | time/                   |             |
# |    fps                  | 3750        |
# |    iterations           | 30          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002135611 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 1.48e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00133    |
# |    std                  | 0.888       |
# |    value_loss           | 3.44e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 3755         |
# |    iterations           | 31           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0026322685 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.29e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.872        |
# |    value_loss           | 3.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3754         |
# |    iterations           | 32           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0042038765 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.12e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00305     |
# |    std                  | 0.866        |
# |    value_loss           | 3.65e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3736         |
# |    iterations           | 33           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0031772065 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 1.06e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+03      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00219     |
# |    std                  | 0.886        |
# |    value_loss           | 2.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3712         |
# |    iterations           | 34           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0048773363 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 8.11e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 0.913        |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3710         |
# |    iterations           | 35           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0006805477 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 6.5e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.909        |
# |    value_loss           | 3.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 36          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003674881 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 6.14e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 0.918       |
# |    value_loss           | 2.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3715         |
# |    iterations           | 37           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0036517116 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 5.6e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 0.908        |
# |    value_loss           | 2.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 3719         |
# |    iterations           | 38           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0037963428 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 4.05e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 928          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 0.899        |
# |    value_loss           | 2.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 3722        |
# |    iterations           | 39          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004236321 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 3.76e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 907         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00222    |
# |    std                  | 0.91        |
# |    value_loss           | 2.65e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 3726         |
# |    iterations           | 40           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0036059637 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 4.41e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.919        |
# |    value_loss           | 2.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 3730         |
# |    iterations           | 41           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0021971758 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 3.64e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000253    |
# |    std                  | 0.924        |
# |    value_loss           | 2.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 3734         |
# |    iterations           | 42           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0032526464 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 3.46e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 908          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.919        |
# |    value_loss           | 1.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 3737         |
# |    iterations           | 43           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0032642623 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 3.1e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 677          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.902        |
# |    value_loss           | 1.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 3737         |
# |    iterations           | 44           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035909957 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 730          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00149     |
# |    std                  | 0.908        |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.07e+03   |
# | time/                   |             |
# |    fps                  | 3738        |
# |    iterations           | 45          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.002643352 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.62e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 740         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00153    |
# |    std                  | 0.894       |
# |    value_loss           | 1.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 3737         |
# |    iterations           | 46           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0025438992 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 858          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000943    |
# |    std                  | 0.882        |
# |    value_loss           | 1.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 3732        |
# |    iterations           | 47          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.003206753 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 2.44e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 677         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.859       |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 3730         |
# |    iterations           | 48           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0040994957 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 689          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.873        |
# |    value_loss           | 1.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 3695         |
# |    iterations           | 49           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046590148 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 2.15e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 869          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.881        |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 3698         |
# |    iterations           | 50           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0048898794 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 709          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.863        |
# |    value_loss           | 1.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 3699         |
# |    iterations           | 51           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0034761033 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 1.79e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 801          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00386     |
# |    std                  | 0.852        |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 3699         |
# |    iterations           | 52           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0048821163 |
# |    clip_fraction        | 0.0492       |
# ...
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -303         |
# | time/                   |              |
# |    fps                  | 3762         |
# |    iterations           | 131          |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0035021058 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | 0.000302     |
# |    std                  | 0.525        |
# |    value_loss           | 435          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 3763        |
# |    iterations           | 132         |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.004932278 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00531    |
# |    std                  | 0.525       |
# |    value_loss           | 564         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 3761        |
# |    iterations           | 133         |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.001973547 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96          |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.001      |
# |    std                  | 0.524       |
# |    value_loss           | 280         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -291         |
# | time/                   |              |
# |    fps                  | 3762         |
# |    iterations           | 134          |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0043183514 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00301     |
# |    std                  | 0.516        |
# |    value_loss           | 93.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -308         |
# | time/                   |              |
# |    fps                  | 3763         |
# |    iterations           | 135          |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0031747497 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.515        |
# |    value_loss           | 478          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -311         |
# | time/                   |              |
# |    fps                  | 3764         |
# |    iterations           | 136          |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0047922134 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 333          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.515        |
# |    value_loss           | 366          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -333         |
# | time/                   |              |
# |    fps                  | 3765         |
# |    iterations           | 137          |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0029687083 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 202          |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.0041      |
# |    std                  | 0.516        |
# |    value_loss           | 364          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 3766         |
# |    iterations           | 138          |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0053287414 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 196          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.516        |
# |    value_loss           | 485          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 3767        |
# |    iterations           | 139         |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.004356507 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.7        |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.000732   |
# |    std                  | 0.513       |
# |    value_loss           | 252         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -317         |
# | time/                   |              |
# |    fps                  | 3768         |
# |    iterations           | 140          |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0038130344 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 0.508        |
# |    value_loss           | 311          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 3769        |
# |    iterations           | 141         |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.004804925 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.6        |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.506       |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -284        |
# | time/                   |             |
# |    fps                  | 3770        |
# |    iterations           | 142         |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.016841142 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.498       |
# |    value_loss           | 75.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 3771        |
# |    iterations           | 143         |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.004473033 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00296     |
# |    std                  | 0.488       |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -274        |
# | time/                   |             |
# |    fps                  | 3771        |
# |    iterations           | 144         |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.011253502 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.000699    |
# |    std                  | 0.48        |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -269        |
# | time/                   |             |
# |    fps                  | 3772        |
# |    iterations           | 145         |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.006516246 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.8        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.474       |
# |    value_loss           | 211         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -244         |
# | time/                   |              |
# |    fps                  | 3773         |
# |    iterations           | 146          |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0078090187 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | 0.00213      |
# |    std                  | 0.474        |
# |    value_loss           | 52.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -230        |
# | time/                   |             |
# |    fps                  | 3773        |
# |    iterations           | 147         |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.010483112 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 0.461       |
# |    value_loss           | 16.1        |
# -----------------------------------------

# %% [markdown]
# ## 🧪 Step 4: Select π₂ (Half-Performance PPO Checkpoint)

# %%
def evaluate_policy(model, env, episodes=10):
    scores = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        done = False
        total = 0
        while not done:
            action, _ = model.predict(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        scores.append(total)
    return np.mean(scores)

env = gym.make(env_id)
checkpoints = sorted([f for f in os.listdir(checkpoint_dir) if f.endswith(".zip")])
rewards = [(f, evaluate_policy(PPO.load(os.path.join(checkpoint_dir, f), env=env), env)) for f in checkpoints]
best_reward = max(rewards, key=lambda x: x[1])[1]
if best_reward < 0 :
    target = best_reward*1.5
else :
    target = best_reward * 0.5
rewards.sort(key=lambda x: abs(x[1] - target))
pi2_model = PPO.load(os.path.join(checkpoint_dir, rewards[0][0]), env=env)
pi2_model.save(f"{env_id}_pi2_model_seed{seed}.zip")
print(f"✅ Selected π₂: {rewards[0][0]} with ~{rewards[0][1]:.1f} reward")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ✅ Selected π₂: ppo_210000_steps.zip with ~-442.7 reward

# %% [markdown]
# ## ❤️ Step 5: Generate Preferences (π₁ vs π₂)

# %%
import numpy as np
import pickle
from tqdm import trange
import numpy as np

def generate_trajectory(model, env, seed, max_steps):
    obs_list, act_list, rewards, mask = [], [], [], []
    obs, _ = env.reset(seed=seed)

    for step in range(max_steps):
        action, _ = model.predict(obs)
        obs_, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        obs_list.append(np.array(obs))       # ensure obs is np.array
        act_list.append(np.array(action))    # ensure action is np.array
        rewards.append(reward)
        mask.append(1)

        obs = obs_
        if done:
            break

    pad_len = max_steps - len(obs_list)
    if pad_len > 0:
        obs_shape = obs_list[0].shape
        obs_list += [np.zeros(obs_shape)] * pad_len
        act_shape = act_list[0].shape if isinstance(act_list[0], np.ndarray) else ()
        act_list += [np.zeros(act_shape)] * pad_len
        rewards += [0.0] * pad_len
        mask += [0] * pad_len

    return {
        "obs": np.stack(obs_list),       # [T, obs_dim]
        "acts": np.stack(act_list),      # [T] (discrete) or [T, act_dim] (continuous)
        "rews": np.array(rewards),       # [T]
        "mask": np.array(mask)           # [T]
    }

def compute_return(traj):
    return sum(traj["rews"])

def soft_preference_prob(R1, R2):
    max_r = max(R1, R2)
    return np.exp(R1 - max_r) / (np.exp(R1 - max_r) + np.exp(R2 - max_r))

# Sample preference data
num_prefs = [10000, 20000, 30000]
prefs = []
env = gym.make(env_id)
for idx in trange(30000, desc="🔄 Generating preference pairs"):
    if idx in num_prefs:
        filename = f"prefs_{env_id}_seed{seed}_{idx}.pkl"
        with open(filename, "wb") as f:
            pickle.dump(prefs, f)
        print(f"✅ Saved {len(prefs)} preference pairs to {filename}")
    traj1 = generate_trajectory(model = expert_model, env=env, seed=idx, max_steps=sample_length)
    traj2 = generate_trajectory(pi2_model, env=env, seed=idx, max_steps=sample_length)
    R1, R2 = compute_return(traj1), compute_return(traj2)
    p = soft_preference_prob(R1, R2)
    label = int(np.random.rand() < p)
    prefs.append((traj1, traj2, label))

    # save .pkl
# Out:
# 🔄 Generating preference pairs:  33%|███▎      | 10005/30000 [06:06<22:12, 15.01it/s]
# ✅ Saved 10000 preference pairs to prefs_Pendulum-v1_seed42_10000.pkl
# 🔄 Generating preference pairs:  67%|██████▋   | 20004/30000 [12:17<21:10,  7.87it/s]
# ✅ Saved 20000 preference pairs to prefs_Pendulum-v1_seed42_20000.pkl
# 🔄 Generating preference pairs: 100%|██████████| 30000/30000 [18:25<00:00, 27.13it/s]

# %%
class PreferenceDataset(torch.utils.data.Dataset):
    def __init__(self, prefs, is_discrete):
        self.prefs = prefs
        self.is_discrete = is_discrete

    def __len__(self):
        return len(self.prefs)

    def __getitem__(self, idx):
        traj1, traj2, label = self.prefs[idx]

        return {
            "obs1": torch.from_numpy(traj1["obs"]).float(),
            "acts1": torch.from_numpy(traj1["acts"]).long() if self.is_discrete else torch.from_numpy(traj1["acts"]).float(),
            "mask1": torch.from_numpy(traj1["mask"]).float(),

            "obs2": torch.from_numpy(traj2["obs"]).float(),
            "acts2": torch.from_numpy(traj2["acts"]).long() if self.is_discrete else torch.from_numpy(traj2["acts"]).float(),
            "mask2": torch.from_numpy(traj2["mask"]).float(),

            "label": torch.tensor(label, dtype=torch.float32)
        }

# %% [markdown]
# ## ⚙️ Step 7: Train DPO Policy

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO

def train_dpo(dataloader, env, seed=0, epochs=25, device='cpu'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    
    model = PPO("MlpPolicy", env, verbose=0, seed=seed, device=device)
    policy = model.policy
    policy.train()  # ensure in training mode
    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]

            obs1_flat = obs1.view(-1, obs_dim)
            obs2_flat = obs2.view(-1, obs_dim)
            acts1_flat = acts1.view(-1) if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1) if is_discrete else acts2.view(-1, act_dim)

            dist1 = policy.get_distribution(obs1_flat)  # returns Categorical
            dist2 = policy.get_distribution(obs2_flat)
            lp1 = dist1.log_prob(acts1_flat).view(B, T)  # [B, T]
            lp2 = dist2.log_prob(acts2_flat).view(B, T)
            
            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits = logp1_sum - logp2_sum        # [B]

            loss = F.binary_cross_entropy_with_logits(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

#with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
#    prefs = pickle.load(f)
#prefs = prefs[:sample_prefs]

#dataset = PreferenceDataset(prefs, is_discrete)
#loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

#dpo_model = train_dpo(loader, env)
#torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")

# %%
import torch
import torch.nn.functional as F
from torch import nn
from stable_baselines3 import PPO
import copy

def train_dpo_from_ref(dataloader,ref_policy_sb3, env, beta= 0.05,  seed=42, epochs=25, device='cpu'):
    torch.manual_seed(seed)
    is_discrete = hasattr(env.action_space, "n")
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]


    ref_policy = ref_policy_sb3.policy  # frozen
    policy = copy.deepcopy(ref_policy)  # trainable

    policy.to(device)
    ref_policy.to(device)
    ref_policy.eval()  # ensure frozen

    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)

    for epoch in range(epochs):
        total_loss = 0
        policy.train()  # ensure in training mode
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            B, T = obs1.shape[0], obs1.shape[1]
            obs1_flat = obs1.view(-1, obs_dim) # [B*T, obs_dim]
            obs2_flat = obs2.view(-1, obs_dim) # [B*T, obs_dim]
            acts1_flat = acts1.view(-1).long() if is_discrete else acts1.view(-1, act_dim)
            acts2_flat = acts2.view(-1).long() if is_discrete else acts2.view(-1, act_dim)

            # --- Compute log probs from trainable policy ---

            dist1 = policy.get_distribution(obs1_flat)
            dist2 = policy.get_distribution(obs2_flat)

            logp1 = dist1.log_prob(acts1_flat)
            logp2 = dist2.log_prob(acts2_flat)



            #logp1 = torch.log_softmax(policy(obs1_flat), dim=-1)
            #logp2 = torch.log_softmax(policy(obs2_flat), dim=-1)

            # --- Compute log probs from reference policy (frozen) ---
            with torch.no_grad():
                dist1_ref = ref_policy.get_distribution(obs1_flat)
                dist2_ref = ref_policy.get_distribution(obs2_flat)

                logp1_ref = dist1_ref.log_prob(acts1_flat)
                logp2_ref = dist2_ref.log_prob(acts2_flat)

                #logp1_ref = torch.log_softmax(ref_policy(obs1_flat), dim=-1)
                #logp2_ref = torch.log_softmax(ref_policy(obs2_flat), dim=-1)


            lp1 = (logp1 - logp1_ref).view(B, -1)  # shape [B, T]
            lp2 = (logp2 - logp2_ref).view(B, -1)


            #lp1 = logp1[torch.arange(len(acts1_flat)), acts1_flat].view(B, -1)
            #lp2 = logp2[torch.arange(len(acts2_flat)), acts2_flat].view(B, -1)

            logp1_sum = (lp1 * mask1).sum(dim=1)  # [B]
            logp2_sum = (lp2 * mask2).sum(dim=1)  # [B]
            logits =beta*(logp1_sum - logp2_sum)        # [B]
            loss = F.binary_cross_entropy_with_logits(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return policy

# %%
def eval_policy(model, env, is_sb3=True, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0] if is_sb3 else model.select_action(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns



import matplotlib.pyplot as plt
import numpy as np

def fine_tune_dpo_with_betas(env, dataloader, pi2_model, beta_values_from_ref, epochs=15, device='cpu'):
    rewards_from_ref = {}
    rewards = {}

    obs_dim = env.observation_space.shape[0]
    is_discrete = hasattr(env.action_space, "n")
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]

    # ✅ Train DPO starting from π₂ and moving toward expert
    for beta in beta_values_from_ref:
        print(f"Training DPO (π₂ → Expert) with β = {beta}")

        trained_policy_from_ref = train_dpo_from_ref(
            dataloader=dataloader,
            ref_policy_sb3=pi2_model,
            env=env,
            beta=beta,
            epochs=epochs,
            device=device
        )

        avg_reward = np.mean(eval_policy(trained_policy_from_ref, env, episodes=40))
        print(f"Final avg reward for β = {beta}: {avg_reward:.2f}")
        rewards_from_ref[beta] = avg_reward






    # ✅ Plot both curves
    plt.figure(figsize=(9, 5))
    plt.plot(list(rewards_from_ref.keys()), list(rewards_from_ref.values()), marker='o', label="DPO from π₂")
    plt.xlabel("β (temperature)")
    plt.ylabel("Final Avg Reward")
    plt.title("DPO Fine-Tuning: π₂ → Expert vs Baseline")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return rewards_from_ref


rewards = []
num_prefs = [10000, 20000, 30000]
for num_pref in num_prefs:
    with open(f"prefs_{env_id}_seed{seed}_{num_pref}.pkl", "rb") as f:
        prefs = pickle.load(f)
    prefs = prefs[:num_pref]

    dataset = PreferenceDataset(prefs, is_discrete)
    loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

    beta_values_from_ref =np.concatenate([np.arange(0,0.2, 0.01) , np.arange(0.2, 1, 0.1), np.arange(1, 6, 0.2)])

    # we could also potentially choose an adaptive beta, like : beta = beta_init * (epoch / max_epochs)


    '''
    When I increase β, I am being more conservative and penalizing drift from pi_ref.
    When I decrease β, I allow the model to explore more and drift away from pi_ref.

    Becasue pi2 is close to expert, B do not play a key role here

    '''


    rewards_from_ref= fine_tune_dpo_with_betas(env, loader, pi2_model,beta_values_from_ref)
    rewards.append(rewards_from_ref)

print(rewards)
beta_from_ref = max(rewards_from_ref, key = rewards_from_ref.get)
#beta_from_ref = 0.5
print(f"--------------------------------we use beta = {beta_from_ref}")
# Out:
# Training DPO (π₂ → Expert) with β = 0.0
# Epoch 1/15, Loss: 0.6931
# Epoch 2/15, Loss: 0.6931
# Epoch 3/15, Loss: 0.6931
# Epoch 4/15, Loss: 0.6931
# Epoch 5/15, Loss: 0.6931
# Epoch 6/15, Loss: 0.6931
# Epoch 7/15, Loss: 0.6931
# Epoch 8/15, Loss: 0.6931
# Epoch 9/15, Loss: 0.6931
# Epoch 10/15, Loss: 0.6931
# Epoch 11/15, Loss: 0.6931
# Epoch 12/15, Loss: 0.6931
# Epoch 13/15, Loss: 0.6931
# Epoch 14/15, Loss: 0.6931
# Epoch 15/15, Loss: 0.6931
# Final avg reward for β = 0.0: -356.72
# Training DPO (π₂ → Expert) with β = 0.01
# Epoch 1/15, Loss: 0.1855
# Epoch 2/15, Loss: 0.1701
# Epoch 3/15, Loss: 0.1625
# Epoch 4/15, Loss: 0.1565
# Epoch 5/15, Loss: 0.1525
# Epoch 6/15, Loss: 0.1475
# Epoch 7/15, Loss: 0.1450
# Epoch 8/15, Loss: 0.1438
# Epoch 9/15, Loss: 0.1403
# Epoch 10/15, Loss: 0.1398
# Epoch 11/15, Loss: 0.1394
# Epoch 12/15, Loss: 0.1395
# Epoch 13/15, Loss: 0.1388
# Epoch 14/15, Loss: 0.1394
# Epoch 15/15, Loss: 0.1383
# Final avg reward for β = 0.01: -1212.07
# Training DPO (π₂ → Expert) with β = 0.02
# Epoch 1/15, Loss: 0.1840
# Epoch 2/15, Loss: 0.1678
# Epoch 3/15, Loss: 0.1594
# Epoch 4/15, Loss: 0.1523
# Final avg reward for β = 1.0: -416.40
# Training DPO (π₂ → Expert) with β = 1.2
# Epoch 1/15, Loss: 0.9109
# Epoch 2/15, Loss: 1.0212
# Epoch 3/15, Loss: 0.7515
# Epoch 4/15, Loss: 0.6773
# Epoch 5/15, Loss: 0.6941
# Epoch 6/15, Loss: 0.7901
# Epoch 7/15, Loss: 0.7090
# Epoch 8/15, Loss: 0.8227
# Epoch 9/15, Loss: 0.6914
# Epoch 10/15, Loss: 0.7246
# Epoch 11/15, Loss: 0.7018
# Epoch 12/15, Loss: 0.8364
# Epoch 13/15, Loss: 0.6554
# Epoch 14/15, Loss: 0.7187
# Epoch 15/15, Loss: 0.6342
# Final avg reward for β = 1.2: -386.71
# Training DPO (π₂ → Expert) with β = 1.4
# Epoch 1/15, Loss: 1.0695
# Epoch 2/15, Loss: 1.0119
# Epoch 3/15, Loss: 0.9528
# Epoch 4/15, Loss: 1.0090
# Epoch 5/15, Loss: 0.8071
# Epoch 6/15, Loss: 0.8309
# Epoch 7/15, Loss: 0.8375
# Epoch 8/15, Loss: 0.9149
# Epoch 9/15, Loss: 0.7481
# Epoch 10/15, Loss: 0.8006
# Epoch 11/15, Loss: 0.8625
# Epoch 12/15, Loss: 0.9258
# Epoch 13/15, Loss: 0.7552
# Epoch 14/15, Loss: 0.8428
# Epoch 15/15, Loss: 0.7142
# Final avg reward for β = 1.4: -403.74
# Training DPO (π₂ → Expert) with β = 1.5999999999999999
# Epoch 1/15, Loss: 1.1650
# Epoch 2/15, Loss: 1.0413
# Epoch 3/15, Loss: 1.3346
# Epoch 4/15, Loss: 0.9404
# Epoch 5/15, Loss: 0.9663
# Epoch 6/15, Loss: 0.8251
# Epoch 7/15, Loss: 0.8808
# Epoch 8/15, Loss: 1.0687
# Epoch 9/15, Loss: 0.8547
# Epoch 10/15, Loss: 0.9719
# Epoch 11/15, Loss: 1.0125
# Epoch 12/15, Loss: 1.1956
# Epoch 13/15, Loss: 0.9007
# Epoch 14/15, Loss: 1.0011
# Epoch 15/15, Loss: 0.8974
# Final avg reward for β = 1.5999999999999999: -413.44
# Training DPO (π₂ → Expert) with β = 1.7999999999999998
# Epoch 1/15, Loss: 1.4501
# Epoch 2/15, Loss: 1.5083
# Epoch 3/15, Loss: 1.2516
# Epoch 4/15, Loss: 0.9545
# Epoch 5/15, Loss: 1.0516
# Epoch 6/15, Loss: 1.1435
# Epoch 7/15, Loss: 1.0136
# Epoch 8/15, Loss: 1.2316
# Epoch 9/15, Loss: 0.9612
# Epoch 10/15, Loss: 1.0970
# Epoch 11/15, Loss: 1.0265
# Epoch 12/15, Loss: 1.3908
# Epoch 13/15, Loss: 1.0283
# Epoch 14/15, Loss: 1.0620
# Epoch 15/15, Loss: 0.9302
# Final avg reward for β = 1.7999999999999998: -409.16
# Training DPO (π₂ → Expert) with β = 1.9999999999999998
# Epoch 1/15, Loss: 1.6515
# Epoch 2/15, Loss: 1.4810
# Epoch 3/15, Loss: 1.3870
# Epoch 4/15, Loss: 1.2908
# Epoch 13/15, Loss: 0.5316
# Epoch 14/15, Loss: 0.6168
# Epoch 15/15, Loss: 0.5352
# Final avg reward for β = 1.0: -416.40
# Training DPO (π₂ → Expert) with β = 1.2
# Epoch 1/15, Loss: 0.9109
# Epoch 2/15, Loss: 1.0212
# Epoch 3/15, Loss: 0.7515
# Epoch 4/15, Loss: 0.6773
# Epoch 5/15, Loss: 0.6941
# Epoch 6/15, Loss: 0.7901
# Epoch 7/15, Loss: 0.7090
# Epoch 8/15, Loss: 0.8227
# Epoch 9/15, Loss: 0.6914
# Epoch 10/15, Loss: 0.7246
# Epoch 11/15, Loss: 0.7018
# Epoch 12/15, Loss: 0.8364
# Epoch 13/15, Loss: 0.6554
# Epoch 14/15, Loss: 0.7187
# Epoch 15/15, Loss: 0.6342
# Final avg reward for β = 1.2: -386.71
# Training DPO (π₂ → Expert) with β = 1.4
# Epoch 1/15, Loss: 1.0695
# Epoch 2/15, Loss: 1.0119
# Epoch 3/15, Loss: 0.9528
# Epoch 4/15, Loss: 1.0090
# Epoch 5/15, Loss: 0.8071
# Epoch 6/15, Loss: 0.8309
# Epoch 7/15, Loss: 0.8375
# Epoch 8/15, Loss: 0.9149
# Epoch 9/15, Loss: 0.7481
# Epoch 10/15, Loss: 0.8006
# Epoch 11/15, Loss: 0.8625
# Epoch 12/15, Loss: 0.9258
# Epoch 13/15, Loss: 0.7552
# Epoch 14/15, Loss: 0.8428
# Epoch 15/15, Loss: 0.7142
# Final avg reward for β = 1.4: -403.74
# Training DPO (π₂ → Expert) with β = 1.5999999999999999
# Epoch 1/15, Loss: 1.1650
# Epoch 2/15, Loss: 1.0413
# Epoch 3/15, Loss: 1.3346
# Epoch 4/15, Loss: 0.9404
# Epoch 5/15, Loss: 0.9663
# Epoch 6/15, Loss: 0.8251
# Epoch 7/15, Loss: 0.8808
# Epoch 8/15, Loss: 1.0687
# Epoch 9/15, Loss: 0.8547
# Epoch 10/15, Loss: 0.9719
# Epoch 11/15, Loss: 1.0125
# Epoch 12/15, Loss: 1.1956
# Epoch 13/15, Loss: 0.9007
# Epoch 14/15, Loss: 1.0011
# Epoch 15/15, Loss: 0.8974
# Final avg reward for β = 1.5999999999999999: -413.44
# Training DPO (π₂ → Expert) with β = 1.7999999999999998
# Epoch 1/15, Loss: 1.4501
# Epoch 2/15, Loss: 1.5083
# Epoch 3/15, Loss: 1.2516
# Epoch 4/15, Loss: 0.9545
# Epoch 5/15, Loss: 1.0516
# Epoch 6/15, Loss: 1.1435
# Epoch 7/15, Loss: 1.0136
# Epoch 8/15, Loss: 1.2316
# Epoch 9/15, Loss: 0.9612
# Epoch 10/15, Loss: 1.0970
# Epoch 11/15, Loss: 1.0265
# Epoch 12/15, Loss: 1.3908
# Epoch 13/15, Loss: 1.0283
# Epoch 14/15, Loss: 1.0620
# Epoch 15/15, Loss: 0.9302
# Final avg reward for β = 1.7999999999999998: -409.16
# Training DPO (π₂ → Expert) with β = 1.9999999999999998
# Epoch 1/15, Loss: 1.6515
# Epoch 2/15, Loss: 1.4810
# Epoch 11/15, Loss: 3.1229
# Epoch 12/15, Loss: 3.0257
# Epoch 13/15, Loss: 3.0872
# Epoch 14/15, Loss: 3.3297
# Epoch 15/15, Loss: 2.9857
# Final avg reward for β = 5.399999999999999: -442.41
# Training DPO (π₂ → Expert) with β = 5.599999999999999
# Epoch 1/15, Loss: 5.7034
# Epoch 2/15, Loss: 3.8651
# Epoch 3/15, Loss: 3.6235
# Epoch 4/15, Loss: 3.2883
# Epoch 5/15, Loss: 3.5499
# Epoch 6/15, Loss: 3.1581
# Epoch 7/15, Loss: 3.1102
# Epoch 8/15, Loss: 4.0911
# Epoch 9/15, Loss: 2.9304
# Epoch 10/15, Loss: 3.3745
# Epoch 11/15, Loss: 3.1384
# Epoch 12/15, Loss: 3.3691
# Epoch 13/15, Loss: 3.4603
# Epoch 14/15, Loss: 3.6482
# Epoch 15/15, Loss: 3.3370
# Final avg reward for β = 5.599999999999999: -401.27
# Training DPO (π₂ → Expert) with β = 5.799999999999999
# Epoch 1/15, Loss: 5.0691
# Epoch 2/15, Loss: 4.2048
# Epoch 3/15, Loss: 3.7998
# Epoch 4/15, Loss: 3.8845
# Epoch 5/15, Loss: 3.5352
# Epoch 6/15, Loss: 3.4610
# Epoch 7/15, Loss: 3.5686
# Epoch 8/15, Loss: 3.9265
# Epoch 9/15, Loss: 3.1800
# Epoch 10/15, Loss: 3.4671
# Epoch 11/15, Loss: 3.4395
# Epoch 12/15, Loss: 3.7104
# Epoch 13/15, Loss: 3.2939
# Epoch 14/15, Loss: 3.4631
# Epoch 15/15, Loss: 2.9178
# Final avg reward for β = 5.799999999999999: -403.69
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 67
#      65 num_prefs = [10000, 20000, 300000]
#      66 for num_pref in num_prefs:
# ---> 67     with open(f"prefs_{env_id}_seed{seed}_{num_pref}.pkl", "rb") as f:
#      68         prefs = pickle.load(f)
#      69     prefs = prefs[:sample_prefs]
#
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prefs_Pendulum-v1_seed42_300000.pkl'

# %%
plt.figure(figsize=(8, 6))

# Loop through each dictionary and create a scatter plot
for i, reward_dict in enumerate(rewards):
    x = list(reward_dict.keys())
    y = list(reward_dict.values())
    plt.plot(x, y, label=f'rr')

# Configure the plot
plt.title("beta finetuning for diffents lengths of beta")
plt.xlabel(" beta ")
plt.ylabel("rewards")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
dpo_model_from_ref = train_dpo_from_ref(loader,pi2_model, env, beta=0.5, seed=seed)
torch.save(dpo_model_from_ref.state_dict(), f"{env_id}_dpo_pi2_seed{seed}.pth")

dpo_model = train_dpo(loader, env, seed=seed)
torch.save(dpo_model.state_dict(), f"{env_id}_dpo_seed{seed}.pth")
# Out:
# Epoch 1/25, Loss: 0.6511
# Epoch 2/25, Loss: 0.7441
# Epoch 3/25, Loss: 0.3078
# Epoch 4/25, Loss: 0.4128
# Epoch 5/25, Loss: 0.4202
# Epoch 6/25, Loss: 0.3521
# Epoch 7/25, Loss: 0.3614
# Epoch 8/25, Loss: 0.3779
# Epoch 9/25, Loss: 0.4629
# Epoch 10/25, Loss: 0.3996
# Epoch 11/25, Loss: 0.3543
# Epoch 12/25, Loss: 0.4986
# Epoch 13/25, Loss: 0.3629
# Epoch 14/25, Loss: 0.3061
# Epoch 15/25, Loss: 0.3249
# Epoch 16/25, Loss: 0.2825
# Epoch 17/25, Loss: 0.2801
# Epoch 18/25, Loss: 0.3629
# Epoch 19/25, Loss: 0.4447
# Epoch 20/25, Loss: 0.3917
# Epoch 21/25, Loss: 0.2843
# Epoch 22/25, Loss: 0.4013
# Epoch 23/25, Loss: 0.3551
# Epoch 24/25, Loss: 0.4404
# Epoch 25/25, Loss: 0.3149
# Epoch 1/25, Loss: 1.2486
# Epoch 2/25, Loss: 1.0240
# Epoch 3/25, Loss: 0.8511
# Epoch 4/25, Loss: 0.7561
# Epoch 5/25, Loss: 0.6654
# Epoch 6/25, Loss: 0.5797
# Epoch 7/25, Loss: 0.5230
# Epoch 8/25, Loss: 0.4682
# Epoch 9/25, Loss: 0.4237
# Epoch 10/25, Loss: 0.3798
# Epoch 11/25, Loss: 0.3395
# Epoch 12/25, Loss: 0.3115
# Epoch 13/25, Loss: 0.2824
# Epoch 14/25, Loss: 0.2642
# Epoch 15/25, Loss: 0.2479
# Epoch 16/25, Loss: 0.2308
# Epoch 17/25, Loss: 0.2183
# Epoch 18/25, Loss: 0.2125
# Epoch 19/25, Loss: 0.1990
# Epoch 20/25, Loss: 0.1884
# Epoch 21/25, Loss: 0.1831
# Epoch 22/25, Loss: 0.1733
# Epoch 23/25, Loss: 0.1758
# Epoch 24/25, Loss: 0.1703
# Epoch 25/25, Loss: 0.1606

# %% [markdown]
# ## 🧠 Step 8: Train RewardNet from Preferences (for PPO-RLHF)

# %%
class RewardNet(nn.Module):
    def __init__(self, obs_dim, act_dim, is_discrete=True, hidden_size=64):
        super().__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, states, actions):
        if self.is_discrete:
            one_hot = F.one_hot(actions.view(-1), num_classes=self.act_dim).float()
            x = torch.cat([states, one_hot], dim=-1)
        else:
            x = torch.cat([states, actions], dim=-1)
        return self.net(x).squeeze(-1)

def train_reward_model(dataloader, obs_dim, act_dim, is_discrete, epochs=50, lr=1e-3, device='cpu'):
    model = RewardNet(obs_dim, act_dim, is_discrete).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        total_loss = 0.0
        for batch in dataloader:
            obs1 = batch["obs1"].to(device)      # [B, T, obs_dim]
            acts1 = batch["acts1"].to(device)    # [B, T] or [B, T, act_dim]
            mask1 = batch["mask1"].to(device)    # [B, T]

            obs2 = batch["obs2"].to(device)
            acts2 = batch["acts2"].to(device)
            mask2 = batch["mask2"].to(device)

            labels = batch["label"].to(device)   # [B]

            r1 = model(obs1.view(-1, obs_dim), acts1.view(-1) if is_discrete else acts1.view(-1, act_dim))
            r2 = model(obs2.view(-1, obs_dim), acts2.view(-1) if is_discrete else acts2.view(-1, act_dim))

            r1 = r1.view(obs1.shape[0], obs1.shape[1]) * mask1
            r2 = r2.view(obs2.shape[0], obs2.shape[1]) * mask2

            r1_sum = r1.sum(dim=1)  # [B]
            r2_sum = r2.sum(dim=1)  # [B]

            logits = r1_sum - r2_sum  # [B]
            loss = criterion(logits, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    return model

with open(f"prefs_{env_id}_seed{seed}.pkl", "rb") as f:
    prefs = pickle.load(f)
prefs = prefs[:sample_prefs]

dataset = PreferenceDataset(prefs, is_discrete=is_discrete)
loader = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

reward_model = train_reward_model(loader, obs_dim, act_dim, is_discrete)
torch.save(reward_model.state_dict(), f"{env_id}_reward_model_seed{seed}.pth")
# Out:
# Epoch 1/50, Loss: 0.8114
# Epoch 2/50, Loss: 0.1128
# Epoch 3/50, Loss: 0.1124
# Epoch 4/50, Loss: 0.1108
# Epoch 5/50, Loss: 0.1127
# Epoch 6/50, Loss: 0.1082
# Epoch 7/50, Loss: 0.1093
# Epoch 8/50, Loss: 0.1037
# Epoch 9/50, Loss: 0.1091
# Epoch 10/50, Loss: 0.1089
# Epoch 11/50, Loss: 0.1154
# Epoch 12/50, Loss: 0.1107
# Epoch 13/50, Loss: 0.1095
# Epoch 14/50, Loss: 0.1056
# Epoch 15/50, Loss: 0.1063
# Epoch 16/50, Loss: 0.1143
# Epoch 17/50, Loss: 0.1224
# Epoch 18/50, Loss: 0.1135
# Epoch 19/50, Loss: 0.1135
# Epoch 20/50, Loss: 0.1156
# Epoch 21/50, Loss: 0.1009
# Epoch 22/50, Loss: 0.1099
# Epoch 23/50, Loss: 0.1055
# Epoch 24/50, Loss: 0.1020
# Epoch 25/50, Loss: 0.1177
# Epoch 26/50, Loss: 0.1137
# Epoch 27/50, Loss: 0.1024
# Epoch 28/50, Loss: 0.1091
# Epoch 29/50, Loss: 0.1131
# Epoch 30/50, Loss: 0.1063
# Epoch 31/50, Loss: 0.1030
# Epoch 32/50, Loss: 0.1148
# Epoch 33/50, Loss: 0.1138
# Epoch 34/50, Loss: 0.1084
# Epoch 35/50, Loss: 0.1065
# Epoch 36/50, Loss: 0.1028
# Epoch 37/50, Loss: 0.1085
# Epoch 38/50, Loss: 0.1003
# Epoch 39/50, Loss: 0.0983
# Epoch 40/50, Loss: 0.0986
# Epoch 41/50, Loss: 0.1160
# Epoch 42/50, Loss: 0.0991
# Epoch 43/50, Loss: 0.1118
# Epoch 44/50, Loss: 0.1130
# Epoch 45/50, Loss: 0.1085
# Epoch 46/50, Loss: 0.1056
# Epoch 47/50, Loss: 0.0995
# Epoch 48/50, Loss: 0.1312
# Epoch 49/50, Loss: 0.1189
# Epoch 50/50, Loss: 0.0991

# %% [markdown]
# ## 🔁 Step 9: Train PPO-RLHF (Reward Finetuned from Expert π₁)

# %%
import gymnasium as gym
from gymnasium import Wrapper

class RewardNetWrapper(Wrapper):
    def __init__(self, env, reward_net, is_discrete):
        super().__init__(env)
        self.reward_net = reward_net
        self.is_discrete = is_discrete

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)

        # Convert to tensor
        obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        if self.is_discrete:
            act_tensor = torch.tensor(action, dtype=torch.long).unsqueeze(0)
        else:
            act_tensor = torch.tensor(action, dtype=torch.float32).unsqueeze(0)

        # Predict learned reward
        with torch.no_grad():
            reward = self.reward_net(obs_tensor, act_tensor).item()

        return obs, reward, terminated, truncated, info

# Wrap the environment with the trained reward_net
reward_model.eval()  # Ensure the model is in inference mode
env = RewardNetWrapper(gym.make(env_id), reward_model, is_discrete)
env = Monitor(env)

# Retrain the policy using the new reward
rlhf_model = PPO("MlpPolicy", env, verbose=1, seed=seed)
rlhf_model.learn(total_timesteps=total_timesteps)
rlhf_model.save(f"{env_id}_rlhf_seed{seed}.zip")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -40.2    |
# | time/              |          |
# |    fps             | 5663     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -34.4        |
# | time/                   |              |
# |    fps                  | 3571         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033265045 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0475       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.982        |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -24.5        |
# | time/                   |              |
# |    fps                  | 3263         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0045994692 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.93         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.956        |
# |    value_loss           | 10.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -21.6       |
# | time/                   |             |
# |    fps                  | 3133        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005970049 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00363    |
# |    std                  | 0.957       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -23.9        |
# | time/                   |              |
# |    fps                  | 3033         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0033252905 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.57         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00259     |
# |    std                  | 0.952        |
# |    value_loss           | 17.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -14.4        |
# | time/                   |              |
# |    fps                  | 2974         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0031525425 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.21         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0037      |
# |    std                  | 0.943        |
# |    value_loss           | 12.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -12.2        |
# | time/                   |              |
# |    fps                  | 2941         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034217495 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.3          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 0.938        |
# |    value_loss           | 18.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -9.42        |
# | time/                   |              |
# |    fps                  | 2788         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0018948277 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00311     |
# |    std                  | 0.935        |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -4.58        |
# | time/                   |              |
# |    fps                  | 2785         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0066365544 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00733     |
# |    std                  | 0.932        |
# |    value_loss           | 12.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 0.282       |
# | time/                   |             |
# |    fps                  | 2783        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004661533 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0023     |
# |    std                  | 0.925       |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 7.1         |
# | time/                   |             |
# |    fps                  | 2784        |
# |    iterations           | 11          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005048421 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0032     |
# |    std                  | 0.923       |
# |    value_loss           | 16.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 9.49        |
# | time/                   |             |
# |    fps                  | 2773        |
# |    iterations           | 12          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008579873 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0075     |
# |    std                  | 0.927       |
# |    value_loss           | 14.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 2768         |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0069094137 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.01         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00416     |
# |    std                  | 0.909        |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 23.2         |
# | time/                   |              |
# |    fps                  | 2766         |
# |    iterations           | 14           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0059603117 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.48         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00354     |
# |    std                  | 0.899        |
# |    value_loss           | 7.67         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 29          |
# | time/                   |             |
# |    fps                  | 2770        |
# |    iterations           | 15          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007083372 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00806    |
# |    std                  | 0.886       |
# |    value_loss           | 4.93        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 34.7         |
# | time/                   |              |
# |    fps                  | 2777         |
# |    iterations           | 16           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0029703309 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.776        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.867        |
# |    value_loss           | 3.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 37.3         |
# | time/                   |              |
# |    fps                  | 2778         |
# |    iterations           | 17           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0107167475 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1            |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000503    |
# |    std                  | 0.861        |
# |    value_loss           | 3.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 43.4        |
# | time/                   |             |
# |    fps                  | 2785        |
# |    iterations           | 18          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008210726 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.997       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.861       |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 2787        |
# |    iterations           | 19          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008878138 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00131    |
# |    std                  | 0.821       |
# |    value_loss           | 0.758       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 49.7         |
# | time/                   |              |
# |    fps                  | 2788         |
# |    iterations           | 20           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0083855465 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.105        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.781        |
# |    value_loss           | 0.232        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 50.8         |
# | time/                   |              |
# |    fps                  | 2784         |
# |    iterations           | 21           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0042283684 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.282        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000381    |
# |    std                  | 0.778        |
# |    value_loss           | 0.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 53.5         |
# | time/                   |              |
# |    fps                  | 2781         |
# |    iterations           | 22           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0027822033 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.764        |
# |    value_loss           | 0.936        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 54.1        |
# | time/                   |             |
# |    fps                  | 2781        |
# |    iterations           | 23          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005131376 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.189       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00286    |
# |    std                  | 0.755       |
# |    value_loss           | 0.582       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 56.9         |
# | time/                   |              |
# |    fps                  | 2781         |
# |    iterations           | 24           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0073504676 |
# |    clip_fraction        | 0.072        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00461     |
# |    std                  | 0.745        |
# |    value_loss           | 0.476        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 58.5        |
# | time/                   |             |
# |    fps                  | 2791        |
# |    iterations           | 25          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009976089 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00548     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.746       |
# |    value_loss           | 0.153       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 58.8        |
# | time/                   |             |
# |    fps                  | 2793        |
# |    iterations           | 26          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011297765 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0536      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00444    |
# |    std                  | 0.739       |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 60.7        |
# | time/                   |             |
# |    fps                  | 2794        |
# |    iterations           | 27          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016325485 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0507      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00768    |
# |    std                  | 0.718       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 59.9         |
# | time/                   |              |
# |    fps                  | 2793         |
# |    iterations           | 28           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0071965996 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0542       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00404     |
# |    std                  | 0.711        |
# |    value_loss           | 0.201        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 58.6         |
# | time/                   |              |
# |    fps                  | 2793         |
# |    iterations           | 29           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038496861 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.713        |
# |    value_loss           | 3.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 57.6        |
# | time/                   |             |
# |    fps                  | 2794        |
# |    iterations           | 30          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006192891 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00587    |
# |    std                  | 0.711       |
# |    value_loss           | 8.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 58.3         |
# | time/                   |              |
# |    fps                  | 2797         |
# |    iterations           | 31           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0036787582 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.34         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.709        |
# |    value_loss           | 7.99         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 59.7        |
# | time/                   |             |
# |    fps                  | 2798        |
# |    iterations           | 32          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004480742 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.325       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000975   |
# |    std                  | 0.703       |
# |    value_loss           | 1.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 60.7         |
# | time/                   |              |
# |    fps                  | 2797         |
# |    iterations           | 33           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0053744246 |
# |    clip_fraction        | 0.0923       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00279      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.00171      |
# |    std                  | 0.678        |
# |    value_loss           | 0.196        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 60           |
# | time/                   |              |
# |    fps                  | 2789         |
# |    iterations           | 34           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0055771163 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0278       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000404    |
# |    std                  | 0.661        |
# |    value_loss           | 0.142        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 59.8         |
# | time/                   |              |
# |    fps                  | 2787         |
# |    iterations           | 35           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0031600199 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.678        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.659        |
# |    value_loss           | 1.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 60.9        |
# | time/                   |             |
# |    fps                  | 2783        |
# |    iterations           | 36          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007400156 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.015       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000599   |
# |    std                  | 0.635       |
# |    value_loss           | 0.058       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 61.3        |
# | time/                   |             |
# |    fps                  | 2780        |
# |    iterations           | 37          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005051517 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0314      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 0.629       |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 61.3        |
# | time/                   |             |
# |    fps                  | 2779        |
# |    iterations           | 38          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007710997 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.257       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00496    |
# |    std                  | 0.632       |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 63.9        |
# | time/                   |             |
# |    fps                  | 2785        |
# |    iterations           | 39          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005054578 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.589       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000874   |
# |    std                  | 0.631       |
# |    value_loss           | 0.999       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 64.5        |
# | time/                   |             |
# |    fps                  | 2795        |
# |    iterations           | 40          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006436779 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00214    |
# |    std                  | 0.625       |
# |    value_loss           | 0.404       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 65.2        |
# | time/                   |             |
# |    fps                  | 2805        |
# |    iterations           | 41          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009447009 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.627       |
# |    value_loss           | 2.58        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 65.7         |
# | time/                   |              |
# |    fps                  | 2814         |
# |    iterations           | 42           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0057486217 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.97         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00424     |
# |    std                  | 0.628        |
# |    value_loss           | 3.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 65.6        |
# | time/                   |             |
# |    fps                  | 2824        |
# |    iterations           | 43          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011017226 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0285      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00155     |
# |    std                  | 0.615       |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 2833        |
# |    iterations           | 44          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015105268 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00366    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.585       |
# |    value_loss           | 0.0373      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 65.9        |
# | time/                   |             |
# |    fps                  | 2840        |
# |    iterations           | 45          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005389221 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.148       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00442    |
# |    std                  | 0.593       |
# |    value_loss           | 0.768       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 66.3       |
# | time/                   |            |
# |    fps                  | 2849       |
# |    iterations           | 46         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01002522 |
# |    clip_fraction        | 0.0865     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.878     |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0427     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0019    |
# |    std                  | 0.57       |
# |    value_loss           | 0.11       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 66.4        |
# | time/                   |             |
# |    fps                  | 2849        |
# |    iterations           | 47          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008847268 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.573       |
# |    value_loss           | 0.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 67.3        |
# | time/                   |             |
# |    fps                  | 2857        |
# |    iterations           | 48          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013662934 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00325     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00212    |
# |    std                  | 0.555       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | 67.6      |
# | time/                   |           |
# |    fps                  | 2865      |
# |    iterations           | 49        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0082633 |
# |    clip_fraction        | 0.0924    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.832    |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0176   |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.00218  |
# |    std                  | 0.553     |
# |    value_loss           | 0.0418    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 68.6        |
# | time/                   |             |
# |    fps                  | 2873        |
# |    iterations           | 50          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007014147 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0212      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 0.545       |
# |    value_loss           | 0.0587      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 69.7         |
# | time/                   |              |
# |    fps                  | 2880         |
# |    iterations           | 51           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0069690784 |
# |    clip_fraction        | 0.0905       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.103        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00438     |
# |    std                  | 0.534        |
# |    value_loss           | 0.132        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 70.1        |
# | time/                   |             |
# |    fps                  | 2888        |
# |    iterations           | 52          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007876635 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0258      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00238    |
# |    std                  | 0.517       |
# |    value_loss           | 0.0532      |
# -----------------------------------------
# -----------------------------------------
# ...
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0205     |
# |    n_updates            | 1290       |
# |    policy_gradient_loss | 0.00442    |
# |    std                  | 0.247      |
# |    value_loss           | 0.024      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 73.7        |
# | time/                   |             |
# |    fps                  | 2697        |
# |    iterations           | 131         |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 268288      |
# | train/                  |             |
# |    approx_kl            | 0.014899429 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0245     |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.00374    |
# |    std                  | 0.249       |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 74.6        |
# | time/                   |             |
# |    fps                  | 2696        |
# |    iterations           | 132         |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.015729629 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0352     |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.686       |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.252       |
# |    value_loss           | 2.07        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 74.3       |
# | time/                   |            |
# |    fps                  | 2695       |
# |    iterations           | 133        |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 272384     |
# | train/                  |            |
# |    approx_kl            | 0.03133724 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0295    |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0109     |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | 0.00552    |
# |    std                  | 0.246      |
# |    value_loss           | 0.0379     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75          |
# | time/                   |             |
# |    fps                  | 2694        |
# |    iterations           | 134         |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.026019888 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00609    |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0571      |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.00254     |
# |    std                  | 0.242       |
# |    value_loss           | 0.0199      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 74.9        |
# | time/                   |             |
# |    fps                  | 2692        |
# |    iterations           | 135         |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.016121183 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00603    |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00472     |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | 0.00523     |
# |    std                  | 0.245       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.6        |
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 136         |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.019119913 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00838    |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00892    |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | 0.00162     |
# |    std                  | 0.243       |
# |    value_loss           | 0.0079      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 74.8        |
# | time/                   |             |
# |    fps                  | 2689        |
# |    iterations           | 137         |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.016954813 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00492     |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.0011      |
# |    std                  | 0.238       |
# |    value_loss           | 0.017       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 74.3       |
# | time/                   |            |
# |    fps                  | 2687       |
# |    iterations           | 138        |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 282624     |
# | train/                  |            |
# |    approx_kl            | 0.04117055 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0201     |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.14       |
# |    n_updates            | 1370       |
# |    policy_gradient_loss | -0.00363   |
# |    std                  | 0.235      |
# |    value_loss           | 0.0825     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 74.6       |
# | time/                   |            |
# |    fps                  | 2686       |
# |    iterations           | 139        |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 284672     |
# | train/                  |            |
# |    approx_kl            | 0.03693942 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0363     |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00258   |
# |    n_updates            | 1380       |
# |    policy_gradient_loss | 0.00376    |
# |    std                  | 0.231      |
# |    value_loss           | 0.035      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 76          |
# | time/                   |             |
# |    fps                  | 2686        |
# |    iterations           | 140         |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.011009042 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0478      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00818     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | 0.002       |
# |    std                  | 0.23        |
# |    value_loss           | 0.00248     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 77          |
# | time/                   |             |
# |    fps                  | 2684        |
# |    iterations           | 141         |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.009155255 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0645      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0194     |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.000859   |
# |    std                  | 0.224       |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 76          |
# | time/                   |             |
# |    fps                  | 2683        |
# |    iterations           | 142         |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.015000597 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0927      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0632      |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | 0.000913    |
# |    std                  | 0.217       |
# |    value_loss           | 0.0164      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.5        |
# | time/                   |             |
# |    fps                  | 2673        |
# |    iterations           | 143         |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.022028586 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.105       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0223      |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00363    |
# |    std                  | 0.218       |
# |    value_loss           | 0.0291      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.4        |
# | time/                   |             |
# |    fps                  | 2669        |
# |    iterations           | 144         |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.022711998 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.103       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00156     |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.00703     |
# |    std                  | 0.219       |
# |    value_loss           | 0.0257      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.6        |
# | time/                   |             |
# |    fps                  | 2668        |
# |    iterations           | 145         |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.027347716 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.117       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.00653     |
# |    std                  | 0.212       |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.3        |
# | time/                   |             |
# |    fps                  | 2668        |
# |    iterations           | 146         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.027424663 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.134       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0238      |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | 0.00476     |
# |    std                  | 0.211       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 75.9        |
# | time/                   |             |
# |    fps                  | 2668        |
# |    iterations           | 147         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.024229744 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.141       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.00257     |
# |    std                  | 0.209       |
# |    value_loss           | 0.0229      |
# -----------------------------------------

# %% [markdown]
# ## 📊 Step 10: Compare PPO Expert vs PPO-RLHF vs DPO

# %%
def eval_policy(model, env, episodes=20):
    returns = []
    for idx in range(episodes):
        obs, _ = env.reset(seed=idx)
        total = 0.0
        done = False
        while not done:
            action = model.predict(obs, deterministic=True)[0]
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total += reward
        returns.append(total)
    return returns


env = gym.make(env_id)
returns_expert = eval_policy(PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env), env)
returns_rlhf   = eval_policy(PPO.load(f"{env_id}_rlhf_seed{seed}.zip", env=env), env)
dpo_model = PPO("MlpPolicy", env, verbose=0, seed=seed)
state_dict = torch.load(f"{env_id}_dpo_seed{seed}.pth")
dpo_model.policy.load_state_dict(state_dict)
returns_dpo    = eval_policy(dpo_model, env)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env)
returns_pi2 = eval_policy(pi2_model, env)
dpo_model_from_pi2 = PPO("MlpPolicy", env, verbose=0, seed=seed)
dpo_model_from_pi2.policy.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))
returns_dpo_from_pi2 = eval_policy(dpo_model_from_pi2, env)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# First subplot: Full comparison
axes[0].boxplot([returns_expert, returns_rlhf, returns_dpo, returns_pi2, returns_dpo_from_pi2],
                labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
                showmeans=True)
axes[0].set_title("Full Policy Comparison")
axes[0].set_ylabel("Episode Return")
axes[0].set_ylim([-1750, 0])
axes[0].grid(True)

# Second subplot: Only DPO, π₁, and π₂
axes[1].boxplot([returns_expert, returns_pi2,returns_rlhf, returns_dpo_from_pi2],
                labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
                showmeans=True)
axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
axes[1].set_ylim([-400, 0])
axes[1].grid(True)

plt.tight_layout()
plt.savefig(f"{env_id}_dual_benchmark_{seed}_dataset{sample_prefs}.png", dpi=300)
plt.show()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:33: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:42: SyntaxWarning: invalid escape sequence '\p'
#   labels=["Expert ($\pi_1$)", "$\pi_2$", "RLHF","DPO from $\pi_2$"],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1].set_title("Focused: Expert, π₂, RLHF, DPO from $\pi_2$")
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:32: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot([returns_expert, returns_rlhf, returns_dpo, returns_pi2, returns_dpo_from_pi2],
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/1006884898.py:41: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot([returns_expert, returns_pi2,returns_rlhf, returns_dpo_from_pi2],

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML, display
from stable_baselines3 import PPO
import os

# Step 1: Run a single episode and record rendered frames
def record_episode(model, env, seed, max_steps=1000):
    frames = []
    obs, _ = env.reset(seed=seed)
    for _ in range(max_steps):
        frame = env.render()
        frames.append(frame)
        action = model.predict(obs, deterministic=True)[0]
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    return frames

# Step 2: Combine multiple frame sequences into a single animation and optionally save as a GIF
def show_combined_animation(frames_list, fps=30, gif_path=None):
    min_len = min(len(f) for f in frames_list)
    fig = plt.figure(figsize=(12, 4))
    plt.axis('off')
    init_frame = np.hstack([f[0] for f in frames_list])
    im = plt.imshow(init_frame)

    def update(i):
        combined = np.hstack([f[i] for f in frames_list])
        im.set_array(combined)
        return [im]

    ani = animation.FuncAnimation(fig, update, frames=min_len, interval=1000/fps)

    if gif_path:
        ani.save(gif_path, writer='pillow', fps=fps)
        print(f"✅ GIF saved to: {os.path.abspath(gif_path)}")

    return HTML(ani.to_jshtml())

def trajectory_overlay_faded(frames, threshold=30, min_alpha=0.05, max_alpha=0.6):
    frames = [f.astype(np.float32) for f in frames]
    H, W, C = frames[0].shape

    overlay = np.ones((H, W, C), dtype=np.float32) * 255
    num_frames = len(frames)

    for idx, frame in enumerate(frames):
        diff = np.abs(frame - 255)
        mask = (diff.mean(axis=2) > threshold)

        alpha = min_alpha + (max_alpha - min_alpha) * (idx / (num_frames - 1))

        for c in range(3):
            overlay[:, :, c][mask] = (
                alpha * frame[:, :, c][mask] +
                (1 - alpha) * overlay[:, :, c][mask]
            )
    return np.clip(overlay, 0, 255).astype(np.uint8)

def show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2, titles=None):
    if titles is None:
        titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]

    fig, axes = plt.subplots(1, 5, figsize=(18, 6))
    images = [img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2]

    for ax, img, title in zip(axes, images, titles):
        ax.imshow(img)
        ax.set_title(title, fontsize=20)
        ax.axis('off')
    plt.tight_layout()
    plt.savefig(f"{env_id}_render_{seed}_dataset{sample_prefs}.png", dpi=300)
    plt.show()

# Step 4: Load models and environments
# Step 4: Load models and environments
env_expert = gym.make(env_id, render_mode="rgb_array")
env_rlhf   = gym.make(env_id, render_mode="rgb_array")
env_dpo    = gym.make(env_id, render_mode="rgb_array")
env_pi2 = gym.make(env_id, render_mode="rgb_array")
env_dpo_from_pi2 = gym.make(env_id, render_mode="rgb_array")
expert_model = PPO.load(f"{env_id}_expert_seed{seed}.zip", env=env_expert)
rlhf_model   = PPO.load(f"{env_id}_rlhf_seed{seed}.zip", env=env_rlhf)
dpo_model.policy.load_state_dict(state_dict)
pi2_model = PPO.load(f"{env_id}_pi2_model_seed{seed}.zip", env=env_pi2)
dpo_from_pi2 = copy.deepcopy(pi2_model.policy)
dpo_from_pi2.load_state_dict(torch.load(f"{env_id}_dpo_pi2_seed{seed}.pth"))

# Step 5: Collect animation frames for all three strategies
frames_expert = record_episode(expert_model, env_expert, seed=seed)
frames_rlhf   = record_episode(rlhf_model, env_rlhf, seed=seed)
frames_dpo    = record_episode(dpo_model, env_dpo, seed=seed)
frames_pi2 = record_episode(pi2_model, env_pi2, seed=seed)
frames_dpo_from_pi2 = record_episode(dpo_from_pi2, env_dpo_from_pi2, seed=seed)

# Step 6: Display the combined animation and save it as a GIF file
display(HTML("<h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2"))
display(show_combined_animation(
    [frames_expert, frames_rlhf, frames_dpo, frames_pi2, frames_dpo_from_pi2],
    gif_path=f"{env_id}_comparison_seed{seed}_dataset{sample_prefs}.gif"
))

img_expert = trajectory_overlay_faded(frames_expert, threshold=55)
img_rlhf = trajectory_overlay_faded(frames_rlhf, threshold=55)
img_dpo = trajectory_overlay_faded(frames_dpo, threshold=55)
img_pi2 = trajectory_overlay_faded(frames_pi2, threshold=55)
img_dpo_from_pi2 = trajectory_overlay_faded(frames_dpo_from_pi2, threshold=55)
show_trajectory_comparison(img_expert, img_rlhf, img_dpo, img_pi2, img_dpo_from_pi2)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/4259130483.py:66: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]
# /var/folders/2y/m4y6zdts1b7_30s8c0tfd1b40000gn/T/ipykernel_1350/4259130483.py:66: SyntaxWarning: invalid escape sequence '\p'
#   titles = ["Expert", "RLHF", "DPO", "$\pi_2$", "DPO from $\pi_2$"]
# <h3>🎯 Strategy Animation Comparison: PPO Expert vs RLHF vs DPO</h3> vs PI2 vs DPO_PI2
# ✅ GIF saved to: /Users/mathis/Master/RL/project/yule/EE-568-RL/Pendulum-v1_comparison_seed42_dataset2000.gif
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7ffcf79fc0d6415fa929505585a509c9">
#   <div class="anim-controls">
#     <input id="_anim_slider7ffcf79fc0d6415fa929505585a509c9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7ffcf79fc0d6415fa929505585a509c9.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7ffcf79fc0d6415fa929505585a509c9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7ffcf79fc0d6415fa929505585a509c9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7ffcf79fc0d6415fa929505585a509c9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7ffcf79fc0d6415fa929505585a509c9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7ffcf79fc0d6415fa929505585a509c9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7ffcf79fc0d6415fa929505585a509c9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7ffcf79fc0d6415fa929505585a509c9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7ffcf79fc0d6415fa929505585a509c9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7ffcf79fc0d6415fa929505585a509c9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7ffcf79fc0d6415fa929505585a509c9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7ffcf79fc0d6415fa929505585a509c9"
#              >
#       <label for="_anim_radio1_7ffcf79fc0d6415fa929505585a509c9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7ffcf79fc0d6415fa929505585a509c9"
#              checked>
#       <label for="_anim_radio2_7ffcf79fc0d6415fa929505585a509c9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7ffcf79fc0d6415fa929505585a509c9"
#              >
#       <label for="_anim_radio3_7ffcf79fc0d6415fa929505585a509c9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7ffcf79fc0d6415fa929505585a509c9";
#     var slider_id = "_anim_slider7ffcf79fc0d6415fa929505585a509c9";
#     var loop_select_id = "_anim_loop_select7ffcf79fc0d6415fa929505585a509c9";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAD95J
